# %% [markdown]
# # 리뷰 데이터 수집

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.banhala.android",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST)

# %%
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    df.to_csv(f'./data/01.리뷰키워드분석_01통합본_{name}_리뷰크롤링파일.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'에이블리')

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
def tokenize(dataFrame):
    okt = Okt()
    dataFrame['morphs'] = [okt.morphs(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    tokenize(dataFrame)
    remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <22194x20754 sparse matrix of type '<class 'numpy.int64'>'
# 	with 169279 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <22194x20754 sparse matrix of type '<class 'numpy.float64'>'
# 	with 169279 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '사용 있었는데 리뷰 사진 업로드 돼요 문의 해봤는데 지우고 깔라 업데이트 반복 어쩔 는 사진 업로드 될 있는데 상황 은 10 2 없어요 사진 업로드 싶어도 돼서 너무 짜증납니다 업데이트 계속 휴대폰 데이터 최신 버전,쓰면서 느낀 아쉬운 3 써 볼게요 ..! 1 쓰다 보니 원래 가격 에다가 3000원 붙여놓고 무료 배송 이라 쓰는거였어요 2 옷 인기 순 설정 많이 팔린 순이 아니고 시스템 덜 팔린 옷 띄워줘요 구매 횟수 적은 옷 보여줘 야하는건 이해 이럴거면 인기 순 설정 버튼 은 있는거죠 3 첫 구매 990원 이벤트 아무 없이 없어져서 아쉬워요 ㅜㅠ,환불 처리 너무 느립니다 이건 에이 블리 아니고 마켓 쇼핑몰 같은데 이틀 만에 완료 제품 있지만 취소 일주일 넘게 걸리는 있습니다 학생 은 돈 넉넉하지 않아서 돈 빨리 들어오면 일주일 돈 없이 살아야 됩니다 교환 이미 상품 받고 반품 거 면 달이 넘어도 이해 하겠는데 아직 배송 했고 상품 준비 중이 라고 뜨면서 배송 은 2 주일 지나도록 오는 취소 하겠다는데 처리 너무 느리네요 문의 기다리라고만 짜증납니다,구매 좋은 앱 가장 큰 단점 있습니다 인형 또는 키링 자잘한 악세사리 구매 검색 했을 나오는 가격 대부분 가짜 라는 거 죠 일반 상품 검색 나오는 가격 은 선택 할인 적용 되지 않은 가격 적어야 한다고 합니다 에이블리 는 검색 했을 보이는 가격 실제 구매 탭 볼 있는 가격 다릅니다 키링 구매 개당 5000원 구매 시 개당 4000원 ( 총 8000원 ) 구매 있는 할인 행사 진행중 라면 대표 보이는 가격 은 당연히 5000원 이어야 대부분 개당 4000원 이라고 표시 한다는 겁니다 낱개 로만 구매 싶을 땐 탭 들어가서 실제 가격 확인 해야 굉장히 불편합니다 몇몇 브랜드 에서만 표시 아닌 대부분 브랜드 식 표시 있기 에이 블리 어플 자체 표시 방식 바꿔주셨으면 좋겠습니다,가격 4900원 적어놨는데 막상 상품 고르면 진짜 가격 은 만원 넘고 이러네요 옵션 추가 게 없는데 가짜 가격 적어놓은 상품 쇼핑 불편해요 진짜 가격 얼 들어가서 일일이 클릭 확인 해야 되니 타 쇼핑몰 보다 직관 이지 힘 들어요 에이 블 리가 유명해서 필요한거 사려 깔았는데 클릭 마다 상품 지웠어요 부분 해결 되면 좋을 같아요,사용 하고있는데 부분 추가 되었으면 좋겠어요 첫째 장바구니 검색 옵션 장바구니 옷 많이 담아놓는 사용자 로서 장바구니 제품 쇼핑몰 명칭 검색 찾을수 있게 기능 생기 면 좋겠습니다 일일 히 스 크롤 내려서 찾는게 너무 힘들어요 둘째 지그재그 처럼 해당 쇼핑몰 들어가면 카테고리 아우 터 스커트 상의 세부 카테고리 나눠서 볼수있는 기능 생겼음 좋겠습니다 아우 터 들어가면 아우 터 에도 패딩 롱 코트 숏 코트 조끼 자켓 집업 가디건 종류 별로 볼수있게 카테고리 추가 해주세요 ㅠ 는 들어 패딩제품 으로만 보고싶은데 아우 터 제품 뜨니까 패딩 찾아 보기 너무 힘들고 불편합니다 부분 개선 되면 사용자 입장 편하게 이용 할수있을거 같아요,너무 잘쓰고있습니다 6년 째 사용 인데 예전 에는 그랬는데 계속 업데이트 서는 마켓 오래 스 크롤 면 \' 오류 발생 새로고침 \' 페이지 뜨면서 보던게 날아가요 ㆍㆍ 마켓 살때 한번 다 사려 카테고리 별로 누르면서 살펴보는데 오래 봐도 렉 걸걸 리다 새로고침 창 뜨니까 보던 상품 있는데까지 내려가야되 고하는게 굉장히 불편합니다 업데이트 마다 은 개선 되지 않고있습니다,옷 종류 다양하고 포인트 모으는 방법 여러가지 광고 나옵니다 쿠폰 주고 가격 싸고 질도 좋은 옷 많아서 사용 했습니다 검색 추천 순 저가 순 으로도 옷 볼 있고 키 나이 컬러 디자인 디 테일로 기준 나눠 볼 있어서 좋았어요 기장 사이 즈 별로 볼 있는 기능 생겼으면 좋겠습니다 제품 추천 옷 나오는 기능 선택 해서 나오거나 나오지 않게 있게 되면 정말 감사할 같습니다,상품 가격 비교 하며 합리 있어서 좋습니다 1:1 오더 방식 해외 배송 은 정확한 배송 기간 유추 어려워 기다림 길어질 있습니다 여러 할인 쿠폰 포인트 적립 사용 은 너무 좋습니다 정말 급할 마음 드는 제품 은 쓱 배송 불가하더라구요 쓱 배송 제품 다양하게 늘어났으면 좋겠습니다,에이 블리 쓰고 있어요 근데 결제 아쉬운 부분 발견 네이버 페이 사용 해야 할인 쿠폰 인데 페이 코 선택 결제 진행 시 도합 니 다 인증 끝난 나온 메시지 \' 정지 된 카드 라서 결제 실패했다 \' 떠요 카드 는 정상 카드 맞기 에러 메시지 잘못 되었어요 쿠폰 맞게 해당 결제 수단 선택 하도록 구현 해야 같아요 처음 결제 진행 되지 막아야 같습니다 !!!,진짜 좋은데 필터 빼는 기능 ? 넣어주셨으면 좋겠어요 버클 싫어하는데 버클 없게 했으면 좋겠어요 ... ㅠㅜ 가로 볼수있어야 좀더 좋은 재질 퀄리티 추측 할수있는데 할인 율 높고 가격 대 조정 원하는 제품 보일수있어서 에요,정말 사용 있었는데 최근 들어 오류 많이 발생 해서 서칭 하다가도 오류 발생 되었다는 문구 초기 화면 돌아가지네요 서 칭 하던 걸 찾아야하구요 기본 나와있는 가격 이랑 구매 하려고 선택 가격 이랑 차이 나면 정말 기분 좋습니다 부분 서 해결 부탁드립니다 에이 블리 사용 쉽고 가격 대가 낮은 쇼핑 앱 은 처음 써 봐서 정말 유용하게 사용 있는만큼 최근 들어 실망 스러운 마음 개선 부탁드립니다,에이 블리 이용 있는데 메인 화면 보이는 가격 실제 제품 가격 너무 불편해요 ㅠㅜ 판매 입장 소비자 할인 율과 싼 가격 이라고 어필 있겠지만 너무 별로 예요 ㅠ 사려 하니까 가격 달라 서 실망하고 은 같아서 불편해요 ... 일일이 제품 다 선택 해 보면서 가격 따로 확인 하려니까 검색 해서 원하는 가격 대만 볼 수도 소비 너무 되더라고요 에이 블리 측 해결 해주시 면 좋을 같습니다,안녕하세요 에이블리 요즘 좋아하고 재밌게 사는 모든 거 다 좋고 재 원하는 옷 있고 이쁜 옷 많아서 좋긴 아쉬운 게 있어요 재 가해 주길 원하는 가격 조이스틱 움직 여서 하는게 어렵네요 조이스틱 말고 원하는 가격 타자 쳐서 게 편리할 같네요 이점 고쳐주시면 다른건 다 좋습니다,건 다 좋습니다 옷 입고 있고요 단점 은 허리 너무 얇으면 입 바지 한정 된다는 겁니다 정장 느낌 바지 계속 찾고 검색 해보는데 계속 젤 작은 허리 29 나오네요 필터 키 뿐 몸무게 넣어주시면 찾기 편할 같아요 실제 모델 분 리뷰 다 확인 샀는데도 허리 큰 많습니다,크게 불편한 은 없는데 한가지 ... 메인 화면 추천 상품 뜨는 거 알고리즘 너무 극단 랄 까요 들어 는 귀 뚫어서 귀걸이 는 관심 없는 인데 어쩌다 실수 귀걸이 제품 눌렀다치면 뒤 장창 귀걸이 도배 됩니다 관련 없는 상품 입니다를 50 눌러도 계속 뜰 ... 자꾸 이러니까 뭐 눌러 보기 겁나네요 알고리즘 망할까봐 ;,어플 사용 제일 짜잉나는점 .... 상품 보다가 화면 내리거나 어플 보다가 들어가면 첫 화면 돌아가는 ...... 거 너무 불편해서 삭제 지그재그 쓰다가 개선 됐나 싶어서 설치 해봤는데 이러네요 ㅠㅠㅠㅠ,구매 이력 없으면 등급 낮아지는 거 그래요 🤨🤔 등급 올라가는데 구매 시 라면서 게이지 있는데 서서히 깎이면서 등급 낮아졌더라고요 ? 달 구매 했다가 깜짝 놀람 설명 엄청 아쉬움 😮\u200d💨 최근 키 몸무게 사이즈 별 선택 하여 리뷰 몰아서 볼 있는 기능 추가 됐던데 아주 칭찬 함 사용 부분 가장 강점 이긴 했음 배송 은 쇼핑몰 마다 다르지만 빠르면 1 3일 늦으면 4 14일 봄 ( 해외 상품 재고 부족 포함 ) 미리 안내 문자 보내주느냐 배송 시작 택배 확인 늦어 늦게 오는 있어서 쇼핑몰 문의 빨리 받은 있음 솔직히 샥 - 출발 주문 상품 은 빨리 받아 본 기억 없네요 급하면 어플 써요 할인 쿠폰 혜택 이벤트 는 꾸준히 해서 좋음 상 큰 할인 은 등급 혜택 쿠폰 쓸 많아요 판매 상품 전혀 걸 판매 쇼핑몰 관리 필요할 듯 에이 블리 믿지만 ;,- 검색 알고리즘 엉망 색깔 맞춰서 검색 색깔 이랑 상관 없는 제품 절반 - 리뷰 제품 관련 없는 인터넷 짤방 많음 검토 리뷰 등록 한다면서 제대로 검토 듯 - 최근 며칠 검색 해서 보고 있는데 갑자기 오류 라면 서 새로고침 라고 뜨고 먹통 잦음 열심히 여러가지 옵션 골 라서 검색 해 놨더 니 하루 대여섯 씩 이러니까 제대로 제품 볼 수가 없 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.morphs(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'사용': 969,
#  '있었는데': 82,
#  '리뷰': 1009,
#  '사진': 418,
#  '업로드': 19,
#  '돼요': 126,
#  '문의': 473,
#  '해봤는데': 64,
#  '지우고': 27,
#  '깔라': 1,
#  '업데이트': 175,
#  '반복': 33,
#  '어쩔': 21,
#  '는': 1389,
#  '될': 63,
#  '있는데': 177,
#  '상황': 40,
#  '은': 1761,
#  '10': 102,
#  '2': 303,
#  '없어요': 162,
#  '싶어도': 24,
#  '돼서': 85,
#  '너무': 3359,
#  '짜증납니다': 10,
#  '계속': 550,
#  '휴대폰': 37,
#  '데이터': 45,
#  '최신': 22,
#  '버전': 13,
#  ',': 20554,
#  '쓰면서': 8,
#  '느낀': 2,
#  '아쉬운': 66,
#  '3': 178,
#  '써': 168,
#  '볼게요': 8,
#  '!': 25,
#  '1': 384,
#  '쓰다': 7,
#  '보니': 128,
#  '원래': 150,
#  '가격': 1221,
#  '에다가': 49,
#  '3000원': 38,
#  '붙여놓고': 2,
#  '무료': 1784,
#  '배송': 3258,
#  '이라': 500,
#  '쓰는거였어요': 1,
#  '옷': 4655,
#  '인기': 66,
#  '순': 99,
#  '설정': 151,
#  '많이': 971,
#  '팔린': 3,
#  '순이': 11,
#  '아니고': 124,
#  '시스템': 81,
#  '덜': 14,
#  '띄워줘요': 1,
#  '구매': 1130,
#  '횟수': 3,
#  '적은': 9,
#  '보여줘': 1,
#  '야하는건': 2,
#  '이해': 57,
#  '이럴거면': 25,
#  '버튼': 110,
#  '있는거죠': 4,
#  '첫': 181,
#  '990원': 138,
#  '이벤트': 610,
#  '아무': 110,
#  '없이': 156,
#  '없어져서': 8,
#  '아쉬워요': 52,
#  'ㅜㅠ': 28,
#  '환불': 479,
#  '처리': 212,
#  '느립니다': 11,
#  '이건': 87,
#  '에이': 1759,
#  '블리': 1537,
#  '마켓': 458,
#  '쇼핑몰': 668,
#  '같은데': 93,
#  '이틀': 47,
#  '만에': 66,
#  '완료': 94,
#  '제품': 677,
#  '있지만': 59,
#  '취소': 566,
#  '일주일': 161,
#  '넘게': 96,
#  '걸리는': 19,
#  '있습니다': 221,
#  '학생': 101,
#  '돈': 328,
#  '넉넉하지': 2,
#  '않아서': 55,
#  '빨리': 296,
#  '들어오면': 12,
#  '살아야': 1,
#  '됩니다': 64,
#  '교환': 129,
#  '이미': 137,
#  '상품': 2177,
#  '받고': 124,
#  '반품': 221,
#  '거': 917,
#  '면': 427,
#  '달이': 15,
#  '넘어도': 5,
#  '하겠는데': 9,
#  '아직': 235,
#  '했고': 21,
#  '준비': 151,
#  '중이': 61,
#  '라고': 252,
#  '뜨면서': 24,
#  '주일': 24,
#  '지나도록': 7,
#  '오는': 58,
#  '하겠다는데': 2,
#  '느리네요': 27,
#  '기다리라고만': 4,
#  '좋은': 1041,
#  '앱': 1862,
#  '가장': 111,
#  '큰': 117,
#  '단점': 101,
#  '인형': 6,
#  '또는': 17,
#  '키링': 10,
#  '자잘한': 4,
#  '악세사리': 72,
#  '검색': 448,
#  '했을': 49,
#  '나오는': 34,
#  '대부분': 81,
#  '가짜': 5,
#  '라는': 162,
#  '죠': 195,
#  '일반': 23,
#  '선택': 232,
#  '할인': 631,
#  '적용': 98,
#  '되지': 65,
#  '않은': 64,
#  '적어야': 3,
#  '한다고': 47,
#  '합니다': 359,
#  '보이는': 22,
#  '실제': 47,
#  '탭': 23,
#  '볼': 275,
#  '있는': 391,
#  '다릅니다': 1,
#  '개당': 3,
#  '5000원': 29,
#  '시': 142,
#  '4000원': 5,
#  '(': 184,
#  '총': 15,
#  '8000원': 6,
#  ')': 160,
#  '행사': 36,
#  '진행중': 22,
#  '라면': 40,
#  '대표': 5,
#  '당연히': 14,
#  '이어야': 1,
#  '이라고': 265,
#  '표시': 57,
#  '한다는': 32,
#  '겁니다': 25,
#  '낱개': 1,
#  '로만': 24,
#  '싶을': 18,
#  '땐': 30,
#  '들어가서': 77,
#  '확인': 276,
#  '해야': 162,
#  '굉장히': 48,
#  '불편합니다': 44,
#  '몇몇': 25,
#  '브랜드': 121,
#  '에서만': 31,
#  '아닌': 60,
#  '식': 75,
#  '있기': 3,
#  '어플': 621,
#  '자체': 182,
#  '방식': 32,
#  '바꿔주셨으면': 3,
#  '좋겠습니다': 119,
#  '4900원': 1,
#  '적어놨는데': 2,
#  '막상': 37,
#  '고르면': 9,
#  '진짜': 1363,
#  '만원': 63,
#  '넘고': 2,
#  '이러네요': 6,
#  '옵션': 75,
#  '추가': 251,
#  '게': 519,
#  '없는데': 71,
#  '적어놓은': 3,
#  '쇼핑': 914,
#  '불편해요': 137,
#  '얼': 7,
#  '일일이': 21,
#  '클릭': 58,
#  '되니': 19,
#  '타': 76,
#  '보다': 467,
#  '직관': 6,
#  '이지': 18,
#  '힘': 4,
#  '들어요': 158,
#  '블': 213,
#  '리가': 129,
#  '유명해서': 2,
#  '필요한거': 5,
#  '사려': 75,
#  '깔았는데': 77,
#  '마다': 220,
#  '지웠어요': 4,
#  '부분': 119,
#  '해결': 97,
#  '되면': 97,
#  '좋을': 74,
#  '같아요': 906,
#  '하고있는데': 10,
#  '되었으면': 40,
#  '좋겠어요': 480,
#  '첫째': 1,
#  '장바구니': 204,
#  '담아놓는': 1,
#  '사용자': 48,
#  '로서': 7,
#  '명칭': 1,
#  '찾을수': 14,
#  '있게': 118,
#  '기능': 426,
#  '생기': 48,
#  '일일': 17,
#  '히': 50,
#  '스': 70,
#  '크롤': 66,
#  '내려서': 8,
#  '찾는게': 9,
#  '힘들어요': 39,
#  '둘째': 6,
#  '지그재그': 93,
#  '처럼': 111,
#  '해당': 34,
#  '들어가면': 112,
#  '카테고리': 191,
#  '아우': 14,
#  '터': 23,
#  '스커트': 7,
#  '상의': 50,
#  '세부': 16,
#  '나눠서': 8,
#  '볼수있는': 7,
#  '생겼음': 7,
#  '에도': 123,
#  '패딩': 5,
#  '롱': 13,
#  '코트': 22,
#  '숏': 2,
#  '조끼': 2,
#  '자켓': 15,
#  '집업': 7,
#  '가디건': 16,
#  '종류': 222,
#  '별로': 366,
#  '볼수있게': 10,
#  '해주세요': 315,
#  'ㅠ': 410,
#  '들어': 75,
#  '으로만': 17,
#  '보고싶은데': 16,
#  '뜨니까': 10,
#  '찾아': 23,
#  '보기': 363,
#  '힘들고': 9,
#  '개선': 145,
#  '입장': 27,
#  '편하게': 119,
#  '이용': 602,
#  '할수있을거': 2,
#  '잘쓰고있습니다': 14,
#  '6년': 1,
#  '째': 112,
#  '인데': 434,
#  '예전': 80,
#  '에는': 185,
#  '그랬는데': 15,
#  '서는': 11,
#  '오래': 95,
#  "'": 107,
#  '오류': 246,
#  '발생': 27,
#  '새로고침': 42,
#  '페이지': 113,
#  '보던게': 1,
#  '날아가요': 1,
#  'ㆍㆍ': 1,
#  '살때': 72,
#  '한번': 375,
#  '다': 1926,
#  '누르면서': 1,
#  '살펴보는데': 1,
#  '봐도': 43,
#  '렉': 120,
#  '걸걸': 1,
#  '리다': 6,
#  '창': 132,
#  '보던': 10,
#  '있는데까지': 1,
#  '내려가야되': 1,
#  '고': 15,
#  '하는게': 96,
#  '않고있습니다': 1,
#  '다양하고': 166,
#  '포인트': 319,
#  '모으는': 1,
#  '방법': 87,
#  '여러가지': 144,
#  '광고': 257,
#  '나옵니다': 8,
#  '쿠폰': 1311,
#  '주고': 102,
#  '싸고': 266,
#  '질도': 30,
#  '많아서': 681,
#  '했습니다': 72,
#  '추천': 405,
#  '저가': 16,
#  '으로도': 139,
#  '있고': 289,
#  '키': 254,
#  '나이': 46,
#  '컬러': 10,
#  '디자인': 167,
#  '디': 16,
#  '테일로': 1,
#  '기준': 38,
#  '나눠': 6,
#  '있어서': 694,
#  '좋았어요': 115,
#  '기장': 16,
#  '사이': 29,
#  '즈': 33,
#  '생겼으면': 41,
#  '해서': 752,
#  '나오거나': 4,
#  '나오지': 9,
#  '않게': 15,
#  '정말': 838,
#  '감사할': 4,
#  '같습니다': 98,
#  '비교': 258,
#  '하며': 24,
#  '합리': 23,
#  '좋습니다': 378,
#  '1:1': 8,
#  '오더': 2,
#  '해외': 35,
#  '정확한': 11,
#  '기간': 82,
#  '유추': 3,
#  '어려워': 6,
#  '기다림': 2,
#  '길어질': 1,
#  '여러': 338,
#  '적립': 26,
#  '급할': 5,
#  '마음': 295,
#  '드는': 65,
#  '쓱': 3,
#  '불가하더라구요': 1,
#  '다양하게': 93,
#  '늘어났으면': 2,
#  '쓰고': 220,
#  '있어요': 395,
#  '근데': 456,
#  '결제': 846,
#  '발견': 15,
#  '네이버': 95,
#  '페이': 53,
#  '코': 18,
#  '진행': 48,
#  '도합': 2,
#  '니': 193,
#  '인증': 140,
#  '끝난': 1,
#  '나온': 13,
#  '메시지': 5,
#  '정지': 2,
#  '된': 256,
#  '카드': 98,
#  '라서': 154,
#  '실패했다': 3,
#  '떠요': 94,
#  '정상': 25,
#  '맞기': 1,
#  '에러': 17,
#  '잘못': 68,
#  '되었어요': 14,
#  '맞게': 38,
#  '수단': 22,
#  '하도록': 9,
#  '구현': 1,
#  '처음': 363,
#  '막아야': 3,
#  '!!!,': 162,
#  '좋은데': 641,
#  '필터': 120,
#  '빼는': 3,
#  '?': 1150,
#  '넣어주셨으면': 5,
#  '버클': 2,
#  '싫어하는데': 1,
#  '없게': 16,
#  '했으면': 44,
#  'ㅠㅜ': 51,
#  '가로': 16,
#  '볼수있어야': 1,
#  '좀더': 32,
#  '재질': 43,
#  '퀄리티': 97,
#  '추측': 1,
#  '할수있는데': 1,
#  '율': 18,
#  '높고': 8,
#  '대': 168,
#  '조정': 11,
#  '원하는': 235,
#  '보일수있어서': 1,
#  '에요': 162,
#  '최근': 69,
#  '서칭': 2,
#  '하다가도': 2,
#  '되었다는': 5,
#  '문구': 29,
#  '초기': 30,
#  '화면': 134,
#  '돌아가지네요': 1,
#  '서': 592,
#  '칭': 5,
#  '하던': 16,
#  '걸': 173,
#  '찾아야하구요': 1,
#  '기본': 80,
#  '나와있는': 5,
#  '이랑': 207,
#  '하려고': 172,
#  '차이': 21,
#  '나면': 11,
#  '기분': 115,
#  '부탁드립니다': 66,
#  '쉽고': 106,
#  '대가': 25,
#  '낮은': 10,
#  '봐서': 22,
#  '유용하게': 46,
#  '있는만큼': 2,
#  '실망': 58,
#  '스러운': 6,
#  '메인': 16,
#  '판매': 270,
#  '소비자': 72,
#  '율과': 1,
#  '싼': 64,
#  '어필': 1,
#  '있겠지만': 8,
#  '예요': 105,
#  '하니까': 67,
#  '달라': 51,
#  '실망하고': 2,
#  '같아서': 52,
#  '해': 413,
#  '보면서': 24,
#  '따로': 89,
#  '하려니까': 24,
#  '대만': 5,
#  '수도': 48,
#  '소비': 15,
#  '되더라고요': 6,
#  '측': 50,
#  '해주시': 102,
#  '안녕하세요': 40,
#  '요즘': 219,
#  '좋아하고': 7,
#  '재밌게': 9,
#  '사는': 66,
#  '모든': 143,
#  '좋고': 427,
#  '재': 80,
#  '이쁜': 727,
#  '좋긴': 33,
#  '가해': 2,
#  '주길': 1,
#  '조이스틱': 2,
#  '움직': 3,
#  '여서': 145,
#  '어렵네요': 10,
#  '말고': 64,
#  '타자': 1,
#  '쳐서': 8,
#  '편리할': 4,
#  '같네요': 127,
#  '이점': 11,
#  '고쳐주시면': 21,
#  '다른건': 65,
#  '건': 172,
#  '입고': 73,
#  '있고요': 20,
#  '허리': 16,
#  '얇으면': 1,
#  '입': 76,
#  '바지': 77,
#  '한정': 9,
#  '된다는': 21,
#  '정장': 2,
#  '느낌': 84,
#  '찾고': 29,
#  '해보는데': 14,
#  '젤': 55,
#  '작은': 39,
#  '29': 3,
#  '나오네요': 26,
#  '뿐': 49,
#  '몸무게': 53,
#  '넣어주시면': 12,
#  '찾기': 273,
#  '편할': 8,
#  '모델': 77,
#  '분': 192,
#  '샀는데도': 3,
#  '많습니다': 29,
#  '크게': 26,
#  '불편한': 46,
#  '한가지': 31,
#  '뜨는': 42,
#  '알고리즘': 22,
#  '극단': 3,
#  '랄': 7,
#  '까요': 18,
#  '귀': 8,
#  '뚫어서': 1,
#  '귀걸이': 12,
#  '관심': 56,
#  '없는': 261,
#  '어쩌다': 6,
#  '실수': 42,
#  '눌렀다치면': 1,
#  '뒤': 130,
#  '장창': 8,
#  '도배': 13,
#  '관련': 94,
#  '입니다를': 1,
#  '50': 14,
#  '눌러도': 29,
#  '뜰': 4,
#  '자꾸': 202,
#  '이러니까': 7,
#  '뭐': 378,
#  '눌러': 13,
#  '겁나네요': 1,
#  '망할까봐': 2,
#  ';,': 44,
#  '제일': 119,
#  '짜잉나는점': 1,
#  '보다가': 13,
#  '내리거나': 2,
#  '돌아가는': 2,
#  '불편해서': 13,
#  '삭제': 262,
#  '쓰다가': 30,
#  '됐나': 4,
#  '싶어서': 34,
#  '설치': 131,
#  'ㅠㅠㅠㅠ': 39,
#  '이력': 2,
#  '없으면': 39,
#  '등급': 133,
#  '낮아지는': 1,
#  '그래요': 40,
#  '🤨🤔': 1,
#  '올라가는데': 1,
#  '라면서': 4,
#  '게이지': 1,
#  '서서히': 3,
#  '깎이면서': 1,
#  '낮아졌더라고요': 1,
#  '달': 124,
#  '했다가': 35,
#  '깜짝': 5,
#  '놀람': 2,
#  '설명': 92,
#  '엄청': 204,
#  '아쉬움': 14,
#  '😮\u200d💨': 1,
#  '사이즈': 290,
#  '별': 282,
#  '하여': 30,
#  '몰아서': 4,
#  '됐던데': 1,
#  '아주': 231,
#  '칭찬': 15,
#  '함': 196,
#  '강점': 7,
#  '이긴': 12,
#  '했음': 17,
#  '다르지만': 6,
#  '빠르면': 14,
#  '3일': 79,
#  '늦으면': 9,
#  '4': 84,
#  '14일': 4,
#  '봄': 42,
#  '재고': 112,
#  '부족': 8,
#  '포함': 52,
#  '미리': 40,
#  '안내': 47,
#  '문자': 108,
#  '보내주느냐': 1,
#  '시작': 66,
#  '택배': 147,
#  '늦어': 3,
#  '늦게': 62,
#  '받은': 43,
#  '있음': 83,
#  '솔직히': 69,
#  '샥': 85,
#  '-': 40,
#  '출발': 79,
#  '주문': 761,
#  '받아': 90,
#  '본': 75,
#  '기억': 12,
#  '없네요': 174,
#  '급하면': 1,
#  '써요': 31,
#  '혜택': 109,
#  '꾸준히': 11,
#  '좋음': 439,
#  '상': 31,
#  '쓸': 121,
#  '많아요': 540,
#  '전혀': 57,
#  '관리': 118,
#  '필요할': 10,
#  '듯': 117,
#  '믿지만': 1,
#  ';,-': 1,
#  '엉망': 23,
#  '색깔': 35,
#  '맞춰서': 23,
#  '상관': 9,
#  '절반': 2,
#  '인터넷': 121,
#  '짤방': 1,
#  '많음': 97,
#  '검토': 6,
#  '등록': 59,
#  '한다면서': 3,
#  '제대로': 135,
#  '며칠': 66,
#  '보고': 329,
#  '갑자기': 220,
#  '뜨고': 157,
#  '먹통': 10,
#  '잦음': 1,
#  '열심히': 29,
#  '골': 26,
#  '놨더': 1,
#  '하루': 127,
#  '대여섯': 1,
#  '씩': 125,
#  '수가': 64,
#  '없음': 119,
#  '막대기': 1,
#  '좌우': 3,
#  '가끔': 131,
#  '100만': 1,
#  '가까이': 18,
#  '결과': 25,
#  '섞여': 3,
#  '있으면': 179,
#  '맞추기': 3,
#  '어려워짐': 2,
#  '숫자': 6,
#  '입력': 118,
#  '가능하게': 23,
#  '바뀌었으면': 5,
#  '보려고': 30,
#  '상세': 150,
#  '댓글': 36,
#  '그냥': 379,
#  '썸네일': 2,
#  '보이구요': 3,
#  '안되구요': 3,
#  '로딩': 90,
#  '있지': 16,
#  '세': 182,
#  '알려줄': 1,
#  '새': 29,
#  '들어가지지가': 4,
#  '않아요': 73,
#  '버그': 35,
#  '수정': 134,
#  '맞나요': 11,
#  '?,': 351,
#  'vvip': 6,
#  '찍었는데요': 1,
#  '그만큼': 25,
#  '샀어요': 38,
#  '이유': 89,
#  '량': 3,
#  '보유': 2,
#  '그런거였어요': 1,
#  '지급': 21,
#  '강제': 17,
#  '100': 24,
#  '찍으면서': 1,
#  '없을거': 2,
#  '욕구': 5,
#  '올려주기도': 1,
#  '이득': 19,
#  '많다고': 16,
#  '체계': 4,
#  '버리시면': 1,
#  '하락': 1,
#  '눈': 75,
#  '보이겠죠': 1,
#  '리만': 40,
#  '짱': 441,
#  '됐으면': 31,
#  '찜': 231,
#  '서랍': 88,
#  '조합': 3,
#  '모아놓을': 1,
#  '코디': 39,
#  '현재': 22,
#  '없어서': 244,
#  '새로': 40,
#  '만들어서': 17,
#  '저장': 17,
#  '있기는': 1,
#  '담': 8,
#  '꼭': 163,
#  '2020년': 3,
#  '즈음': 1,
#  '인가': 41,
#  '했던': 32,
#  '유저': 45,
#  '2024년': 1,
#  '썼고': 2,
#  '그러고': 21,
#  '싶은': 50,
#  '익숙해져': 1,
#  '둘러보기': 3,
#  '힘들': 5,
#  '물들': 1,
#  '여지': 2,
#  '든': 46,
#  '에겐': 12,
#  '소중한': 2,
#  '이에요': 282,
#  '가성': 180,
#  '비도': 36,
#  '많아': 119,
#  '자주': 442,
#  '애용': 184,
#  '늘어나기': 1,
#  '간략하게': 1,
#  '적어': 15,
#  '봅니다': 20,
#  '뜬': 7,
#  '납니다': 14,
#  '한다길래': 3,
#  '들어가': 73,
#  '봤더니': 21,
#  '7900원': 2,
#  '한다던지': 2,
#  '솔직한': 5,
#  '주셨으면': 19,
#  '우측': 4,
#  '하단': 16,
#  '보입니다': 12,
#  '주의': 6,
#  '사항': 34,
#  '달라는데': 2,
#  '없어': 47,
#  '날려': 3,
#  '먹은': 2,
#  '아닙니다': 14,
#  '억울하지만': 1,
#  '참고': 45,
#  '넘어간': 1,
#  '아니어야': 1,
#  '하는데': 298,
#  '넘어': 9,
#  '이네': 177,
#  '제발': 242,
#  '그대로': 54,
#  '고정': 7,
#  '시켜주세요': 11,
#  '가기': 27,
#  '터치': 32,
#  '싹': 16,
#  '화': 37,
#  '44': 9,
#  '55': 6,
#  '66': 6,
#  'FREE': 3,
#  '44~66': 1,
#  '77': 7,
#  '88': 2,
#  '해주시길': 12,
#  '부탁드리고': 2,
#  '프리': 23,
#  '위': 52,
#  '변질': 1,
#  '되어서': 32,
#  '고쳐주셨음': 2,
#  '하고요': 14,
#  '신발': 58,
#  '하려니': 13,
#  '불편한데': 2,
#  '고쳐주세요': 111,
#  '만큼이나': 2,
#  '점도': 33,
#  '많네요': 181,
#  '다양한': 300,
#  '물이': 4,
#  '찾아보기': 12,
#  '구성': 23,
#  '되있는': 6,
#  '이라서': 119,
#  '편리합니다': 30,
#  '위해': 34,
#  '거기': 73,
#  '여름': 30,
#  '가을': 11,
#  '겨울': 18,
#  '사계절': 2,
#  '중구': 2,
#  '난방': 2,
#  '있으니까': 22,
#  '힘들더라고요': 4,
#  '계절': 36,
#  '감': 19,
#  '적혀있으니까': 1,
#  '입으면': 7,
#  '적당한지': 1,
#  '추': 12,
#  '운지': 1,
#  '더운지': 1,
#  '모르겠으니': 1,
#  '좋아요': 5723,
#  '예쁜': 580,
#  '많고': 672,
#  '있죠': 5,
#  '그게': 60,
#  '원피스': 55,
#  '폰': 288,
#  '케이스': 294,
#  '뜨네요': 109,
#  ';;': 172,
#  '일부러': 16,
#  '섞어서': 1,
#  '될것': 10,
#  '나쁘지': 43,
#  '뭘': 60,
#  '해본': 6,
#  '최대': 35,
#  '장점': 111,
#  '들이고요': 1,
#  '아이돌': 24,
#  '사진이거나': 1,
#  '짤': 14,
#  '올리시는': 6,
#  '이면': 32,
#  '"': 57,
#  '반': 47,
#  '있거든요': 6,
#  '에게는': 15,
#  '않는': 52,
#  '같더라구요': 4,
#  '진': 17,
#  '모르겠지만': 38,
#  '업뎃': 27,
#  '그건': 27,
#  '달라지지': 1,
#  '에서는': 66,
#  '방해': 7,
#  '버려서': 9,
#  '인거': 78,
#  '꼼꼼하게': 5,
#  '좋겠네요': 114,
#  '굿': 886,
#  '뜨': 18,
#  '👍': 230,
#  ',,,': 32,
#  '할수': 152,
#  '되어있으면': 5,
#  '좋을거': 52,
#  ',,,,': 22,
#  'ㅜㅠㅜㅜ': 1,
#  '간절합니다': 3,
#  '그거': 97,
#  '말고는': 14,
#  '무배': 208,
#  '+': 94,
#  '뿌려주고': 3,
#  '구경': 96,
#  '재미': 35,
#  '쏠쏠': 4,
#  '입점': 51,
#  '가는줄': 5,
#  '모르고': 19,
#  '품명': 1,
#  '몰라서': 15,
#  '못': 785,
#  '존재': 10,
#  '넘': 499,
#  '아쉽고': 6,
#  '간절한': 1,
#  '패션': 31,
#  '용어': 1,
#  '그걸': 22,
#  '외우기엔': 1,
#  '버겁고': 1,
#  '검색어': 17,
#  '로는': 24,
#  '않나': 22,
#  '듭': 40,
#  '임팩트': 2,
#  '떨어지는': 6,
#  '추세': 1,
#  '옷값': 3,
#  '비': 218,
#  '하는지': 31,
#  '많더라고요': 7,
#  '사이트': 172,
#  '붙여서': 4,
#  '파는': 54,
#  '봤구요': 1,
#  '모아': 63,
#  '본다는': 2,
#  '괜찮게': 4,
#  '요구': 5,
#  '차단': 40,
#  '즐겨찾기': 17,
#  '동대문': 4,
#  '명품': 4,
#  '다는': 9,
#  '꼴': 10,
#  '싫어': 4,
#  '죽겠는데': 4,
#  '피드': 8,
#  '떠서': 121,
#  '모르게': 3,
#  'ably': 5,
#  '끄게': 3,
#  '되네요': 97,
#  '특정': 22,
#  '내력': 1,
#  '평판': 1,
#  '좋지': 19,
#  '카테고라': 1,
#  '이징': 1,
#  '응원': 25,
#  '경험': 13,
#  '고가': 14,
#  '정렬': 23,
#  '사라져서': 7,
#  '이어도': 4,
#  '원단': 12,
#  '독특한': 2,
#  '해봤습니다': 1,
#  '찾거나': 1,
#  '디테일': 8,
#  '하기가': 45,
#  '어렵습니다': 7,
#  '무조건': 73,
#  '저렴한': 99,
#  '사고': 161,
#  '금액': 108,
#  '지불': 5,
#  '비있고': 1,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
