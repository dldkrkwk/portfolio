# %% [markdown]
# # 리뷰 데이터 수집

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.oliveyoung",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST,
                      count=50000)

# %%
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
import numpy as np
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    df.to_csv(f'./data/01.리뷰키워드분석_01통합본_{name}_리뷰크롤링파일.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'올리브영')

# %%
df.sort_values('at',ascending=False)
# Out:
#                                                 content  score  thumbsUpCount  \
# 1199    라이브 방송 나쁨 ㅠㅠ 😭 😢 😥 😭 😢 😥 😭 😢 사람 개무시 ㅡㅡ 😑 😐 😑 ㅠㅠ      1              0
# 198                    앱이 느림 터치를 못 따라옴 그래도 구경하는거 정도는 괞춘      4              0
# 311                                      ui부터 편의성 전부 없음      1              0
# 211   너무너무 불편해요 특히 오늘드림 무료배송 쓰려다가 안되는 상품이랑 가능한 상품 구분...      1              0
# 1384                  3세 이상이라면서 만 14세 미만은 왜 회원가입이 안되는거죠      2              0
# ...                                                 ...    ...            ...
# 1003  비밀번호 바꾸려고해서 인증메일 보냈다더니 메일은 몇시간이 지나도 오질 않고 뭐하자는...      2              8
# 213   어제부터 계속 결제할 때 결제창은 안 뜨고 사용할 앱을 선택하라고 뜨네요 원래는 안...      1             73
# 487   결제창으로 왜 안 넘어가나요?? 결제하기 누르면 사용할 어플리케이션 선택하라고 이상...      2             11
# 337   노트8사용자에요 저번달 출석체크부터 누르면 아무반응 없더니 어제부터 시작한 가을히든...      1              6
# 1813            만3세인데...왜 로그인할때는 14세로 돼어있죠?13세로 해주세요...      1              1
#
#                       at
# 1199 2024-02-19 00:31:18
# 198  2024-02-18 19:05:30
# 311  2024-02-15 11:30:10
# 211  2024-02-13 20:43:36
# 1384 2024-02-12 22:28:57
# ...                  ...
# 1003 2018-09-17 00:14:14
# 213  2018-09-16 11:36:57
# 487  2018-09-15 18:16:23
# 337  2018-09-15 03:50:15
# 1813 2018-09-12 21:45:51
#
# [1990 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1990 entries, 0 to 1989
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        1990 non-null   object
#  1   score          1990 non-null   int64
#  2   thumbsUpCount  1990 non-null   int64
#  3   at             1990 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 62.3+ KB

# %%
df['year'] = df['at'].dt.strftime("%Y")
df
# Out:
#                                                 content  score  thumbsUpCount  \
# 0     앱이 너무 느려요.. 터치 밀려서 다른 거 터치되고, 올영페스타 티켓구매 때는 차라...      1             83
# 1     업데이트 할수록 점점 불편해짐 1. 매거진과 셔터 기능 하등 쓸모없음 -기본 5개 ...      2             51
# 2     7/3 추가: 역시나 느리고 무겁고 그대로... 많은 사용자가 불편을 호소하는 문제...      1            907
# 3     자동로그인되어있는데도 이벤트 참여하려고 할때마다 로그인해야 이용할 수 있다고 계속 ...      1            133
# 4     일단 앱이 너무너무 느려요. 뭔 이벤트 한번하면 사이트 터질거같이 로딩이 엄청 오래...      1            135
# ...                                                 ...    ...            ...
# 1985                                    출석체크가 왜 안되나요?!!      1              2
# 1986                      진짜 어플 개느림 굳이 이럴거면 어플 만든 필요가??      2              1
# 1987                           태블릿 안되는거 나만 그런게 아니구나 ㅋㅋㅋ      1              3
# 1988                                   문의답변이 진짜진짜 개개개느림      2              1
# 1989                                        너무재미있네요^^♡☆      5              0
#
#                       at  year
# 0    2023-12-27 17:23:45  2023
# 1    2024-01-19 09:59:52  2024
# 2    2022-07-03 19:38:39  2022
# 3    2023-09-02 13:27:38  2023
# 4    2022-11-16 15:57:16  2022
# ...                  ...   ...
# 1985 2022-12-11 17:40:08  2022
# 1986 2022-02-28 19:36:20  2022
# 1987 2023-06-16 19:48:09  2023
# 1988 2022-10-01 12:14:15  2022
# 1989 2021-08-16 09:52:11  2021
#
# [1990 rows x 5 columns]

# %%
df.loc[:][df['year']==2022]
# Out:
# Empty DataFrame
# Columns: [content, score, thumbsUpCount, at, year]
# Index: []

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df['content'].isnull().sum()
# Out:
# 0

# %%
print(df.info())
print()
df.dropna(subset='content',axis=0,inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1990 entries, 0 to 1989
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        1990 non-null   object
#  1   score          1990 non-null   int64
#  2   thumbsUpCount  1990 non-null   int64
#  3   at             1990 non-null   datetime64[ns]
#  4   year           1990 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 77.9+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1990 entries, 0 to 1989
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        1990 non-null   object
#  1   score          1990 non-null   int64
#  2   thumbsUpCount  1990 non-null   int64
#  3   at             1990 non-null   datetime64[ns]
#  4   year           1990 non-null   object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 77.9+ KB
# None

# %%
def tokenize(dataFrame):
    okt = Okt()
    
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    dataframe = tokenize(dataFrame)
    dataframe = remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
tokenized = tokenize(df)

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <1990x2355 sparse matrix of type '<class 'numpy.int64'>'
# 	with 14042 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <1990x2355 sparse matrix of type '<class 'numpy.float64'>'
# 	with 14042 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '앱 터치 거 터치 페스 타 티켓 구매 서버 페이지 거 일자 선택 라면 옵션 선택 창 결산 클릭 어플 나이 광고 하루 보지 접속 차로 잘못,업데이트 점점 짐 셔터 기능 하등 기본 기능 셔터 홈 히스토리 마이 아예 공간 낭비 아예 곳 빼 메이크업 세부 분류 립 제품 메이크업 제품 기능 기능,추가 역시 그대로 사용자 불편 호소 척 피드백 반영 의문 앱 로딩 시 광고 대신 젠 앱 진입 차 팝업 광고 실수 클릭 유도 정말 앱 이용 사용자 편의 성은 전혀 고려 채 화면 최대한 상품 행사 노출 집념 올인 젠 화면 터치 터치 일쑤 상하 스크롤 멋대로 좌우 스크롤 빈번 앱 스트레스 앱 첫 화면 오늘 드림 강조 상단 메뉴 리뷰 답변 선택 심플 함 미학 바라지 개선 관심 주시 앱,자동 로그인 이벤트 참여 로그인 이용 계속 로그인 화면 자동 이동 로그인 이동 그냥 아무 이벤트 참여 수가 앱 삭제 진짜 이벤트 참여 계속 시도 화가 자동 로그인 기능 건가,앱 이벤트 한번 사이트 로딩 제품 택배 진짜 박스 아예 박스 정상 직육면체 제품 기스 기본 옵션 택배 절대 오늘 드림 주변 올리브영 려면 가야 진짜 별로,갤럭시 플립 안드로이드 버전 사용 페이지 화면 아래 위로 수가 예전 계속 업데이트 앱 사용 부분 확인 업데이트 메인 이벤트 행사 안내 화면 오른쪽 밑 플러스 버튼 전체 보기 화면 행사 종류 아래 위로 자꾸 새로고침 메인 전체 판매 상품 리뷰 전체 상품 보기 홋수 선택 리뷰 목록 아래 한번 위로 수가 새로고침 제품 처음 화면 여러가지 리뷰,사용 경험 아주 오류 요새 앱 튕기 경험 매우 혜택 다운 혜택 내내 결제 시도 통신 주문 취소 엉망 진창 은 스마트폰 사고 처음 기능 추천,서버 수정 업데이트 사진 첨부 불가 사진 리뷰 크게 참고 기기 갤럭시 노트 평소 사진 리뷰 로딩 이미지 파일 아예 첨부 대체 뭐 사진 리뷰 이하 이미지 파일 첨부 갤러리 사진 파일 용량 약 확인 사진 첨부 재시 확인 와이파이 칸 이어도 일부러 데이터 시도 전혀 로딩 첨부 계속 문의 사진 첨부 네모 첨부 앱 사진 첨부 재차 확인 사진 용량 이하임 갤러리 재차 확인 조속 사진 첨부 오류 바람 수정 재업 문의 답변 관련 내용 확인 중이 함,앱 저번 화면 삭제 로그인 자꾸 서버 오류 와이파이 데이터 어플 며칠 로그인 접속 몇번 삭제,직접 올리브영 쇼핑 정말 덕분 텅 마음 행복 며칠 상품 평 등록 시 사진 첨부 사진 선택 상품 평 사진 버그 힝 포인트,앱 검색 기능 페이지 그냥 계속 검색 홈 뒤 가기 검색 페이지 그대로 뒤 가기 쿠폰 배부 대기 오류 거나 대기 앱 대기 처음 앱 자주 오류 검색 오류 속도 앱 키 제품 검색 분 수정,조건 부 정렬 상품 보고 뒤 가기 정렬 리셋 가장 정렬 의미 물건 볼때 정렬 위 앱 오류 버그 신고 기능 리뷰 구글 리뷰 아무 오류 외 크게 신경,정렬순서 변경 상품 상세 보기 뒤 가면 정렬순서 리셋 앱 자체 뒤 가기 버튼 설정 유지 휴대폰 뒤 가기 사용 리셋 광고 위치 상품 클릭 갑자기 위치 광고 진짜 어플,상품 한눈 볼 매우 오늘 드림 직접 제품 주문 혼동 주문 확인 추가 증정 제품 간 고객 센터 대응 행사 상품 매장 정가 어플 할인 가로 팔고 손 기분 통일 해 살짝 버벅이는 모든 화면 사진 로딩 여러 상품 사용,앱 기능 서비스 개선 불량 제품 교환 세번 불량 수령 확인 재 배송 과정 고객 센터 통화량 연결 한참 앱 직관 이진 교환 신청 진행 단계 확인,처음 어플 실행 전면 광고 건 이해 이해 감 유튭 컨텐츠 이용 애초 돈 어플 풀 화면 팝업 광고 초 광고 창 자동 게 초 팝업창 자동 광고 역대 신 시스템 정말 정말 정말 제발 해 올리브영 어플 아예 어플,페이지 리다 화면 보고 상품 아예 프레임 밖 데이터 메인 화면 어플 접속 난리 당사 큐 레이 팅 광고 보고 어플 광고 뿜뿜 데이터 간소화 광고 축소 듯 쇼핑몰 소비자 신경 몰래 몰래 광고 올리브영 댕청 미가 배짱 장사 려 장바구니 클릭 자꾸 선택 란 이동해 광고 페이지 의도 거 기분 의도 거 어플 개선,물건 한눈 탑 리뷰 순위도 체험 단 이벤트 참가 거 라면 최근 검색어 한번 중간 한번 랙 외,주전 앱 라운드 서버 진짜 앱 완전 종료 흐름 완전 업데이트 폰 갤럭시 노트 데이터 환경 매우 어플 얼른,해당 앱 사용 뒤 앱 스마트폰 인터넷 연결 문구 뒤 가기 앱 앱 강제 종료 상품 설명 구매 정보 리뷰 칸 리뷰 칸 맨 위 리뷰 위치 곳 볼 개선,지난달 화면 접속 접속 로그인 계속 하라 고함 안내 창 그냥 장바구니 로그인 창 계속 뜸 오프라인 온라인 영만 사용 덕분 처음 롭스 어플,앱 오류 시일 구매 앱 접속 홈 화면 정상 카테고리 검색 창 장바구니 제대로 화면 이틀 꼴 오류 식 앱 이용 어플 존재 의미 이벤트 위 언급 부분 수정 이벤트 진행,방 요즘 버퍼링 심해 신상 방송 화면 크게 음소거 해제 계속 음소거 댓글 답변 리뷰 사진 여러 첨부 씩 첨부 은 거 킹 앨범 별로 볼 수도 사진,진짜 장난 이전 리뷰 앱 서버 현상 관리자 뭐 연결 여러 버튼 가까이 속도 배송비 조회 오류 처음 문서 작성 주문 앱 전용 쿠폰 주지 통한 온라인 잘만 거기 앱 전용 쿠폰 사용 앱 의도 사용자 사용자 최소한 서버 구축 낭비 밤 결제 도중 오류 통장 돈 주문 뭐 겁 앱 서버 증설 처리 속도 하든 고객 대한 준비 고객 마케팅,앱 자체 사용 매우 뿐 장바구니 구매 구매 창 계속 오류 부분 장바구니 클릭 인식 부분 로드 앱 비교 도저히 사용 삭제 문제점 리뷰 지속 제기 개선 실망,어플 반응속도 제품 상세 페이지 스 크롤 걸 옆 스 와이프 인식 리뷰 창 감 모션 식이 제대로 앱 팝업 광고 광고 이후 앱 반응속도 엉망 느낌,앱 무거워 뭐 잘못 원래 페이지 앱 후기 프리징 스토어 앱 빡종하 경험 최적화,계정 휴면 상태 여서 로그인 로그인 카카오 톡 카카오 톡 로그인 버튼 몇번 화면 계속 화면 상태 와이파이 앱 오류,화면 스 크롤 갑자기 현상 처음 경험 일이,업데이트 이후 화면 로딩 아예 흰색 로딩 화면 계속 이벤트 서버 아예 로딩 자체 상품 확인 처음 수정,중순 앱 포토 리뷰 문의 사진 안드로이드 갤럭시 플러스 사진 사진첩 구글 변경 대체 올리브영 앱 사진 고객 센터 차례 문의 테스트,구매 단계 픽업 주문 분리 오프라인 매장 재고 온라인 품절 장바구니 못 하니 픽업 구매 아예,상품 구매 방법 선택 오늘 드림 서비스 이용 상품 대다수 직접 픽업 서비스 이용 매장 올리브영 예전 자주 사용 사용 미사 홍보 기대 사용 혜택 가격 메리트 서비스 메리트 올리브영 설치 구입 상품 가격 메리트 쿠팡 이용 나은 선택 듯해,오늘 드림 서비스 공동 현관 출입 방법 현관 비밀번호 입력 영수증 비밀번호 건 뭔가 처음 기사 못 영수증,피부 케어 화장품 주문 볼때 렉 재부팅 해,가입 서버 맛 페이지 이벤트 제대로 준비 서버 확장 조치 시스템 구축 열 가입,최근 업데이트 건의 부분 꽤 반영 된거 검색 올리브영 배송 필터 링 기능 생기,우먼 케어 저번 오류 업데이트 계속 사용 못 네트워크 문구 계속 도대체 사용,앱 포인트 적립 위 광고 보기 버튼 올리브영 앱 강제 연결 매우 올리브영 앱 삭제,케어 캘린더 계속 해결 네트워크 연결 상태 확인 데이터,배송 영업일 영업일 배송 준비 취소 반품 수수료 거 올리브영 중국 직구 회사 서비스 탈회 예정 구매,몇번 로그인 시도 아이디 비번 아이디 비밀번호 재발 계속 번은 시도 듯 거 건가 비번 제대로 입력 계속 확인 로그인 비번 아이디 일치 자꾸 오류 라면,순서 순서 계속 앱 강제 종료 강제 종료 순서 거 트래픽 감당 서버,평소 업데이트 이후 이벤트 참여 오류 방 이벤트 이벤트 마감 체험 단 오류 새로고침 어플 신청 제품 목록 걸 뭐 신청 핸드폰 기 어플 전혀 부분 개선 요즘 이벤트 업데이트 할인 기간 표시 별로 업데이트 건 은,올리브영 신상 뭐 고객 앱 업데이트 상품 코너,카드 계좌 입력 자꾸 정보 입력 확인 계좌 카드 입력 입력,표시 걸 최근 상품 탭 이건 오륜,앱 업데이트 아예 리지 로그인 화면 수정,검색 예전 검색 앱 짐 밑 메뉴,로그인 분명 아이디 비번 계속 비번,제품 페이지 오류 제품 구매 차질,내내 앱 먹통 수가 특정 날짜 특정시 제품 검색 상품 못 보고 제대로 건 광고 팝업 이쯤 사지 눈치 사려 거 앱 포인트 소진하 그냥 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'앱': 842,
#  '터치': 67,
#  '거': 159,
#  '페스': 1,
#  '타': 7,
#  '티켓': 1,
#  '구매': 190,
#  '서버': 84,
#  '페이지': 106,
#  '일자': 1,
#  '선택': 67,
#  '라면': 13,
#  '옵션': 15,
#  '창': 98,
#  '결산': 1,
#  '클릭': 58,
#  '어플': 369,
#  '나이': 7,
#  '광고': 124,
#  '하루': 14,
#  '보지': 8,
#  '접속': 109,
#  '차로': 1,
#  '잘못': 21,
#  '업데이트': 174,
#  '점점': 10,
#  '짐': 8,
#  '셔터': 3,
#  '기능': 56,
#  '하등': 1,
#  '기본': 22,
#  '홈': 34,
#  '히스토리': 1,
#  '마이': 26,
#  '아예': 47,
#  '공간': 2,
#  '낭비': 5,
#  '곳': 40,
#  '빼': 1,
#  '메이크업': 2,
#  '세부': 1,
#  '분류': 1,
#  '립': 1,
#  '제품': 153,
#  '추가': 35,
#  '역시': 4,
#  '그대로': 12,
#  '사용자': 35,
#  '불편': 16,
#  '호소': 1,
#  '척': 3,
#  '피드백': 3,
#  '반영': 5,
#  '의문': 8,
#  '로딩': 73,
#  '시': 33,
#  '대신': 2,
#  '젠': 15,
#  '진입': 3,
#  '차': 3,
#  '팝업': 25,
#  '실수': 5,
#  '유도': 7,
#  '정말': 49,
#  '이용': 73,
#  '편의': 9,
#  '성은': 1,
#  '전혀': 22,
#  '고려': 2,
#  '채': 5,
#  '화면': 199,
#  '최대한': 1,
#  '상품': 171,
#  '행사': 28,
#  '노출': 3,
#  '집념': 1,
#  '올인': 1,
#  '일쑤': 2,
#  '상하': 1,
#  '스': 52,
#  '크롤': 44,
#  '멋대로': 12,
#  '좌우': 2,
#  '빈번': 3,
#  '스트레스': 9,
#  '첫': 10,
#  '오늘': 178,
#  '드림': 125,
#  '강조': 2,
#  '상단': 7,
#  '메뉴': 17,
#  '리뷰': 239,
#  '답변': 42,
#  '심플': 1,
#  '함': 58,
#  '미학': 1,
#  '바라지': 2,
#  '개선': 140,
#  '관심': 3,
#  '주시': 4,
#  '자동': 32,
#  '로그인': 385,
#  '이벤트': 104,
#  '참여': 13,
#  '계속': 216,
#  '이동': 18,
#  '그냥': 125,
#  '아무': 16,
#  '수가': 45,
#  '삭제': 84,
#  '진짜': 255,
#  '시도': 36,
#  '화가': 17,
#  '건가': 41,
#  '한번': 40,
#  '사이트': 22,
#  '택배': 24,
#  '박스': 8,
#  '정상': 18,
#  '직육면체': 1,
#  '기스': 1,
#  '절대': 13,
#  '주변': 2,
#  '올리브영': 163,
#  '려면': 1,
#  '가야': 5,
#  '별로': 33,
#  '갤럭시': 13,
#  '플립': 5,
#  '안드로이드': 9,
#  '버전': 17,
#  '사용': 178,
#  '아래': 9,
#  '위로': 7,
#  '예전': 17,
#  '부분': 21,
#  '확인': 87,
#  '메인': 35,
#  '안내': 22,
#  '오른쪽': 1,
#  '밑': 21,
#  '플러스': 5,
#  '버튼': 64,
#  '전체': 15,
#  '보기': 31,
#  '종류': 6,
#  '자꾸': 112,
#  '새로고침': 29,
#  '판매': 14,
#  '홋수': 1,
#  '목록': 12,
#  '처음': 82,
#  '여러가지': 6,
#  '경험': 10,
#  '아주': 11,
#  '오류': 160,
#  '요새': 3,
#  '튕기': 23,
#  '매우': 22,
#  '혜택': 17,
#  '다운': 35,
#  '내내': 4,
#  '결제': 209,
#  '통신': 3,
#  '주문': 117,
#  '취소': 54,
#  '엉망': 11,
#  '진창': 1,
#  '은': 8,
#  '스마트폰': 7,
#  '사고': 13,
#  '추천': 12,
#  '수정': 29,
#  '사진': 53,
#  '첨부': 24,
#  '불가': 11,
#  '크게': 4,
#  '참고': 9,
#  '기기': 2,
#  '노트': 13,
#  '평소': 15,
#  '이미지': 6,
#  '파일': 3,
#  '대체': 26,
#  '뭐': 137,
#  '이하': 1,
#  '갤러리': 3,
#  '용량': 7,
#  '약': 3,
#  '재시': 1,
#  '와이파이': 17,
#  '칸': 10,
#  '이어도': 1,
#  '일부러': 14,
#  '데이터': 28,
#  '문의': 71,
#  '네모': 1,
#  '재차': 2,
#  '이하임': 1,
#  '조속': 1,
#  '바람': 6,
#  '재업': 1,
#  '관련': 12,
#  '내용': 11,
#  '중이': 5,
#  '저번': 8,
#  '며칠': 15,
#  '몇번': 43,
#  '직접': 13,
#  '쇼핑': 64,
#  '덕분': 10,
#  '텅': 1,
#  '마음': 9,
#  '행복': 1,
#  '평': 9,
#  '등록': 23,
#  '버그': 27,
#  '힝': 1,
#  '포인트': 25,
#  '검색': 92,
#  '뒤': 48,
#  '가기': 31,
#  '쿠폰': 195,
#  '배부': 1,
#  '대기': 32,
#  '거나': 7,
#  '자주': 36,
#  '속도': 58,
#  '키': 17,
#  '분': 20,
#  '조건': 5,
#  '부': 3,
#  '정렬': 7,
#  '보고': 35,
#  '리셋': 9,
#  '가장': 9,
#  '의미': 6,
#  '물건': 45,
#  '볼때': 11,
#  '위': 15,
#  '신고': 4,
#  '구글': 9,
#  '외': 7,
#  '신경': 15,
#  '정렬순서': 2,
#  '변경': 16,
#  '상세': 24,
#  '가면': 11,
#  '자체': 66,
#  '설정': 33,
#  '유지': 3,
#  '휴대폰': 16,
#  '위치': 10,
#  '갑자기': 62,
#  '한눈': 4,
#  '볼': 20,
#  '혼동': 1,
#  '증정': 5,
#  '간': 3,
#  '고객': 60,
#  '센터': 35,
#  '대응': 3,
#  '매장': 97,
#  '정가': 2,
#  '할인': 74,
#  '가로': 1,
#  '팔고': 2,
#  '손': 6,
#  '기분': 24,
#  '통일': 2,
#  '해': 40,
#  '살짝': 5,
#  '버벅이': 1,
#  '모든': 5,
#  '여러': 6,
#  '서비스': 37,
#  '불량': 3,
#  '교환': 11,
#  '세번': 2,
#  '수령': 5,
#  '재': 31,
#  '배송': 243,
#  '과정': 4,
#  '통화량': 1,
#  '연결': 55,
#  '한참': 15,
#  '직관': 3,
#  '이진': 1,
#  '신청': 17,
#  '진행': 14,
#  '단계': 6,
#  '실행': 44,
#  '전면': 1,
#  '건': 39,
#  '이해': 13,
#  '감': 7,
#  '유튭': 1,
#  '컨텐츠': 1,
#  '애초': 3,
#  '돈': 37,
#  '풀': 3,
#  '초': 7,
#  '게': 39,
#  '팝업창': 7,
#  '역대': 2,
#  '신': 1,
#  '시스템': 25,
#  '제발': 62,
#  '리다': 5,
#  '프레임': 1,
#  '밖': 3,
#  '난리': 5,
#  '당사': 1,
#  '큐': 2,
#  '레이': 4,
#  '팅': 3,
#  '뿜뿜': 1,
#  '간소화': 1,
#  '축소': 1,
#  '듯': 27,
#  '쇼핑몰': 21,
#  '소비자': 17,
#  '몰래': 2,
#  '댕청': 1,
#  '미가': 1,
#  '배짱': 1,
#  '장사': 10,
#  '려': 8,
#  '장바구니': 89,
#  '란': 7,
#  '이동해': 3,
#  '의도': 4,
#  '탑': 7,
#  '순위도': 1,
#  '체험': 5,
#  '단': 7,
#  '참가': 1,
#  '최근': 11,
#  '검색어': 2,
#  '중간': 7,
#  '랙': 2,
#  '주전': 1,
#  '라운드': 1,
#  '완전': 13,
#  '종료': 25,
#  '흐름': 1,
#  '폰': 56,
#  '환경': 6,
#  '얼른': 1,
#  '해당': 5,
#  '인터넷': 45,
#  '문구': 10,
#  '강제': 21,
#  '설명': 17,
#  '정보': 49,
#  '맨': 4,
#  '지난달': 1,
#  '하라': 51,
#  '고함': 2,
#  '뜸': 14,
#  '오프라인': 32,
#  '온라인': 47,
#  '영만': 4,
#  '롭스': 14,
#  '시일': 2,
#  '카테고리': 20,
#  '제대로': 41,
#  '이틀': 2,
#  '꼴': 3,
#  '식': 15,
#  '존재': 3,
#  '언급': 1,
#  '방': 3,
#  '요즘': 23,
#  '버퍼링': 10,
#  '심해': 20,
#  '신상': 9,
#  '방송': 3,
#  '음소거': 2,
#  '해제': 16,
#  '댓글': 7,
#  '킹': 1,
#  '앨범': 1,
#  '수도': 8,
#  '장난': 19,
#  '이전': 4,
#  '현상': 15,
#  '관리자': 4,
#  '가까이': 7,
#  '배송비': 15,
#  '조회': 5,
#  '문서': 1,
#  '작성': 32,
#  '전용': 10,
#  '주지': 2,
#  '통한': 2,
#  '잘만': 11,
#  '거기': 13,
#  '최소한': 2,
#  '구축': 6,
#  '밤': 10,
#  '도중': 2,
#  '통장': 3,
#  '겁': 11,
#  '증설': 3,
#  '처리': 27,
#  '하든': 2,
#  '대한': 13,
#  '준비': 26,
#  '마케팅': 9,
#  '뿐': 3,
#  '인식': 6,
#  '로드': 2,
#  '비교': 6,
#  '도저히': 4,
#  '문제점': 3,
#  '지속': 8,
#  '제기': 2,
#  '실망': 10,
#  '반응속도': 7,
#  '걸': 33,
#  '옆': 29,
#  '와이프': 4,
#  '모션': 2,
#  '식이': 1,
#  '이후': 15,
#  '느낌': 13,
#  '무거워': 13,
#  '원래': 21,
#  '후기': 21,
#  '프리징': 1,
#  '스토어': 11,
#  '빡종하': 1,
#  '최적화': 20,
#  '계정': 15,
#  '휴면': 11,
#  '상태': 29,
#  '여서': 1,
#  '카카오': 15,
#  '톡': 9,
#  '흰색': 3,
#  '중순': 1,
#  '포토': 5,
#  '사진첩': 1,
#  '차례': 2,
#  '테스트': 6,
#  '픽업': 40,
#  '분리': 2,
#  '재고': 15,
#  '품절': 31,
#  '못': 54,
#  '하니': 12,
#  '방법': 8,
#  '대다수': 1,
#  '미사': 1,
#  '홍보': 7,
#  '기대': 1,
#  '가격': 44,
#  '메리트': 7,
#  '설치': 68,
#  '구입': 15,
#  '쿠팡': 9,
#  '나은': 3,
#  '공동': 6,
#  '현관': 9,
#  '출입': 1,
#  '비밀번호': 38,
#  '입력': 55,
#  '영수증': 13,
#  '뭔가': 8,
#  '기사': 1,
#  '피부': 10,
#  '케어': 8,
#  '화장품': 34,
#  '렉': 149,
#  '재부팅': 2,
#  '가입': 94,
#  '맛': 2,
#  '확장': 1,
#  '조치': 7,
#  '열': 18,
#  '건의': 1,
#  '꽤': 8,
#  '된거': 5,
#  '필터': 5,
#  '링': 3,
#  '생기': 3,
#  '우먼': 3,
#  '네트워크': 8,
#  '도대체': 29,
#  '적립': 5,
#  '캘린더': 4,
#  '해결': 34,
#  '영업일': 2,
#  '반품': 17,
#  '수수료': 1,
#  '중국': 1,
#  '직구': 4,
#  '회사': 10,
#  '탈회': 1,
#  '예정': 16,
#  '아이디': 38,
#  '비번': 31,
#  '재발': 3,
#  '번은': 7,
#  '일치': 4,
#  '순서': 4,
#  '트래픽': 3,
#  '감당': 9,
#  '마감': 2,
#  '핸드폰': 17,
#  '기': 5,
#  '기간': 52,
#  '표시': 12,
#  '코너': 1,
#  '카드': 33,
#  '계좌': 9,
#  '탭': 19,
#  '이건': 22,
#  '오륜': 1,
#  '리지': 13,
#  '분명': 8,
#  '차질': 2,
#  '먹통': 21,
#  '특정': 2,
#  '날짜': 2,
#  '특정시': 1,
#  '이쯤': 3,
#  '사지': 10,
#  '눈치': 1,
#  '사려': 20,
#  '소진하': 1,
#  '브랜드': 15,
#  '공홈': 2,
#  '로란': 1,
#  '대여': 1,
#  '제일': 16,
#  '드럭스토어': 3,
#  '구려': 9,
#  '뭘': 48,
#  '평일': 3,
#  '저녁': 1,
#  '규모': 2,
#  '생리': 1,
#  '임기': 1,
#  '배란기': 1,
#  '체크': 57,
#  '멤버십': 7,
#  '바코드': 24,
#  '그대': 1,
#  '어필': 1,
#  '질도': 1,
#  '끝내': 1,
#  '최소': 4,
#  '당일': 7,
#  '문자': 14,
#  '입': 3,
#  '끝': 9,
#  '처': 5,
#  '임의': 1,
#  '결품': 3,
#  '출고': 6,
#  '빅세일': 1,
#  '벤트': 1,
#  '선착': 4,
#  '인원': 5,
#  '딜': 3,
#  '세기': 2,
#  '시대': 8,
#  '작동': 20,
#  '인내심': 5,
#  '업무': 2,
#  '햐': 1,
#  '장점': 5,
#  '학생': 2,
#  '도움': 2,
#  '일도': 5,
#  '굿': 4,
#  '단점': 4,
#  '순위': 4,
#  '이름': 9,
#  '튕깁': 2,
#  '그레': 2,
#  '튕겼어': 1,
#  '발색': 1,
#  '은근': 1,
#  '누루': 1,
#  '짝': 1,
#  '전향': 1,
#  '직원': 22,
#  '완료': 19,
#  '활성화': 8,
#  '뭡': 1,
#  '계산': 5,
#  '직전': 7,
#  '눌려': 6,
#  '반복': 34,
#  '스스로': 3,
#  '누룰': 1,
#  '최악': 41,
#  '수년': 1,
#  '늘': 6,
#  '세': 23,
#  '상': 1,
#  '불구': 7,
#  '손가락': 1,
#  '바': 6,
#  '저건': 1,
#  '답': 13,
#  '코로나': 4,
#  '시국': 1,
#  '각오': 1,
#  '품질': 3,
#  '반년': 1,
#  '가짐': 5,
#  '고해': 9,
#  '빅': 2,
#  '시기': 1,
#  '옷': 1,
#  '이면': 12,
#  '보통': 7,
#  '굳이': 12,
#  '탭바': 1,
#  '프로': 5,
#  '끼리': 1,
#  '메뉴바': 1,
#  '어제': 13,
#  '캐시': 5,
#  '제거': 12,
#  '다운로드': 17,
#  '시정': 1,
#  '꼭': 12,
#  '어어': 5,
#  '포기': 14,
#  '버버벅': 1,
#  '거리': 43,
#  '초기': 20,
#  '쭉쭉': 1,
#  '부지': 4,
#  '기수': 1,
#  '진득': 1,
#  '앱임': 2,
#  '국민': 1,
#  '뷰티': 1,
#  '항상': 26,
#  '수준': 16,
#  '대기업': 20,
#  '대충': 5,
#  '초보': 1,
#  '개발자': 24,
#  '서초': 2,
#  '지도': 3,
#  '이유': 17,
#  '세상': 5,
#  '배달': 10,
#  '면도기': 1,
#  '선': 9,
#  '도무지': 1,
#  '카톡': 12,
#  '유투브': 1,
#  '정해진': 1,
#  '시작': 18,
#  '시장': 1,
#  '독점': 4,
#  '유저': 5,
#  '용': 10,
#  '아두': 1,
#  '최신기종': 1,
#  '개인': 3,
#  '정': 4,
#  '땐': 8,
#  '버벅': 54,
#  '수강신청': 4,
#  '눌리': 5,
#  '틈': 2,
#  '체적': 4,
#  '난국': 3,
#  '커서': 1,
#  '별': 19,
#  '화요일': 2,
#  '다음주': 1,
#  '출발': 9,
#  '움직': 5,
#  '접근': 3,
#  '대부분': 4,
#  '던데': 1,
#  '운영': 7,
#  '꼬': 3,
#  '탈퇴': 7,
#  '고장': 2,
#  '배송지': 30,
#  '본가': 1,
#  '자취': 1,
#  '개심': 3,
#  '오지': 10,
#  '웹사이트': 3,
#  '장애': 4,
#  '깝깝': 1,
#  '길': 7,
#  '플레이스토어': 2,
#  '이제': 15,
#  '유산균': 1,
#  '린다': 2,
#  '고치': 2,
#  '튕기길': 1,
#  '예상': 3,
#  '종일': 5,
#  '튕겨': 16,
#  '구경': 6,
#  '래야': 1,
#  '치명': 1,
#  '종종': 3,
#  '장도': 1,
#  '안뜰': 1,
#  '극악': 2,
#  '쓰레기': 21,
#  '확대': 8,
#  '현대': 1,
#  '맘춤': 1,
#  '실패': 6,
#  '웹브라우저': 1,
#  '대학교': 1,
#  '상부': 1,
#  '배치': 1,
#  '하부': 1,
#  '임': 43,
#  '웹': 18,
#  '저장': 10,
#  '로그아웃': 8,
#  '하란': 5,
#  '드': 7,
#  '버벅거림': 7,
#  '오류로': 6,
#  '역': 11,
#  '안해': 10,
#  '런가': 6,
#  '전화': 16,
#  '본인': 11,
#  '마인드': 2,
#  '걱정': 1,
#  '논리': 1,
#  '필요': 11,
#  '한텐': 1,
#  '명도': 2,
#  '원인': 4,
#  '반대': 2,
#  '쓰시': 1,
#  '분도': 1,
#  '칭찬': 3,
#  '자유': 1,
#  '의견': 3,
#  '존중': 1,
#  '크롬': 5,
#  '복': 5,
#  '단순': 2,
#  '지연': 36,
#  '달이': 9,
#  '메시지': 4,
#  '인터페이스': 7,
#  '디자인': 4,
#  '션': 1,
#  '쉬': 4,
#  '알림': 32,
#  '진동': 1,
#  '소리': 6,
#  '착각': 2,
#  '무조건': 6,
#  '권한': 7,
#  '요구': 4,
#  '적도': 2,
#  '허용': 6,
#  '차원': 1,
#  '후자': 1,
#  '침범': 1,
#  '그간': 1,
#  '만행': 1,
#  '마지막': 11,
#  '타이틀': 1,
#  '점주': 2,
#  '가요': 32,
#  '눈': 7,
#  '초심': 1,
#  '귀': 2,
#  '돈좀': 2,
#  '자꾸만': 2,
#  '눌': 6,
#  '리기': 4,
#  '고양이': 1,
#  '무': 17,
#  '면서': 9,
#  '박아': 1,
#  '엑스': 4,
#  '옴': 8,
#  '최': 1,
#  '입장': 4,
#  '리가': 2,
#  '발생': 16,
#  '랭킹': 5,
#  '려고': 9,
#  '몰이': 2,
#  '차이': 2,
#  '남': 9,
#  '방문': 9,
#  '진심': 15,
#  '투성이': 2,
#  '불': 2,
#  '안정': 4,
#  '방식': 3,
#  '편리': 2,
#  '비': 7,
#  '쇼': 3,
#  '회원': 64,
#  '영문': 1,
#  '숫자': 4,
#  '특수문자': 1,
#  '중복': 8,
#  '글자': 1,
#  '십분': 1,
#  '씨름': 2,
#  '완': 1,
#  '요청': 4,
#  '별하나': 5,
#  '글': 28,
#  '위해': 7,
#  '중소기업': 5,
#  '현재': 7,
#  '경이': 1,
#  '쭈우욱': 1,
#  '목적': 2,
#  '홈페이지': 17,
#  '날': 26,
#  '컴퓨터': 3,
#  '소용': 3,
#  '활용': 3,
#  '발급': 15,
#  '라이브': 18,
#  '천만': 1,
#  '스탬프': 1,
#  '몰리': 5,
#  '안눌림': 2,
#  '순간': 5,
#  '질': 2,
#  '거주': 2,
#  '지역': 10,
#  '주로': 2,
#  '사항': 6,
#  '자격': 1,
#  '적용': 19,
#  '일주일': 17,
#  '새벽': 18,
#  '점검': 5,
#  '이용자': 6,
#  '도거': 1,
#  '훨': 4,
#  '소프트웨어': 1,
#  '최신': 12,
#  '커녕': 3,
#  '문의사항': 1,
#  '뭥미': 1,
#  '컴': 2,
#  '허참': 1,
#  '물품': 6,
#  '말씀': 4,
#  '신지': 1,
#  '뚝딱': 3,
#  '상황': 5,
#  '추후': 1,
#  '온': 4,
#  '파손': 4,
#  '한지': 3,
#  '젠데': 1,
#  '불량품': 1,
#  '루트': 2,
#  '달': 30,
#  '잡고': 3,
#  '우리말': 1,
#  '반려': 3,
#  '단어': 4,
#  '즈그': 1,
#  '상관': 3,
#  '듸': 1,
#  '선착순': 16,
#  '품목': 7,
#  '꼭꼭': 1,
#  '터': 8,
#  '그거': 6,
#  '카운트': 1,
#  '구동': 9,
#  '메모장': 2,
#  '종이': 3,
#  '본사': 3,
#  '레파': 1,
#  '토리': 1,
#  '끈': 1,
#  '수의': 1,
#  '만해': 2,
#  '매출': 4,
#  '배': 4,
#  '상승': 1,
#  '대요': 1,
#  '일정': 5,
#  '금액': 5,
#  '기만': 7,
#  '지인': 2,
#  '선물': 15,
#  '안드': 1,
#  '월급': 6,
#  '발전': 8,
#  '프로모션': 1,
#  '갈수록': 6,
#  '말단': 1,
#  '관리': 41,
#  '커머스': 1,
#  '플랫폼': 5,
#  '리뉴': 1,
#  '리뉴얼': 2,
#  '점유': 1,
#  '율': 2,
#  '구조조정': 1,
#  '당': 2,
#  '차제': 1,
#  '램': 1,
#  '힘좀': 1,
#  '달라': 5,
#  '접': 2,
#  '출첵': 20,
#  '알람': 9,
#  '동의': 20,
#  '작작': 2,
#  '출석': 60,
#  '어차피': 4,
#  '누적': 1,
#  '나머지': 3,
#  '경품': 1,
#  '확률': 1,
#  '개월': 2,
#  '장가': 13,
#  '앱좀': 3,
#  '점도': 9,
#  '친구': 2,
#  '내부': 3,
#  '포장': 4,
#  '유선': 2,
#  '부디': 1,
#  '대지': 1,
#  '답장': 3,
#  '퇴화': 1,
#  '오후': 5,
#  '연락': 21,
#  '금요일': 1,
#  '흠': 1,
#  '땜': 4,
#  '지고': 6,
#  '세월': 8,
#  '주르륵': 1,
#  '링크': 4,
#  '우리나라': 1,
#  '현저': 1,
#  '짓': 5,
#  '코드': 1,
#  '정리': 4,
#  '부처': 1,
#  '스크롤해애되': 1,
#  '해면': 1,
#  '다해': 4,
#  '더니': 7,
#  '단말기': 2,
#  '느닷': 1,
#  '모바일': 13,
#  '공지': 8,
#  '사과': 1,
#  '취해': 2,
#  '탓': 2,
#  '제조': 1,
#  '사의': 2,
#  '방치': 6,
#  '오프': 6,
#  '통합': 12,
#  '리프': 2,
#  '레시': 1,
#  '눈썹': 1,
#  '손질': 1,
#  '도구': 1,
#  '산적': 1,
#  '불만': 7,
#  '금방': 1,
#  '기미': 1,
#  '가끔': 11,
#  '대비': 4,
#  '로켓': 2,
#  '네이버': 12,
#  '일반': 10,
#  '인프라': 1,
#  '충격': 3,
#  '줌': 3,
#  '무료': 14,
#  '가치': 2,
#  '판단': 1,
#  '나중': 3,
#  '아이쇼핑': 2,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>

# %%
df = pd.DataFrame.from_dict(word_counts, orient='index')
df = df.rename(columns={0:'counts'})
df.sort_values('counts',ascending=False).head(20)
# Out:
#       counts
# 앱        842
# 로그인      385
# 어플       369
# 진짜       255
# 배송       243
# 리뷰       239
# 계속       216
# 결제       209
# 화면       199
# 쿠폰       195
# 구매       190
# 오늘       178
# 사용       178
# 업데이트     174
# 상품       171
# 올리브영     163
# 오류       160
# 거        159
# 제품       153
# 렉        149
