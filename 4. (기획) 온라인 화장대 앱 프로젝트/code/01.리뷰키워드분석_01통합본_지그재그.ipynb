# %% [markdown]
# # 리뷰 데이터 수집

# %%
import pandas as pd
import numpy as np
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.croquis.zigzag",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST)

# %%
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    df.to_csv(f'./data/01.리뷰키워드분석_01통합본_{name}_리뷰크롤링파일.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'지그재그')

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
def tokenize(dataFrame):
    okt = Okt()
    dataFrame['morphs'] = [okt.morphs(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    tokenize(dataFrame)
    remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
df = df.dropna(axis=0)
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <14129x16335 sparse matrix of type '<class 'numpy.int64'>'
# 	with 114072 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <14129x16335 sparse matrix of type '<class 'numpy.float64'>'
# 	with 114072 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '포토 리뷰 크기 ux 개선 부탁드립니다 포토 리뷰 사진 목록 들어갔을 자세히 보고싶은 사진 선택 원래 는 화면 꽉 차게 사진 보여졌는데 은 사진 ui 너무 작아져서 클릭 해야 사진 확대 되서 보이는게 불편해요 ㅠㅠ 터치 2 해야하는 불편한 ux 같아요 수정 요청 드립니다 손꾸락 아파요,최근 ui 정말 최악 직진 배송 보도록 설정 했는데 직진 배송 상품 아닌 추천 상품 비슷한 상품 자동 노출 됩니다 필터 설정 값 에도 맞지 않아 자꾸 모르고 클릭 했다가 화만 나네요 물건 팔려는 건 알겠지만 전혀 소비자 맞춰져 있지 않네요,프로모션 팝업 누르면 동의 없이 카카오 톡 친구 추가 기능 삭제 해주세요 앱 접속 불시 화면 꽉 채우는 팝업 떠서 기능 동작 하다가 실수 팝업창 클릭 하게 되면 자동 카톡 친구 추가 차단 너무 번거롭습니다 카톡 보내시는 광고 성 메시지 는 받아 보고 싶지 않아요 기능 몇번 경험 로는 앱 이용 반감 생겨 부득이 상황 웬만하면 앱 사용 하게 됩니다,안녕하세요 !!!! ❤ 지그재그 잘쓰고 있는 유저 지그재그 에서는 쇼핑몰 있어서 정말 여러 예쁜 옷 찾기 쉬운데 진짜 필터 목록 옷 길이 총기 장 구간 정해 서 구간 맞는 옷 찾을 있도록 넣어주시면 모든 행복 찾아올 ... 😭 진짜 기장 고생 한두 아니라는 아실 겁니다 ............,지그재그 앱 정말 아주 애용 회원 0 사진 보여지기에 사용 에너지 소모 인해 배터리 빨리 닳는 와이파이 권장 이유 있는 앱임 이해 합니다 지그재그 어플 접속 한지 10분 지나면 핸드폰 터질 처럼 뜨거워 집니다 전면 면 ㅠㅠ 어플 ( 검색 장시간 영상 시청 ) 는 전혀 부분 지그재그 사용 현상 여서 20분 째 볼 는 손 기 무서울 앱 끄고 핸드폰 식으면 들어갑니다 .( 시원한 카페 에서도 이렇다 보니 환경 요소 는 관계 없는 같습니다 .) 쇼핑 앱 이라 적은 소요 둘러보는 완료 되지 않는데 쇼핑 물품 이미지 최적화 던지 해결 방법 있을지 궁금합니다 ㅠㅠ 좋은 앱 인데 넘 아쉬워용,모아 보기 기능 매우 매우 매우 편리합니다 후드 는 후드 코트 는 코트 쇼핑몰 쫙 모아놓은 기능 게 너무 편하고 지그재그 존재 의미 라고 합니다 자동 회원 가입 신의 한수 너무 편해요 자동 회원 가입 진짜 ..... 주문 상품 앱 진행 현황 볼 있는 점도 좋고 찜 하기도 쇼핑몰 찜 상품 나열 되기 후드 봤더라도 여러 쇼핑몰 마음 드는 후드 비교 쉬워서 좋아요 쓰고 있습니다,좋아하는 쇼핑몰 각기 곳 주문 쇼핑 목록 한번 조회 해볼수 있어서 간편하고 옷 종목 별로 인기 순 한눈 볼 있어 좋아요 찜 해놓은 물건 쇼핑몰 다 달라 통합 볼 있어서 너무 좋아요 쇼핑몰 통합 체 여서 찾는 종목 별 물건 다 있고 장바구니 배송 조 회도 쇼핑몰 찾아가 로그인 해야 있는 아닌 한번 조회 가능하니 니까 아주 간편합니다,지그재그 너무 좋아요 쇼핑 한번 여러가지 볼수있어서 편하고 비교 하기도 좋고 필요한거 있을 주로 지그재그 이용 합니다 아주 아쉬운건 몇개 사던 쇼핑몰 사면 죄다 배송비 붙어서 그게 아쉬워요 일정 금액 구매 무료 배송 해주고 좋을텐데 어려울까,어제 새벽 2시 쯤 직진 배송 포함 된 주문 했는데요 오늘 오전 8시 에도 배송 준비 이길래 쿠폰 재적 용하려고 취소 똑같은 상품 재 결제 했습니다 취소 문건 오늘 점심 쯤 취소 대기 (?) 였는데 4시 반에 확인 해보니 새로 주문 건 배송 바뀌었더라구요 당황 해서 전화했더니 직진 배송 은 주문 10분 안에 취소 배송 될 있다는데 이런건 크게 써 놔야 하는거 아닌가요 ? 애초 직진 배송 은 10분 지나면 취소 없게 하던가 취소 철회 될 있다고 명시 했으니까 본인 은 못 반품 은 5천원 소비자 몫 이라는 ㅋ 재 주문 할거라고 이유 써놨는데 배송 주문 확인 한번 배송 하는게 맞는거 아닌가요 배송 시작 안해 서 취소 한건데 취소 철회 될줄 알았으면 재 주문 했겠죠 취소 재 주문 해본 경험 없는것도 아닌데 은 처음 이네 상품 팔고 나면 몰라 라인 건지 .... 브랜딩 한다고 기업 인데 직잭 너무 실망 .....,정말 쓰고있습니다 아쉬운건 최근 업뎃되면 서 디자인 불편해졌어요 ㅠㅠ 시선 곳 많이 가다 보니 어지럽고 집중 안됩니다 쇼핑몰 옆 Z 결제 아이콘 라던가 신상 마다 붙어있는 new 아이콘 라던가 굳이 단어 사용 않아도 의미 전달 될거 같구요 상품 클릭 했을 쇼핑몰 페이지 지그재그 창 (?) 보이는데 여기서도 아이콘 버튼 색상 너무 팝 해서 옷 상세 페이지 집중 할수가 없어요 시선 잡아먹는게 위아래 다 있으니 요약 하자면 마젠타 색 은 예쁘지만 포인트 여기저기 너무 많아요 이전 버전 디자인 은 깔끔하니 쇼핑 편했던것 같아요 열심히 연구 개발 하셨을텐데 안좋은 소리 늘어놓아 송구 정말 아쉬워서 절절 리뷰 남깁니다 지그재그 완벽한 쇼핑 앱 은 없어요,지그재그 사용 있었는데 업데이트 되면서 바뀐 건지 찜 상품 편집 맨 위로 올리는 기능 없어져서 불편해요 는 폴더 옷 종류 별로 나눠서 사용 주로 가장 맘 드는 상품 위 두고 봤는데 기능 사라지니까 따로 폴더 만들게 돼서 불편하더라구요 편집 시 전체 선택 사라진 그렇구요 ㅠㅠ 가능하다면 기능 생겨났으면 바람 스토어 별 보기 에서도 상품 누르고 들어가서 일일이 찜 취소 누르기 불편해서 찜 상품 편집 처럼 가위 ? 모양 아이콘 상품 선택 기능 생기 면 편할 같아요 부분 은 만족하며 사용 있습니다 :),주문 상세 페이지 화살표 눌러도 홈키 있는 뒤 가기 눌러도 뒤 가기 안되는 오류 있어요 ㅠㅠ 주문 날짜 다 달라 서 다 확 인하랴 면 매회 차마 다 앱 껐다 켜서 첨부 터 시작 해야 되는데 넘 번거롭네요 ㅠ 유튜브 앱 은 잘만 돌아가는 네트워크 환경 ㅠ 기능 은 잘만 되는데 이럴까 ㅠ 개선 부탁드려용 ㅠㅠㅜ 넘 쓰고 있는 앱 용 개선 되면 평점 5,찜 목록 개선 되면 좋을 거 같아요 찜 목록 쇼핑몰 마다 확인 있는 기능 있으면 좋을 거 같아요 지그재그 는 무료 배송 서비스 없는 앱 이다 니까 쇼핑몰 묶어서 사게 편인데요 기능 있으면 편하고 좋을거 같아요 ..!! 보다 폴더 기능 은 쓰게 되더라구요 8 ㅅ 8,좋아요 쇼핑몰 이랑 상품 가장 많이 있는 같아 편리합니다 한가지 바라는 기능 있는데 즐겨찾기 쇼핑몰 신 상품 인기 상품 한번 볼 있는 기능 있다면 좋겠어요 ㅠㅠㅠ 즐겨찾기 쇼핑몰 일일이 들어가는 좋지만 한번 쫙 볼 있음 더욱 편리할 듯 합니다,지그재그 초창 기 쓰고 있는 인데 요즘 진짜 최악 이라고 로딩 버그 는 앱 자체 들어가질 상당히 많아요 쇼핑 하다가 갑자기 꺼지는 은 쇼핑 불편할 버그 굉장히 많고 맨날 어플 업데이트 는 하는데 오류 는 고쳐지지 않는 거 죠 이용 오류 버그 로딩 제발 해결 해줬으면,마켓 여서 보여줘서 옷 고르기 너무 편해요 1 필터 링 기능 약한것 같아요 들어 아웃 터 > 패딩 단계 까지는 되는데 상세 조건 설정 ( 롱패딩 ) 식 모든 롱패딩 보여주진 못 하는것 같아요 2 사이즈 별 필터 링 가능했으면 좋겠어요 들어 아웃 터 > 코트 온 상세 조건 설정 총기 장 : " 70 80 " 식 입력 있도록 이요 직잭 화이팅 하세용,짱 좋아요 어플 모르면 진짜 손 해보고 사는거 특히 글램 럭셔리 오피스 스타일 최애 인데 지그재그 만의 감성 알맞음 색상 가격 스타일 별로 필터 링 할수있어서 너무 좋고 특정 스타일 검색 창 입력 연관 된 상품 보여주고 이런게 어딨다요 개발자 님 복 받으세요,품절 된 상품 은 페이지 자체 사라지는 사라진 상품 기반 추천 상품 선정 카테고리 제대로 나뉘어있지 않은 ( 티셔츠 카테고리 온갖 악세 서리 필기구 조회 됨 ), 필터 걸고 리스트 조회 어플 전환 되면 리스트 갱신 되며 최상 단 올라가 버리는 문제점 있습니다 마디 구림 편의 성 매우 부족합니다,안녕하세요 지그재그 오래전 이용 해 왔는데 최근 달 간 로딩 너무 많이 걸리고 렉 많이 걸립니다 처음 들어갔을 뜨는 팝업 광고 x 표시 누르는데 계속 광고 페이지 이동 건지 .... 팝업 광고 뜨게 방법 은 없나요 ... 팝업 광고 띄우느라 로딩 느려지고 들어가자마자 빠르게 제품 검색 수가 없어서 불편합니다 제품 찜 위해 하트 누르면 누름과 동시 폴더 분류 선택 있도록 해주셨으면 좋겠어요 사이트 들어가서 찜 하기를 누르고 폴더 분류 려고 뜨는 팝업 누르 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.morphs(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'포토': 15,
#  '리뷰': 528,
#  '크기': 10,
#  'ux': 3,
#  '개선': 175,
#  '부탁드립니다': 63,
#  '사진': 217,
#  '목록': 109,
#  '들어갔을': 10,
#  '자세히': 20,
#  '보고싶은': 9,
#  '선택': 225,
#  '원래': 97,
#  '는': 882,
#  '화면': 274,
#  '꽉': 5,
#  '차게': 1,
#  '보여졌는데': 1,
#  '은': 1044,
#  'ui': 7,
#  '너무': 2650,
#  '작아져서': 1,
#  '클릭': 84,
#  '해야': 115,
#  '확대': 5,
#  '되서': 84,
#  '보이는게': 3,
#  '불편해요': 144,
#  'ㅠㅠ': 631,
#  '터치': 31,
#  '2': 134,
#  '해야하는': 16,
#  '불편한': 45,
#  '같아요': 901,
#  '수정': 84,
#  '요청': 60,
#  '드립니다': 27,
#  '손꾸락': 1,
#  '아파요': 6,
#  ',': 12988,
#  '최근': 68,
#  '정말': 714,
#  '최악': 51,
#  '직진': 102,
#  '배송': 846,
#  '보도록': 1,
#  '설정': 218,
#  '했는데': 342,
#  '상품': 1209,
#  '아닌': 41,
#  '추천': 310,
#  '비슷한': 217,
#  '자동': 89,
#  '노출': 14,
#  '됩니다': 63,
#  '필터': 167,
#  '값': 15,
#  '에도': 91,
#  '맞지': 8,
#  '않아': 18,
#  '자꾸': 334,
#  '모르고': 23,
#  '했다가': 34,
#  '화만': 2,
#  '나네요': 13,
#  '물건': 135,
#  '팔려는': 1,
#  '건': 100,
#  '알겠지만': 2,
#  '전혀': 29,
#  '소비자': 43,
#  '맞춰져': 2,
#  '있지': 10,
#  '않네요': 37,
#  '프로모션': 3,
#  '팝업': 42,
#  '누르면': 153,
#  '동의': 22,
#  '없이': 102,
#  '카카오': 42,
#  '톡': 18,
#  '친구': 119,
#  '추가': 191,
#  '기능': 536,
#  '삭제': 222,
#  '해주세요': 204,
#  '앱': 2025,
#  '접속': 66,
#  '불시': 2,
#  '채우는': 1,
#  '떠서': 96,
#  '동작': 2,
#  '하다가': 38,
#  '실수': 16,
#  '팝업창': 22,
#  '하게': 91,
#  '되면': 91,
#  '카톡': 51,
#  '차단': 21,
#  '번거롭습니다': 4,
#  '보내시는': 1,
#  '광고': 388,
#  '성': 50,
#  '메시지': 10,
#  '받아': 24,
#  '보고': 248,
#  '싶지': 8,
#  '않아요': 54,
#  '몇번': 58,
#  '경험': 13,
#  '로는': 25,
#  '이용': 365,
#  '반감': 1,
#  '생겨': 6,
#  '부득이': 2,
#  '상황': 29,
#  '웬만하면': 10,
#  '사용': 710,
#  '안녕하세요': 29,
#  '!!!!': 30,
#  '❤': 96,
#  '지그재그': 1223,
#  '잘쓰고': 85,
#  '있는': 360,
#  '유저': 23,
#  '에서는': 47,
#  '쇼핑몰': 1924,
#  '있어서': 854,
#  '여러': 450,
#  '예쁜': 345,
#  '옷': 3485,
#  '찾기': 235,
#  '쉬운데': 2,
#  '진짜': 1112,
#  '길이': 18,
#  '총기': 4,
#  '장': 20,
#  '구간': 2,
#  '정해': 9,
#  '서': 363,
#  '맞는': 104,
#  '찾을': 99,
#  '있도록': 25,
#  '넣어주시면': 8,
#  '모든': 106,
#  '행복': 7,
#  '찾아올': 1,
#  '😭': 11,
#  '기장': 17,
#  '고생': 7,
#  '한두': 41,
#  '아니라는': 3,
#  '아실': 1,
#  '겁니다': 10,
#  '아주': 152,
#  '애용': 106,
#  '회원': 124,
#  '0': 14,
#  '보여지기에': 1,
#  '에너지': 1,
#  '소모': 5,
#  '인해': 8,
#  '배터리': 2,
#  '빨리': 132,
#  '닳는': 1,
#  '와이파이': 84,
#  '권장': 2,
#  '이유': 49,
#  '앱임': 3,
#  '이해': 30,
#  '합니다': 216,
#  '어플': 605,
#  '한지': 30,
#  '10분': 10,
#  '지나면': 15,
#  '핸드폰': 72,
#  '터질': 1,
#  '처럼': 98,
#  '뜨거워': 2,
#  '집니다': 10,
#  '전면': 1,
#  '면': 322,
#  '(': 188,
#  '검색': 579,
#  '장시간': 1,
#  '영상': 14,
#  '시청': 1,
#  ')': 155,
#  '부분': 83,
#  '현상': 55,
#  '여서': 65,
#  '20분': 3,
#  '째': 95,
#  '볼': 491,
#  '손': 24,
#  '기': 83,
#  '무서울': 1,
#  '끄고': 8,
#  '식으면': 1,
#  '들어갑니다': 1,
#  '시원한': 1,
#  '카페': 1,
#  '에서도': 49,
#  '이렇다': 1,
#  '보니': 88,
#  '환경': 9,
#  '요소': 2,
#  '관계': 4,
#  '없는': 107,
#  '같습니다': 88,
#  '쇼핑': 626,
#  '이라': 142,
#  '적은': 7,
#  '소요': 7,
#  '둘러보는': 3,
#  '완료': 47,
#  '되지': 47,
#  '않는데': 14,
#  '물품': 13,
#  '이미지': 49,
#  '최적화': 6,
#  '던지': 7,
#  '해결': 104,
#  '방법': 69,
#  '있을지': 3,
#  '궁금합니다': 6,
#  '좋은': 781,
#  '인데': 291,
#  '넘': 433,
#  '아쉬워용': 2,
#  '모아': 230,
#  '보기': 463,
#  '매우': 81,
#  '편리합니다': 28,
#  '후드': 20,
#  '코트': 11,
#  '쫙': 15,
#  '모아놓은': 16,
#  '게': 328,
#  '편하고': 323,
#  '존재': 11,
#  '의미': 11,
#  '라고': 133,
#  '가입': 226,
#  '신의': 2,
#  '한수': 3,
#  '편해요': 315,
#  '주문': 295,
#  '진행': 25,
#  '현황': 16,
#  '점도': 16,
#  '좋고': 238,
#  '찜': 345,
#  '하기도': 54,
#  '나열': 8,
#  '되기': 4,
#  '봤더라도': 1,
#  '마음': 125,
#  '드는': 75,
#  '비교': 356,
#  '쉬워서': 26,
#  '좋아요': 3334,
#  '쓰고': 237,
#  '있습니다': 168,
#  '좋아하는': 86,
#  '각기': 5,
#  '곳': 246,
#  '한번': 585,
#  '조회': 19,
#  '해볼수': 2,
#  '간편하고': 47,
#  '종목': 2,
#  '별로': 342,
#  '인기': 80,
#  '순': 108,
#  '한눈': 208,
#  '있어': 150,
#  '해놓은': 34,
#  '다': 1445,
#  '달라': 56,
#  '통합': 33,
#  '체': 4,
#  '찾는': 58,
#  '별': 228,
#  '있고': 299,
#  '장바구니': 230,
#  '조': 56,
#  '회도': 4,
#  '찾아가': 1,
#  '로그인': 419,
#  '가능하니': 2,
#  '니까': 126,
#  '간편합니다': 1,
#  '여러가지': 162,
#  '볼수있어서': 219,
#  '필요한거': 6,
#  '있을': 32,
#  '주로': 18,
#  '아쉬운건': 11,
#  '몇개': 27,
#  '사던': 3,
#  '사면': 30,
#  '죄다': 8,
#  '배송비': 143,
#  '붙어서': 3,
#  '그게': 50,
#  '아쉬워요': 55,
#  '일정': 6,
#  '금액': 74,
#  '구매': 529,
#  '무료': 84,
#  '해주고': 16,
#  '좋을텐데': 4,
#  '어려울까': 1,
#  '어제': 32,
#  '새벽': 9,
#  '2시': 2,
#  '쯤': 24,
#  '포함': 11,
#  '된': 179,
#  '했는데요': 7,
#  '오늘': 78,
#  '오전': 4,
#  '8시': 3,
#  '준비': 26,
#  '이길래': 1,
#  '쿠폰': 350,
#  '재적': 1,
#  '용하려고': 2,
#  '취소': 214,
#  '똑같은': 39,
#  '재': 70,
#  '결제': 465,
#  '했습니다': 35,
#  '문건': 3,
#  '점심': 1,
#  '대기': 8,
#  '(?)': 41,
#  '였는데': 11,
#  '4시': 1,
#  '반': 30,
#  '에': 28,
#  '확인': 180,
#  '해보니': 6,
#  '새로': 45,
#  '바뀌었더라구요': 1,
#  '당황': 17,
#  '해서': 479,
#  '전화했더니': 3,
#  '안': 5,
#  '될': 42,
#  '있다는데': 1,
#  '이런건': 6,
#  '크게': 15,
#  '써': 110,
#  '놔야': 1,
#  '하는거': 21,
#  '아닌가요': 26,
#  '?': 624,
#  '애초': 7,
#  '없게': 8,
#  '하던가': 7,
#  '철회': 7,
#  '있다고': 13,
#  '명시': 3,
#  '했으니까': 1,
#  '본인': 49,
#  '못': 496,
#  '반품': 143,
#  '5천원': 12,
#  '몫': 3,
#  '이라는': 28,
#  'ㅋ': 67,
#  '할거라고': 1,
#  '써놨는데': 1,
#  '하는게': 62,
#  '맞는거': 3,
#  '시작': 26,
#  '안해': 33,
#  '한건데': 5,
#  '될줄': 1,
#  '알았으면': 3,
#  '했겠죠': 2,
#  '해본': 7,
#  '없는것도': 2,
#  '아닌데': 19,
#  '처음': 191,
#  '이네': 72,
#  '팔고': 8,
#  '나면': 8,
#  '몰라': 7,
#  '라인': 3,
#  '건지': 147,
#  '브랜딩': 1,
#  '한다고': 20,
#  '기업': 7,
#  '직잭': 31,
#  '실망': 21,
#  '쓰고있습니다': 14,
#  '업뎃되': 3,
#  '디자인': 105,
#  '불편해졌어요': 9,
#  '시선': 3,
#  '많이': 617,
#  '가다': 2,
#  '어지럽고': 2,
#  '집중': 5,
#  '안됩니다': 34,
#  '옆': 30,
#  'Z': 23,
#  '아이콘': 14,
#  '라던가': 12,
#  '신상': 43,
#  '마다': 223,
#  '붙어있는': 2,
#  'new': 1,
#  '굳이': 36,
#  '단어': 9,
#  '않아도': 37,
#  '전달': 7,
#  '될거': 7,
#  '같구요': 4,
#  '했을': 39,
#  '페이지': 140,
#  '창': 183,
#  '보이는데': 7,
#  '여기서도': 2,
#  '버튼': 116,
#  '색상': 61,
#  '팝': 1,
#  '상세': 93,
#  '할수가': 31,
#  '없어요': 103,
#  '잡아먹는게': 1,
#  '위아래': 10,
#  '있으니': 13,
#  '요약': 1,
#  '하자': 12,
#  '마젠타': 1,
#  '색': 37,
#  '예쁘지만': 1,
#  '포인트': 172,
#  '여기저기': 24,
#  '많아요': 191,
#  '이전': 27,
#  '버전': 72,
#  '깔끔하니': 1,
#  '편했던것': 1,
#  '열심히': 24,
#  '연구': 1,
#  '개발': 20,
#  '하셨을텐데': 1,
#  '안좋은': 9,
#  '소리': 10,
#  '늘어놓아': 1,
#  '송구': 1,
#  '아쉬워서': 4,
#  '절절': 2,
#  '남깁니다': 23,
#  '완벽한': 6,
#  '있었는데': 62,
#  '업데이트': 313,
#  '되면서': 12,
#  '바뀐': 12,
#  '편집': 19,
#  '맨': 78,
#  '위로': 73,
#  '올리는': 5,
#  '없어져서': 8,
#  '폴더': 101,
#  '종류': 182,
#  '나눠서': 13,
#  '가장': 79,
#  '맘': 175,
#  '위': 69,
#  '두고': 20,
#  '봤는데': 69,
#  '사라지니까': 2,
#  '따로': 102,
#  '만들게': 1,
#  '돼서': 78,
#  '불편하더라구요': 1,
#  '시': 82,
#  '전체': 67,
#  '사라진': 5,
#  '그렇구요': 2,
#  '가능하다면': 5,
#  '생겨났으면': 1,
#  '바람': 11,
#  '스토어': 64,
#  '누르고': 18,
#  '들어가서': 117,
#  '일일이': 52,
#  '누르기': 14,
#  '불편해서': 28,
#  '가위': 2,
#  '모양': 11,
#  '생기': 26,
#  '편할': 8,
#  '만족하며': 6,
#  ':),': 62,
#  '화살표': 3,
#  '눌러도': 58,
#  '홈키': 1,
#  '뒤': 129,
#  '가기': 60,
#  '안되는': 38,
#  '오류': 274,
#  '있어요': 319,
#  '날짜': 14,
#  '확': 10,
#  '인하랴': 1,
#  '매회': 1,
#  '차마': 2,
#  '껐다': 22,
#  '켜서': 4,
#  '첨부': 12,
#  '터': 25,
#  '되는데': 57,
#  '번거롭네요': 7,
#  'ㅠ': 430,
#  '유튜브': 47,
#  '잘만': 10,
#  '돌아가는': 3,
#  '네트워크': 29,
#  '이럴까': 7,
#  '부탁드려용': 2,
#  'ㅠㅠㅜ': 6,
#  '용': 150,
#  '평점': 14,
#  '5': 104,
#  '좋을': 99,
#  '거': 653,
#  '있으면': 180,
#  '서비스': 58,
#  '이다': 33,
#  '묶어서': 12,
#  '사게': 14,
#  '편인데요': 1,
#  '좋을거': 44,
#  '!!': 7,
#  '보다': 252,
#  '쓰게': 19,
#  '되더라구요': 13,
#  '8': 23,
#  'ㅅ': 18,
#  '이랑': 150,
#  '같아': 31,
#  '한가지': 49,
#  '바라는': 15,
#  '있는데': 168,
#  '즐겨찾기': 120,
#  '신': 39,
#  '있다면': 36,
#  '좋겠어요': 443,
#  'ㅠㅠㅠ': 104,
#  '들어가는': 17,
#  '좋지만': 30,
#  '있음': 53,
#  '더욱': 18,
#  '편리할': 3,
#  '듯': 79,
#  '초창': 5,
#  '요즘': 169,
#  '이라고': 87,
#  '로딩': 229,
#  '버그': 39,
#  '자체': 117,
#  '들어가질': 6,
#  '상당히': 8,
#  '갑자기': 185,
#  '꺼지는': 11,
#  '불편할': 5,
#  '굉장히': 47,
#  '많고': 281,
#  '맨날': 61,
#  '하는데': 190,
#  '고쳐지지': 2,
#  '않는': 35,
#  '죠': 128,
#  '제발': 133,
#  '해줬으면': 8,
#  '마켓': 18,
#  '보여줘서': 11,
#  '고르기': 24,
#  '1': 132,
#  '링': 22,
#  '약한것': 1,
#  '들어': 68,
#  '아웃': 4,
#  '>': 23,
#  '패딩': 5,
#  '단계': 5,
#  '까지는': 18,
#  '조건': 13,
#  '롱패딩': 2,
#  '식': 43,
#  '보여주진': 1,
#  '하는것': 12,
#  '사이즈': 220,
#  '가능했으면': 10,
#  '온': 11,
#  ':': 29,
#  '"': 31,
#  '70': 1,
#  '80': 2,
#  '입력': 47,
#  '이요': 5,
#  '화이팅': 13,
#  '하세용': 5,
#  '짱': 403,
#  '모르면': 1,
#  '해보고': 23,
#  '사는거': 9,
#  '특히': 60,
#  '글램': 1,
#  '럭셔리': 2,
#  '오피스': 5,
#  '스타일': 236,
#  '최애': 31,
#  '만의': 7,
#  '감성': 4,
#  '알맞음': 1,
#  '가격': 664,
#  '할수있어서': 45,
#  '특정': 26,
#  '연관': 11,
#  '보여주고': 8,
#  '이런게': 13,
#  '어딨다요': 1,
#  '개발자': 44,
#  '님': 78,
#  '복': 12,
#  '받으세요': 3,
#  '품절': 178,
#  '사라지는': 2,
#  '기반': 3,
#  '선정': 7,
#  '카테고리': 174,
#  '제대로': 64,
#  '나뉘어있지': 1,
#  '않은': 31,
#  '티셔츠': 17,
#  '온갖': 4,
#  '악세': 8,
#  '서리': 6,
#  '필기구': 1,
#  '됨': 56,
#  '),': 41,
#  '걸고': 1,
#  '리스트': 21,
#  '전환': 3,
#  '갱신': 2,
#  '되며': 2,
#  '최상': 4,
#  '단': 14,
#  '올라가': 8,
#  '버리는': 10,
#  '문제점': 5,
#  '마디': 3,
#  '구림': 3,
#  '편의': 5,
#  '부족합니다': 1,
#  '오래전': 5,
#  '해': 325,
#  '왔는데': 19,
#  '달': 69,
#  '간': 36,
#  '걸리고': 69,
#  '렉': 295,
#  '걸립니다': 7,
#  '뜨는': 50,
#  'x': 28,
#  '표시': 63,
#  '누르는데': 4,
#  '계속': 511,
#  '이동': 40,
#  '뜨게': 13,
#  '없나요': 59,
#  '띄우느라': 1,
#  '느려지고': 14,
#  '들어가자마자': 6,
#  '빠르게': 41,
#  '제품': 359,
#  '수가': 52,
#  '없어서': 126,
#  '불편합니다': 44,
#  '위해': 20,
#  '하트': 62,
#  '누름과': 1,
#  '동시': 8,
#  '분류': 82,
#  '해주셨으면': 42,
#  '사이트': 260,
#  '하기를': 11,
#  '려고': 17,
#  '누르려': 2,
#  '찜함': 1,
#  '작업': 3,
#  '불편함이': 10,
#  '쓰다가': 19,
#  '×': 8,
#  '블리': 45,
#  '브랜': 7,
#  '썼었는데': 2,
#  '돌아왔습니다': 1,
#  '인터넷': 84,
#  '브랜드': 119,
#  '다양하고': 58,
#  '연결': 110,
#  '되어있어서': 26,
#  '다양한': 222,
#  '아니여도': 3,
#  '어차피': 8,
#  '비슷하게': 2,
#  '단연': 5,
#  '1등': 6,
#  '양': 9,
#  '쓰시': 4,
#  '분': 114,
#  '좋을거라고': 1,
#  '세': 102,
#  '본': 44,
#  '후기': 105,
#  '+)': 4,
#  '했던': 32,
#  '에는': 140,
#  '돌아온': 1,
#  '발견': 15,
#  '결함': 4,
#  '백': 28,
#  '라운드': 3,
#  '복귀': 1,
#  '있네요': 44,
#  '닫기로': 1,
#  '없애고': 6,
#  '열어서': 2,
#  '진입': 3,
#  '정상': 15,
#  '하단': 11,
#  '내릴': 7,
#  '움직이는': 2,
#  '살짝': 21,
#  '스': 123,
#  '크롤': 125,
#  '해주면': 9,
#  '사라지긴': 1,
#  '평소': 29,
#  '꼭': 107,
#  '고쳐졌으면': 1,
#  '겠네용': 10,
#  'ㅎㅎ': 372,
#  '여성': 47,
#  '의류': 49,
#  '큐': 2,
#  '레이': 2,
#  '션': 1,
#  '제공': 17,
#  '타사': 6,
#  '비해': 32,
#  '잘해주는': 1,
#  '느낌': 56,
#  '들지': 3,
#  '측면': 2,
#  '타': 71,
#  '주는': 26,
#  '이벤트': 123,
#  '싸게': 44,
#  '하도록': 4,
#  '유도': 7,
#  '여기는': 20,
#  '않나': 9,
#  '봐요': 26,
#  '직접': 48,
#  '할수': 119,
#  '아니라서': 12,
#  '한다는': 15,
#  '😥': 7,
#  '예쁘네요': 8,
#  '아직': 138,
#  '사보진': 5,
#  '읺았': 1,
#  '👍👍👍': 19,
#  '엄청': 170,
#  '원하는': 368,
#  '좋아용': 333,
#  '넘어갈': 5,
#  '눌렀는데': 18,
#  '찾는게': 15,
#  '그냥': 306,
#  '기본': 30,
#  '찾': 13,
#  '는걸': 19,
#  '나오더라구요': 4,
#  '찾을수': 47,
#  '갤러리': 7,
#  '또는': 11,
#  '카메라': 7,
#  '찍어서': 8,
#  '됐으면': 26,
#  '좋겠어용': 15,
#  '!!!': 94,
#  '최신': 19,
#  '상태': 58,
#  '넘어가려고': 2,
#  '자주': 249,
#  '안되고': 105,
#  '보려고': 44,
#  '내리는데': 3,
#  '지진': 1,
#  '거나': 44,
#  '아예': 109,
#  '안냐': 1,
#  '려': 10,
#  '지는': 19,
#  '종종': 18,
#  '좋습니다': 217,
#  '코': 16,
#  '아쉬운': 31,
#  '세부': 9,
#  '거슬려서': 2,
#  '그만': 16,
#  '아닙니다': 5,
#  '예나': 1,
#  '하기엔': 8,
#  '편했지만': 1,
#  '엔': 112,
#  '나빠진': 1,
#  '로고': 12,
#  '세련되면': 1,
#  '텐데': 4,
#  '숨기': 1,
#  '싶은': 48,
#  '이에요': 215,
#  '리뉴얼': 7,
#  '전이': 11,
#  '나았던': 1,
#  '싶어지는': 1,
#  '세련된': 2,
#  'pc': 26,
#  '있게': 111,
#  '늘': 20,
#  '상': 26,
#  '편리하고': 132,
#  '쉽게': 163,
#  '있단': 1,
#  '좋았습니다': 20,
#  '길게': 13,
#  '눌러': 21,
#  '아래': 31,
#  '내리면': 23,
#  '홈': 34,
#  '적용': 50,
#  '많았고': 1,
#  '색깔': 37,
#  '비슷하고': 1,
#  '완전히': 8,
#  '나와': 14,
#  '고르는데': 9,
#  '불편함을': 4,
#  '줬습니다': 2,
#  '주시': 28,
#  '편해지고': 5,
#  '어어': 8,
#  '무': 71,
#  '생겨서': 16,
#  '편하구요': 8,
#  '근데': 307,
#  '알짝': 1,
#  '아쉬운게': 6,
#  '해놓': 5,
#  '많아서': 340,
#  '기적': 5,
#  '된것': 4,
#  '씩': 128,
#  '체크': 24,
#  '하고는': 2,
#  '요것': 4,
#  '완전': 264,
#  '아무튼': 7,
#  '통해': 50,
#  '절약': 11,
#  '편하게': 128,
#  '감사합니다': 149,
#  '•': 7,
#  'v': 3,
#  'b': 16,
#  '💓': 5,
#  '대': 206,
#  '좋구': 28,
#  '순위': 32,
#  '세분': 12,
#  '화': 50,
#  '있다는': 36,
#  '장점': 49,
#  'ㅠㅅㅠ': 5,
#  '돋보기': 4,
#  '🔎': 1,
#  '탭': 22,
#  '나와요': 28,
#  '나서': 45,
#  '나갔다': 18,
#  '오면': 6,
#  '되긴': 4,
#  '3': 112,
#  '연령': 46,
#  '해지': 3,
#  '들어오면': 7,
#  '요런': 3,
#  '자잘한': 5,
#  '감사할': 1,
#  '항상': 128,
#  '😘': 12,
#  '힘내시고': 1,
#  '늦었지만': 2,
#  '새해': 2,
#  '💗': 13,
#  '살수': 84,
#  '포털': 2,
#  '나오는': 38,
#  '왠만한': 7,
#  '되는듯': 1,
#  '똑갇': 1,
#  '쓰는': 47,
#  '싼': 25,
#  '골라': 23,
#  '가능하다': 1,
#  '볼수있다': 1,
#  '리다': 14,
#  '무한': 46,
#  '떨림이': 1,
#  '일어남': 2,
#  '외': 27,
#  '공유': 15,
#  '없음': 61,
#  '데이터': 88,
#  '잡아먹음': 1,
#  '받아서': 34,
#  '3년': 6,
#  '쭉': 21,
#  '써오고있어요': 1,
#  '😊': 50,
#  '덕': 9,
#  '히': 54,
#  '정': 59,
#  '강점': 1,
#  '꼽': 1,
#  '키': 175,
#  '워드': 23,
#  '귀찮아서요': 1,
#  '😐': 1,
#  '지정': 6,
#  '",': 1,
#  '저장': 66,
#  '불러': 4,
#  '올수있는': 1,
#  '만들어주세요': 43,
#  '편리해질': 2,
#  '🤭': 1,
#  '구성': 5,
#  '전보': 8,
#  '숨겨진': 1,
#  '강하고': 1,
#  '상의': 33,
#  '하의': 16,
#  '들어가면': 117,
#  "'": 135,
#  '먼저': 17,
#  '뜨는데': 52,
#  '필요성': 3,
#  '느낀': 5,
#  '달까': 4,
#  '가방': 41,
#  '수영복': 3,
#  '해주질': 1,
#  '해주는': 35,
#  '만으로도': 7,
#  '충분한것': 1,
#  '더더': 16,
#  '시키려는': 1,
#  '의도': 14,
#  '인지': 101,
#  '눈': 75,
#  '차지': 9,
#  '않는것': 1,
#  '작게': 3,
#  '나열하지말고': 1,
#  '예전': 79,
#  '큼직하게': 1,
#  '정리': 87,
#  '가능하게만': 1,
#  '해줘도': 1,
#  '편할거': 2,
#  '했고': 14,
#  '하던': 15,
#  '점점': 41,
#  '이안': 15,
#  '가는거': 2,
#  '아이쇼핑': 20,
#  '횟수': 6,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
