# %% [markdown]
# # 리뷰 데이터 수집

# %%
# https://play.google.com/store/apps/details?id=com.musinsa.store&hl=ko-KR

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.musinsa.store",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST,
                      count=50000)

# %%
import numpy as np
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    df.to_csv(f'./data/01.리뷰키워드분석_01통합본_{name}_리뷰크롤링파일.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'무신사')

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df.dropna(subset="content",axis=0,inplace=True)

# %%
def tokenize(dataFrame):
    okt = Okt()
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    tokenize(dataFrame)
    remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <18438x5182 sparse matrix of type '<class 'numpy.int64'>'
# 	with 40608 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <18438x5182 sparse matrix of type '<class 'numpy.float64'>'
# 	with 40608 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '의상 브랜드 거기 감각 의류 지갑 드 구매 설명 조합 샷 쇼핑 해 주네 가장 할인 쇼핑 웹,위시 리스트 세부 분류 시도 찾기 찜 상품 곳 크림 항목 쉐딩제품 컨실러 항목 블러셔 보기 뷰티 항목 위시 리스트 폴더 기도 보기 분류 거,배송지 변경 비번 자꾸 오류 뜸 비번 에러 옷 어케사란겨 비번 보고 비번 에러 뜸 게 로딩 데이터 와이파이 페이지 로딩 복불복 임 재 설치 중임,셀렉 트숍 앱 적립금 옷 카테고리 별로 볼 정말 인터넷 쇼핑 입문 계기 준 앱 몇개 사용 정말 개선 매우 실용 성도 꼭 개선 로딩 속도 와이파이 속도 현저 감 로딩 속도 개선 터치 오류 가끔 터치 아마 기기 오류 수도 상세 페이지 종종 발생 터치 곳 무관 창 터치 부분 오류 발견 개선 정렬 고정 리뷰 순 판매량 순 정렬 순 걸 카테고리 걸 설정 움 개인 별로 고정 정렬 순 마지막 정렬 순 적용 꼭 업데이트 사이즈 추천 작성 후기 사이즈 추천 매우 분류,리프 레쉬 앱 앱 튕깁니 삼성 정책 어플 자체 개선 방안 후기 사진 못 사진 플러스 버튼 응용프로그램 선택 카메라 권한 팝업 계속 카메라 어플 진입,점점 업데이트 이후 버튼 위로 이동 항상 특정 화면 버튼 문제점 리뷰 업데이트 이후 꼭 가다가 부분 점수 뚝 어플 그게 사일,상품 랭킹 전체 페이지 페이지 연령 카테고리 반응 상품 클릭 옵션 작동 삭제 설치 다른사람 증상 리뷰 해결 이용,패션 스토어 어플 최근 활용 최근 어플 로딩 핸드폰 상단 바 이벤트 소식 알람 해당 사항 브랜드 한정 발매 인기 상품 재 해당 공지 소식 이동 어플 가장 최근 종료 화면 그대로 이동 사용자 컨버스 보고 어플 종료 뒤 상단 바 노출 아디다스 인기 상품 재 공지 이전 보고 컨 버스 상품 페이지 이동 오류 갑자기 발생 요것 진짜 퍼펙트 완벽 어플 자체,업데이트 편리 성은 퇴화 느낌 이전 눈 랭킹 자주 기능 버튼 볼 파격 쿠폰 뭐 사용 맘 제품 그냥 상품 사라 건가 예전 사가,인스타 역 시즌 기획전 광고 렉 구경 못 위쪽 카테고리 로딩 뒤쪽 액세서리 구경 클릭 앱 자체 마비 버튼 소용 앱 기획전 검색 옷 무한 로딩 그냥 앱 정상 작동 기획전 보라,업데이트 후기 작성 짐 원래 후기 작성 카메라 실행 갤러리 실행 선택 갤러리 선택 선택 사진 얼굴 앱 편집 기능 편집 사진 기능 이해 불가,호감 순 하트 나열 젠 판매량 광고 상품 랭킹 위 렀습 평소 랭킹 순 추천 순은 걸렀는데 최근 스포츠 랭킹 한번 아쉬움 항상 애용 반영 참고,신사 여러 제품 한번 옷 보고 비교 구매 첫 화면 구매 창 보이지 사항 신경 개선,편의 아주 사용 화면 거래 옷 여러가지 패션 의류 스킨 로션 질 제품 자주 이용 아이템 구성 눈 쇼핑 매우 계속 이용 감사,스타일 탭 하트 기능 사진 후루룩 사진 클릭 위치 위 계속 인스타 사진 꾹 사진 크게 하트 기능,패션 스토어 어플 최근 활용 최근 어플 로딩 패션 트 레드 성향 스타일 제안 옷 선택 도움 적립금 쿠폰 사용 할인 단 구입 제품 세용 마켓 쇼핑몰,실 기능 정말 자주 사용 앱 앱 월간 사용 유저 로서 추가 기능 후기 옵션 별로 볼 상품 여러 옵션 구매 옵션 후기 볼 기능 후기 필터 선택 키별 필터 몸무게 별 필터 선택 선택 부분,브랜드 폭 매우 참여 이벤트 일리 추천 아이템 조합 추천 기능 개인 도매 스틱 브랜드 제외 브랜드 부재 패 진입 장벽 높이 평가 이름,앱 업뎃전 기능 후기 작성 시 카메라 갤러리 회전 편집 기능 문의 폰 어플 삭제 마찬가지 정말 구글 글 안드로이드 버전 확인 리부팅 삭제 재 설치 반복 마찬가지,웹사이트 대체 로그아웃 버튼 마이 하단 정말 혁신 기능 사용자 제공 웹 앱 터 부분 보이지 로그아웃 버튼 설정 한참 항상 업데이트 업데이트 핀트 어긋나게 로그아웃 버튼 뭐 로그아웃 빈도 예전 설정 로그아웃 버튼 설정 로그아웃 버튼 한참 사용자 장난 치 로그아웃 위치 명시 해주시,예전 업데이트 뒤 뒤 가기 오류 가장 최근 버전 해결 앱 현상 폰 항상 처음 군데 갤럭시 화면 하단 뒤 가기 터치 인식 뒤 화면 위 모양 뒤 가기 버튼 마찬가지 정말 해결 방법,브랜드 검색 대부분 주문 반품 교환 반품 교환 처음 앱 검색 버튼 밑 위 추천 랭킹,폴더 기능 가요 애 바 아예 컴퓨터 폴더 폴더 폴더 느낌 버그 결벽증 진짜 폴더 기능 업그레이드,업데이트 이후 창 상품 뒤 가기 곳 맨 위로 화면 볼때 일일 아래 업데이트 이후 기능,앱 자체 랙 폰 종 나름 최신기종 앱 사용 시 램 용량 최적화 상태 웹사이트 앱 완전 최악 키 보드 렉 앱 랙 앱,애플리케이션 발전 게 결제 부분 체감 부분 가끔 카카오 톡 네이버 베너 마음 코디 확인 이벤트 메인 화면 링크 게 해당 코디 링크 이벤트 메인 화면 해당 아이템 찾기 가끔 마음 옷 게,상품 가격 구매 자주 애용 스타일 후기 상품 사진 후기 필터 링 성별 키 몸무게 보고 후기 볼 사이즈 추천 검색 표현 아쉬움,앱 블프때 특가 상품 무 통장 입금 결제 후기 사이트 가보 정가 표기 할인 율 주문 취소 취소 사유 선택 게 변심 정가 확인,패션 트 레드 성향 스타일 제안 옷 선택 도움 적립금 쿠폰 사용 할인 단 구입 사가 정 할인 율 할인 쿠폰 적용 일부 상품 할인 쿠폰 사용 제외 보유 적립금 사용 제외 적립금 제외,제발 오류 랭킹 검색 옷 뒤 가기 먹통 이해 수가 인원 사용 어플 대면 진짜 복 치질 뒤 가기 아예 먹통 어플 수고 옷 상세 마다 껏 어플 고치 고객 개선 진짜,선택 장애 진짜 가성 비 옷 기모 분할 기능,최근 건 결제 실 소비 액 연말 결산 브랜드 공식 홈페이지 컨셉 타 플랫폼 결제 금액 배 가까이 여러 브랜드 입점 건 과도 상품 찾기 스포츠 볼캡 사고 카테고리 스포츠 모자 여성 라바 퀄리티 니즈 의류 컨셉 스타일 타 플랫폼 손 거 사용 빈도 점점 유 신사 안녕,사용자 커뮤니티 리뷰 옷 살때 비교 리뷰 미션 참여 포인트 옷 수도 브랜드 리뷰 제품 제대로 제품 정보,목록 카테고리 분류 정신 제품 찾기 크게 분류 순서도 고정,상품 여러 연령 층 사용 의류 세탁,업뎃만하 쓰레기 앱 옷 사고 시스템 무진장 블프하 버러지 터치 옷살때 계산기 앱 자꾸 창 앱 진짜 억 제대로 함 업뎃할거 제대로 해,란 세부 카테고리 로만 분류 업뎃 이전 란 처음 화면 분류 구분 분류 하위 분류 식 분류,최근 갑자기 버벅거리 감당 폰 앱 전혀 현상 고요,업데이트 링크 어플 연동 재 설치,상품 이전 가면 상단 상품 쭉,핏이 핏 품질 품질 마음 재고,결제 갑자기 품절 취소 시스템 품절 결제 결제 취소 하필 이면 주말 옷 돈 적립금 적립금 못 제한 보상,음 옷 스타일 재 스타일 착용 뭔가 돈 옷 판매 앱,브랜드 브랜드 카테고리 별로 분류 일일이 검색어 움 삭제,카카오 그대로 앱 보기 뒤 가기 시작 스 크롤 재미,옷 주문 옷 이월 상품 산옷 밭 상관 옷 나중 주문,사용자 과실 앱 오류로 이벤트 진행 적립금 못 문의 복구 보상 이벤트 종료 처리,옷 유행 아이템 판매 소비자 온라인쇼핑 앱 옷 패션 강추,스타 일일 제품 관련 상품 가격 선택 정말 관리자 재임,옷 기능 화면 전환,목록 카테고리 묶여서 세부 목록 줄줄이 찾기,의류 신발 남성 성용 필터 링 카테고리 관심 상품,출고 지연 미리 도착 예정 한참 뒤 출고 지연 메세지 띡,홈 정상 창 화면 건가 삭제 재 설치,네이버 제품 스타 일링 사진 정말 거,자주 사용 근래 창 뭐 앱 삭제,앱 자주 오류 문의 대응,최근 로딩 최근 로딩,리프 레쉬 심해 어플 메인 화면 돌 아강,리뷰 사진 어플 업데이트 앱 사진 편집 기능 직관 눈 젠 기 방향 전환 어플,쿠폰 낚시 쿠폰 상품 못 못 쿠폰 상품 사진 확대 글씨 칸 확대 축소 사진 스 크롤 반복 확대 축소 요것 원래,계속 오류 앱 자체 점점 리프 레쉬 반복 예전 시절 비 차이 역시 점점 항목 반대 흰색 위주 컬러링 눈 피로 배터리 액정 수명 전체 디자인 레이아웃 고객 친 느낌 사가 광고 컨텐츠 위주 배열 쇼핑 낭비 발생 찜 제품 필수 구석 진 곳 관심 서비스 중심 따름 적립금 적용 비율 날 장바구니 상품 적립금 비율 쿠폰 적용 갈수록 쿠폰 적용 해당 브랜드 문의 브랜드 측 쿠폰 적용 측 검색 이슈 해결 검색어 전혀 제품 검색 건,브랜드 의미 연결 테마 보기 웹디자인 마음 옷 좀더 사만 디자인 곁 옷 판매 바램 예시 트렌디 테마 베이직  ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'의상': 8,
#  '브랜드': 444,
#  '거기': 19,
#  '감각': 6,
#  '의류': 73,
#  '지갑': 8,
#  '드': 36,
#  '구매': 507,
#  '설명': 60,
#  '조합': 4,
#  '샷': 11,
#  '쇼핑': 362,
#  '해': 183,
#  '주네': 7,
#  '가장': 51,
#  '할인': 447,
#  '웹': 38,
#  '위시': 4,
#  '리스트': 8,
#  '세부': 5,
#  '분류': 52,
#  '시도': 11,
#  '찾기': 101,
#  '찜': 9,
#  '상품': 700,
#  '곳': 194,
#  '크림': 5,
#  '항목': 8,
#  '쉐딩': 1,
#  '제품': 458,
#  '컨실러': 1,
#  '블러셔': 1,
#  '보기': 201,
#  '뷰티': 3,
#  '폴더': 12,
#  '기도': 16,
#  '거': 271,
#  '배송지': 14,
#  '변경': 23,
#  '비번': 26,
#  '자꾸': 107,
#  '오류': 154,
#  '뜸': 18,
#  '에러': 30,
#  '옷': 1482,
#  '어케사란겨': 1,
#  '보고': 136,
#  '게': 67,
#  '로딩': 97,
#  '데이터': 18,
#  '와이파이': 15,
#  '페이지': 114,
#  '복불복': 4,
#  '임': 122,
#  '재': 54,
#  '설치': 83,
#  '중임': 4,
#  '셀렉': 8,
#  '트숍': 3,
#  '앱': 1085,
#  '적립금': 130,
#  '카테고리': 106,
#  '별로': 284,
#  '볼': 113,
#  '정말': 230,
#  '인터넷': 51,
#  '입문': 8,
#  '계기': 3,
#  '준': 15,
#  '몇개': 10,
#  '사용': 642,
#  '개선': 94,
#  '매우': 99,
#  '실용': 6,
#  '성도': 4,
#  '꼭': 37,
#  '속도': 54,
#  '현저': 1,
#  '감': 35,
#  '터치': 21,
#  '가끔': 47,
#  '아마': 7,
#  '기기': 9,
#  '수도': 11,
#  '상세': 37,
#  '종종': 10,
#  '발생': 18,
#  '무관': 2,
#  '창': 78,
#  '부분': 46,
#  '발견': 10,
#  '정렬': 21,
#  '고정': 7,
#  '리뷰': 219,
#  '순': 53,
#  '판매량': 2,
#  '걸': 62,
#  '설정': 39,
#  '움': 46,
#  '개인': 27,
#  '마지막': 6,
#  '적용': 64,
#  '업데이트': 225,
#  '사이즈': 225,
#  '추천': 153,
#  '작성': 34,
#  '후기': 208,
#  '리프': 7,
#  '레쉬': 7,
#  '튕깁': 1,
#  '삼성': 2,
#  '정책': 21,
#  '어플': 549,
#  '자체': 101,
#  '방안': 4,
#  '사진': 99,
#  '못': 98,
#  '플러스': 5,
#  '버튼': 68,
#  '응용프로그램': 1,
#  '선택': 116,
#  '카메라': 4,
#  '권한': 4,
#  '팝업': 14,
#  '계속': 252,
#  '진입': 6,
#  '점점': 44,
#  '이후': 58,
#  '위로': 11,
#  '이동': 16,
#  '항상': 142,
#  '특정': 19,
#  '화면': 130,
#  '문제점': 3,
#  '가다가': 1,
#  '점수': 5,
#  '뚝': 4,
#  '그게': 16,
#  '사일': 1,
#  '랭킹': 36,
#  '전체': 48,
#  '연령': 9,
#  '반응': 9,
#  '클릭': 42,
#  '옵션': 17,
#  '작동': 9,
#  '삭제': 300,
#  '다른사람': 4,
#  '증상': 2,
#  '해결': 68,
#  '이용': 386,
#  '패션': 208,
#  '스토어': 72,
#  '최근': 54,
#  '활용': 15,
#  '핸드폰': 17,
#  '상단': 12,
#  '바': 21,
#  '이벤트': 199,
#  '소식': 9,
#  '알람': 22,
#  '해당': 29,
#  '사항': 22,
#  '한정': 6,
#  '발매': 1,
#  '인기': 31,
#  '공지': 12,
#  '종료': 20,
#  '그대로': 15,
#  '사용자': 66,
#  '컨': 5,
#  '버스': 4,
#  '뒤': 105,
#  '노출': 10,
#  '아디다스': 6,
#  '이전': 26,
#  '갑자기': 73,
#  '요것': 2,
#  '진짜': 312,
#  '퍼펙트': 1,
#  '완벽': 7,
#  '편리': 12,
#  '성은': 5,
#  '퇴화': 9,
#  '느낌': 65,
#  '눈': 38,
#  '자주': 193,
#  '기능': 142,
#  '파격': 7,
#  '쿠폰': 659,
#  '뭐': 225,
#  '맘': 89,
#  '그냥': 265,
#  '사라': 14,
#  '건가': 46,
#  '예전': 62,
#  '사가': 71,
#  '인스타': 4,
#  '역': 21,
#  '시즌': 4,
#  '기획전': 7,
#  '광고': 154,
#  '렉': 117,
#  '구경': 19,
#  '위쪽': 1,
#  '뒤쪽': 1,
#  '액세서리': 1,
#  '마비': 1,
#  '소용': 2,
#  '검색': 219,
#  '무한': 13,
#  '정상': 10,
#  '보라': 2,
#  '짐': 25,
#  '원래': 32,
#  '실행': 35,
#  '갤러리': 9,
#  '얼굴': 6,
#  '편집': 37,
#  '이해': 35,
#  '불가': 13,
#  '호감': 2,
#  '하트': 12,
#  '나열': 7,
#  '젠': 32,
#  '위': 67,
#  '렀습': 1,
#  '평소': 11,
#  '순은': 3,
#  '걸렀는데': 1,
#  '스포츠': 6,
#  '한번': 107,
#  '아쉬움': 11,
#  '애용': 110,
#  '반영': 10,
#  '참고': 53,
#  '신사': 164,
#  '여러': 67,
#  '비교': 89,
#  '첫': 22,
#  '보이지': 8,
#  '신경': 24,
#  '편의': 30,
#  '아주': 220,
#  '거래': 11,
#  '여러가지': 48,
#  '스킨': 1,
#  '로션': 1,
#  '질': 68,
#  '아이템': 32,
#  '구성': 19,
#  '감사': 16,
#  '스타일': 135,
#  '탭': 11,
#  '후루룩': 1,
#  '위치': 4,
#  '꾹': 7,
#  '크게': 23,
#  '트': 27,
#  '레드': 2,
#  '성향': 3,
#  '제안': 13,
#  '도움': 55,
#  '단': 13,
#  '구입': 84,
#  '세용': 2,
#  '마켓': 6,
#  '쇼핑몰': 159,
#  '실': 30,
#  '월간': 1,
#  '유저': 17,
#  '로서': 10,
#  '추가': 47,
#  '필터': 45,
#  '키별': 1,
#  '몸무게': 10,
#  '별': 146,
#  '폭': 27,
#  '참여': 10,
#  '일리': 4,
#  '도매': 4,
#  '스틱': 3,
#  '제외': 28,
#  '부재': 3,
#  '패': 19,
#  '장벽': 3,
#  '높이': 1,
#  '평가': 14,
#  '이름': 38,
#  '업뎃전': 2,
#  '시': 64,
#  '회전': 5,
#  '문의': 200,
#  '폰': 59,
#  '마찬가지': 11,
#  '구글': 8,
#  '글': 46,
#  '안드로이드': 9,
#  '버전': 31,
#  '확인': 117,
#  '리부팅': 1,
#  '반복': 29,
#  '웹사이트': 14,
#  '대체': 31,
#  '로그아웃': 31,
#  '마이': 13,
#  '하단': 14,
#  '혁신': 5,
#  '제공': 24,
#  '터': 12,
#  '한참': 12,
#  '핀트': 1,
#  '어긋나게': 1,
#  '빈도': 4,
#  '장난': 34,
#  '치': 18,
#  '명시': 3,
#  '해주시': 11,
#  '가기': 66,
#  '현상': 12,
#  '처음': 136,
#  '군데': 3,
#  '갤럭시': 17,
#  '인식': 6,
#  '모양': 24,
#  '방법': 21,
#  '대부분': 24,
#  '주문': 113,
#  '반품': 87,
#  '교환': 124,
#  '밑': 11,
#  '가요': 58,
#  '애': 30,
#  '아예': 33,
#  '컴퓨터': 7,
#  '버그': 25,
#  '결벽증': 1,
#  '업그레이드': 1,
#  '맨': 9,
#  '볼때': 18,
#  '일일': 6,
#  '아래': 13,
#  '랙': 5,
#  '종': 4,
#  '나름': 23,
#  '최신기종': 1,
#  '램': 2,
#  '용량': 5,
#  '최적화': 40,
#  '상태': 32,
#  '완전': 52,
#  '최악': 146,
#  '키': 40,
#  '보드': 3,
#  '애플리케이션': 1,
#  '발전': 25,
#  '결제': 170,
#  '체감': 3,
#  '카카오': 8,
#  '톡': 6,
#  '네이버': 45,
#  '베너': 3,
#  '마음': 65,
#  '코디': 77,
#  '메인': 41,
#  '링크': 15,
#  '가격': 386,
#  '링': 16,
#  '성별': 43,
#  '표현': 22,
#  '블프때': 4,
#  '특': 19,
#  '무': 75,
#  '통장': 10,
#  '입금': 27,
#  '사이트': 144,
#  '가보': 3,
#  '정가': 9,
#  '표기': 8,
#  '율': 20,
#  '취소': 60,
#  '사유': 3,
#  '변심': 3,
#  '정': 17,
#  '일부': 6,
#  '보유': 3,
#  '제발': 84,
#  '먹통': 14,
#  '수가': 37,
#  '인원': 4,
#  '대면': 1,
#  '복': 20,
#  '치질': 1,
#  '수고': 61,
#  '마다': 6,
#  '껏': 9,
#  '고치': 8,
#  '고객': 310,
#  '장애': 2,
#  '가성': 87,
#  '비': 116,
#  '기모': 2,
#  '분할': 1,
#  '건': 75,
#  '소비': 14,
#  '액': 1,
#  '연말': 1,
#  '결산': 1,
#  '공식': 12,
#  '홈페이지': 23,
#  '컨셉': 8,
#  '타': 26,
#  '플랫폼': 41,
#  '금액': 14,
#  '배': 23,
#  '가까이': 8,
#  '입점': 28,
#  '과도': 1,
#  '볼캡': 1,
#  '사고': 51,
#  '모자': 8,
#  '여성': 116,
#  '라바': 1,
#  '퀄리티': 47,
#  '손': 32,
#  '유': 17,
#  '안녕': 15,
#  '커뮤니티': 16,
#  '살때': 21,
#  '미션': 4,
#  '포인트': 63,
#  '제대로': 80,
#  '정보': 115,
#  '목록': 29,
#  '정신': 28,
#  '순서도': 1,
#  '층': 59,
#  '세탁': 4,
#  '업뎃': 40,
#  '만하': 12,
#  '쓰레기': 107,
#  '시스템': 64,
#  '무진장': 8,
#  '블프하': 1,
#  '버러지': 4,
#  '옷살때': 20,
#  '계산기': 5,
#  '억': 1,
#  '함': 142,
#  '업뎃할거': 1,
#  '란': 16,
#  '로만': 12,
#  '구분': 18,
#  '하위': 3,
#  '식': 36,
#  '버벅': 11,
#  '거리': 14,
#  '감당': 4,
#  '전혀': 19,
#  '고요': 10,
#  '연동': 2,
#  '가면': 13,
#  '쭉': 14,
#  '핏': 24,
#  '품질': 127,
#  '재고': 48,
#  '품절': 63,
#  '하필': 1,
#  '이면': 14,
#  '주말': 19,
#  '돈': 167,
#  '제한': 22,
#  '보상': 11,
#  '음': 48,
#  '착용': 17,
#  '뭔가': 25,
#  '판매': 67,
#  '일일이': 4,
#  '검색어': 7,
#  '시작': 46,
#  '스': 32,
#  '크롤': 26,
#  '재미': 18,
#  '이월': 3,
#  '산옷': 2,
#  '밭': 1,
#  '상관': 2,
#  '나중': 9,
#  '과실': 3,
#  '오류로': 6,
#  '진행': 27,
#  '복구': 5,
#  '처리': 118,
#  '유행': 15,
#  '소비자': 101,
#  '온라인쇼핑': 5,
#  '강추': 13,
#  '스타': 25,
#  '관련': 43,
#  '관리자': 10,
#  '재임': 1,
#  '전환': 16,
#  '묶여서': 1,
#  '줄줄이': 1,
#  '신발': 41,
#  '남성': 176,
#  '성용': 4,
#  '관심': 43,
#  '출고': 50,
#  '지연': 31,
#  '미리': 8,
#  '도착': 24,
#  '예정': 19,
#  '메세지': 4,
#  '띡': 2,
#  '홈': 37,
#  '일링': 14,
#  '근래': 3,
#  '대응': 49,
#  '심해': 16,
#  '돌': 2,
#  '아강': 1,
#  '직관': 39,
#  '기': 22,
#  '방향': 8,
#  '낚시': 13,
#  '확대': 9,
#  '글씨': 3,
#  '칸': 8,
#  '축소': 3,
#  '시절': 7,
#  '차이': 14,
#  '역시': 86,
#  '반대': 6,
#  '흰색': 4,
#  '위주': 15,
#  '컬러링': 1,
#  '피로': 3,
#  '배터리': 2,
#  '액정': 1,
#  '수명': 1,
#  '디자인': 74,
#  '레이아웃': 2,
#  '친': 10,
#  '컨텐츠': 10,
#  '배열': 2,
#  '낭비': 3,
#  '필수': 17,
#  '구석': 1,
#  '진': 11,
#  '서비스': 102,
#  '중심': 5,
#  '따름': 3,
#  '비율': 6,
#  '날': 35,
#  '장바구니': 59,
#  '갈수록': 18,
#  '이슈': 22,
#  '의미': 12,
#  '연결': 50,
#  '테마': 5,
#  '웹디자인': 5,
#  '좀더': 20,
#  '사만': 30,
#  '곁': 1,
#  '바램': 2,
#  '예시': 2,
#  '트렌디': 15,
#  '베이직': 3,
#  '템': 18,
#  '전략': 4,
#  '의견': 15,
#  '물품': 25,
#  '뉴비': 4,
#  '혜택': 120,
#  '모음': 3,
#  '배송': 545,
#  '대비': 13,
#  '현재': 26,
#  '몇번': 23,
#  '버퍼링': 13,
#  '켜': 6,
#  '코디샷': 2,
#  '통째': 1,
#  '저장': 12,
#  '분': 40,
#  '보구': 3,
#  '품목': 27,
#  '휜색': 1,
#  '셔츠': 9,
#  '배경': 5,
#  '도저히': 5,
#  '끌': 2,
#  '엄슴': 2,
#  '새': 5,
#  '소통': 8,
#  '한눈': 47,
#  '소규모': 1,
#  '온라인': 72,
#  '쿠팡': 9,
#  '큐': 3,
#  '레이': 4,
#  '션': 4,
#  '시기': 5,
#  '패린': 2,
#  '슆': 1,
#  '배달': 13,
#  '합리': 32,
#  '최신': 19,
#  '트렌드': 22,
#  '기준': 26,
#  '오늘': 38,
#  '사면': 18,
#  '일해': 8,
#  '기간': 14,
#  '게임': 8,
#  '급': 5,
#  '불': 14,
#  '제일': 61,
#  '모든': 48,
#  '물건': 136,
#  '긍정': 1,
#  '팔고': 14,
#  '일방': 5,
#  '통보': 7,
#  '환불': 214,
#  '이기': 18,
#  '사업': 14,
#  '번창': 40,
#  '행사': 24,
#  '요청': 31,
#  '최고': 364,
#  '듯': 93,
#  '정신사': 2,
#  '디테': 8,
#  '볼라': 1,
#  '이제': 139,
#  '뭐함': 6,
#  '확인가능': 4,
#  '배치': 2,
#  '관리': 78,
#  '방식': 17,
#  '효율': 3,
#  '색깔': 9,
#  '소프트웨어': 2,
#  '입력': 39,
#  '구동': 4,
#  '강제': 20,
#  '이건': 27,
#  '초기': 10,
#  '처': 12,
#  '대처': 60,
#  '엉망': 19,
#  '진창': 2,
#  '피해': 5,
#  '대한': 64,
#  '잘못': 24,
#  '후속': 8,
#  '조취': 1,
#  '하든': 3,
#  '호환성': 2,
#  '이미지': 56,
#  '업로드': 4,
#  '신상': 15,
#  '쇼케이스': 5,
#  '룩북': 10,
#  '접근': 4,
#  '백화점': 11,
#  '살수': 55,
#  '조정': 2,
#  '거지': 15,
#  '이용자': 22,
#  '상대': 2,
#  '종류': 106,
#  '안해': 30,
#  '간만': 3,
#  '대서': 6,
#  '김': 3,
#  '코': 21,
#  '디도': 11,
#  '기장': 3,
#  '난': 30,
#  '대박': 22,
#  '살짝': 18,
#  '다양성': 6,
#  '무료': 67,
#  '맘에듭': 2,
#  '정리': 66,
#  '에드': 15,
#  '빠륵': 1,
#  '금도': 2,
#  '청소년': 4,
#  '은근': 5,
#  '마땅치': 1,
#  '무척': 4,
#  '이유': 102,
#  '모델': 36,
#  '과장': 3,
#  '장갑': 2,
#  '메이크업': 2,
#  '장식': 2,
#  '단점': 14,
#  '주일': 7,
#  '정작': 11,
#  '굿굿': 170,
#  '가입': 123,
#  '응원': 26,
#  '헤택': 1,
#  '나용': 2,
#  '가겍': 1,
#  '대별': 4,
#  '하라': 33,
#  '질도': 15,
#  '아들': 38,
#  '아빠': 6,
#  '싼값': 1,
#  '응대': 29,
#  '센터': 69,
#  '응답': 11,
#  '전화': 43,
#  '이주': 2,
#  '접수': 8,
#  '굿': 1421,
#  '초이스': 5,
#  '골': 10,
#  '최대한': 6,
#  '휴대폰': 21,
#  '투자': 9,
#  '세월': 3,
#  '혈압': 2,
#  '목끝': 1,
#  '늙은이': 2,
#  '빨림': 1,
#  '무난': 37,
#  '꽤': 20,
#  '상술': 3,
#  '레트로': 1,
#  '신청': 49,
#  '라며': 3,
#  '랍': 3,
#  '버벅일': 1,
#  '도대체': 19,
#  '플래그': 1,
#  '빨': 28,
#  '주시': 11,
#  '뮬건': 1,
#  '과정': 11,
#  '메뉴': 29,
#  '에이': 8,
#  '블리': 4,
#  '바지': 35,
#  '답변': 153,
#  '감격': 1,
#  '덕분': 48,
#  '세': 25,
#  '재질': 19,
#  '딸': 10,
#  '티셔츠': 9,
#  '듸자': 1,
#  '심플': 9,
#  '고급': 6,
#  '지고': 2,
#  '편안함': 2,
#  '후드': 14,
#  '티': 33,
#  '연관': 3,
#  '크롭': 1,
#  '모자이크': 1,
#  '요즘': 82,
#  '굳이': 40,
#  '필요': 31,
#  '상처': 1,
#  '운': 7,
#  '신규가입': 8,
#  '분명': 11,
#  '직원': 33,
#  '저녁': 4,
#  '사과': 86,
#  '맘때': 1,
#  '거주지': 1,
#  '법도': 2,
#  '물어': 3,
#  '그거': 29,
#  '답': 54,
#  '가게': 5,
#  '산': 17,
#  '뿌리': 11,
#  '남친': 4,
#  '땜': 3,
#  '모로': 10,
#  '쓰기': 46,
#  '싼마이': 1,
#  '피드백': 13,
#  '뻥튀기': 3,
#  '기침': 1,
#  '평상시': 1,
#  '깜깜': 1,
#  '무소식': 1,
#  '택배': 81,
#  '직접': 27,
#  '어의': 1,
#  '싸구려': 5,
#  '코디맵': 3,
#  '즐겨찾기': 2,
#  '카드': 92,
#  '발급': 10,
#  '제약': 1,
#  '순위': 11,
#  '사서': 17,
#  '뽀대': 1,
#  '의사': 1,
#  '릏': 1,
#  '주로': 3,
#  '뎁스': 1,
#  '적도': 6,
#  '스텝': 1,
#  '불만': 21,
#  '젠더': 11,
#  '흐름': 1,
#  '입': 24,
#  '득템': 20,
#  '천': 2,
#  '수단': 5,
#  '만족': 62,
#  '근본': 6,
#  '뭐임': 2,
#  '개발자': 23,
#  '화장실': 2,
#  '쇼핑카트': 1,
#  '기분': 24,
#  '색상': 27,
#  '벌': 11,
#  '사정': 3,
#  '개별': 8,
#  '합': 8,
#  '배송비': 40,
#  '무게': 3,
#  '부피': 1,
#  '상담': 36,
#  '수준': 23,
#  '일주일': 31,
#  '장문': 1,
#  '토스': 7,
#  '일부러': 9,
#  '선착순': 7,
#  '며': 3,
#  '마감': 1,
#  '해논': 3,
#  '하자': 9,
#  '마자': 1,
#  '개뭐': 1,
#  '님들': 5,
#  '뻘': 2,
#  '휴대폰결제': 1,
#  '주민등록': 1,
#  '번호': 42,
#  '더더': 1,
#  '무니': 1,
#  '전보': 5,
#  '위장': 1,
#  '낚시질': 3,
#  '멋대로': 8,
#  '사기': 83,
#  '신고': 4,
#  '기존': 20,
#  '표시': 14,
#  '습': 35,
#  '트래픽': 2,
#  '그동안': 31,
#  '세번': 5,
#  '편': 21,
#  '허리': 2,
#  '숨': 1,
#  '확정': 8,
#  '도해': 1,
#  '대체로': 9,
#  '된거': 13,
#  '오른쪽': 1,
#  '가독성': 12,
#  '겉멋': 1,
#  '영진': 1,
#  '사전': 4,
#  '검토': 2,
#  '등급': 22,
#  '부티크': 4,
#  '솔드아웃': 9,
#  '계정': 27,
#  '로그인': 141,
#  '다운': 46,
#  '아아': 4,
#  '회원': 143,
#  '어케해': 1,
#  '품': 10,
#  '책정': 1,
#  '후려': 1,
#  '치기': 4,
#  '급식': 2,
#  '성인': 4,
#  '종합': 2,
#  '연예인': 4,
#  '콘서트': 2,
#  '번열': 1,
#  '서버': 64,
#  '난리': 3,
#  '테러': 8,
#  '티켓': 1,
#  '예매': 1,
#  '인터파크': 1,
#  '애초': 12,
#  '증설': 1,
#  '유지비': 1,
#  '소리': 16,
#  '신지': 1,
#  '접속': 85,
#  '상식': 7,
#  '새로고침': 25,
#  '소개': 9,
#  '빅세일': 1,
#  '자동': 41,
#  '고려': 7,
#  '다기': 2,
#  '여자도': 1,
#  '응모': 16,
#  '랜덤': 16,
#  '천명': 2,
#  '회사': 113,
#  '내부': 6,
#  '저번': 25,
#  '조잡': 4,
#  '골프': 7,
#  '페이': 30,
#  '크루': 3,
#  '본인': 38,
#  '강점': 4,
#  '인지': 12,
#  '기억': 7,
#  '본의': 1,
#  '실수': 51,
#  '번은': 11,
#  '대중': 3,
#  '번의': 1,
#  '의사결정': 2,
#  '자정작용': 1,
#  '결과': 11,
#  '외부': 2,
#  '공개': 3,
#  '대체재': 9,
#  '분야': 1,
#  '특성': 3,
#  '댓글': 39,
#  '모습': 18,
#  '남': 98,
#  '과거': 4,
#  '퍼만되': 1,
#  '무탠': 41,
#  '다드': 46,
#  '이자': 5,
#  '체헝별': 1,
#  '선호': 5,
#  '고민': 16,
#  '인터페이스': 45,
#  '미형': 1,
#  '스냅': 14,
#  '입장': 39,
#  '최소한': 1,
#  '배려': 6,
#  '업': 84,
#  '상사면': 1,
#  '다해': 3,
#  '클라스': 2,
#  '알림': 64,
#  '니트': 2,
#  '뿐': 12,
#  '요한': 7,
#  '정품': 12,
#  '연락': 43,
#  '사하': 3,
#  '공유': 4,
#  '목적': 3,
#  '머리': 17,
#  '발끝': 3,
#  '젛겠습니당': 1,
#  '데스크탑': 1,
#  '리뉴얼': 2,
#  '출시': 3,
#  '이제야': 8,
#  '후회': 13,
#  '차례': 1,
#  '걱정': 8,
#  '여타': 2,
#  '감동': 3,
#  '경이': 2,
#  '류': 4,
#  '도메': 5,
#  '유지': 23,
#  '어제': 12,
#  '순간': 11,
#  '수정': 40,
#  '츄': 2,
#  '천인': 1,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
