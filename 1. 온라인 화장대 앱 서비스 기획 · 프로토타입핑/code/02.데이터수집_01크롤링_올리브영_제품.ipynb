# %% [markdown]
# ---
# # 올리브영 제품군 크롤링
# * 크림: https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=100000100010015&fltDispCatNo=&prdSort=01&pageIdx=3
# * 로션: https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=100000100010016&fltDispCatNo=&prdSort=01&pageIdx=3
# * 스킨: https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=100000100010013&fltDispCatNo=&prdSort=01&pageIdx=3
# * 에센스앰플: https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=1000001000100140001&fltDispCatNo=&prdSort=01&pageIdx={page}
# ---

# %%
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
from bs4 import BeautifulSoup
import requests
import time
from selenium.webdriver.support import expected_conditions as EC
from selenium.webdriver.support.ui import WebDriverWait

# %% [markdown]
# # 전체 페이지

# %%
service = Service()
options = webdriver.ChromeOptions()
driver = webdriver.Chrome(service=service,options=options)

time.sleep(0.2)

prd_items = []
prd_brands = []
prd_names = []
prd_prices = []
prd_infos = []
prd_thumbs = [] 
try: 
    for page in range(1, 3):
        url = f"https://www.oliveyoung.co.kr/store/display/getMCategoryList.do?dispCatNo=100000100010015&fltDispCatNo=&prdSort=01&pageIdx={page}"
        driver.get(url)

        time.sleep(1.0)
        prd_list = driver.find_element(By.ID,"Contents")
        # prd = prd_list.find_element(By.CLASS_NAME,"cate_prd_list")      # 한 페이지에 이 클래스 이름을 가진 ul이 여러 개고 그 ul마다 각각 상품 네개씩 있음
        prd = prd_list.find_elements(By.CLASS_NAME,"prd_info")              # 그냥 바로 상품 각각 찾기

        for i in range(len(prd)):
            prds = driver.find_elements(By.CLASS_NAME, "prd_info")  # Refresh the list of prd elements
            each_prd = prds[i]
            each_prd.click()

            info_btn = WebDriverWait(driver, 10).until(EC.element_to_be_clickable((By.ID, "buyInfo")))
            info_btn.click()

            prd_items = driver.find_element(By.CLASS_NAME, "right_area")
            prd_brands.append(prd_items.find_element(By.ID, "moveBrandShop").text)    
            prd_name = prd_items.find_element(By.CLASS_NAME, "prd_name").text
            prd_names.append(prd_name)
            prd_prices.append(prd_items.find_element(By.CLASS_NAME, "price").text.split('\n')[0])
            
            
            prd_images_area = driver.find_element(By.ID, "prd_thumb_list")
            thumbs = prd_images_area.find_elements(By.TAG_NAME, "li")
            imageNames = []
            for idx, li in enumerate(thumbs):
                
                imgs = li.find_element(By.TAG_NAME, "img")
                imgsrc = imgs.get_attribute("src")
                imgres = requests.get(imgsrc)

                imageName = f"./prdimgs/page_{page}_prd_{i}_thumb{idx + 1}.jpg"
                with open(imageName, "wb") as f:
                    f.write(imgres.content)
                imageNames.append(imageName)
                
            prd_thumbs.append(imageNames)
            prd_info = WebDriverWait(driver,10).until(EC.visibility_of_element_located((By.ID, "artcInfo")))
            prd_infos.append(prd_info.text.split("\n"))
            driver.back()
            time.sleep(0.2)
finally:
    driver.quit()

# %%
# page=2까지
import pandas as pd
cream = pd.DataFrame({"제품명":prd_names, "브랜드":prd_brands, "가격":prd_prices,'상품정보':prd_infos,'썸네일':prd_thumbs})
cream
# Out:
#                                                   제품명     브랜드      가격  \
# 0                   [NEW/리뷰이벤트] 에스트라 아토베리어365 크림 80ml    에스트라  33,000
# 1   라로슈포제 시카플라스트 밤B5+ 200ml 기획 (+시카토너 50ml+시카밤 3ml...   라로슈포제  68,000
# 2       [2세대 천만크림] 닥터지 레드 블레미쉬 클리어 수딩 크림 70ml+30ml 세트     닥터지  38,000
# 3            [더블기획] 피지오겔 DMT 페이셜 크림 100ml+100ml 증정 기획    피지오겔  59,000
# 4   [2023어워즈/1+1] 에스네이처 아쿠아 스쿠알란 수분크림 60ml 더블 어워즈 ...   에스네이처  43,000
# 5   [나도PICK/100ml+100ml] 닥터지 더모이스처 배리어 D 인텐스 크림 10...     닥터지  45,000
# 6   [1월 올영픽] 아비브 부활초 크림 뉴트리션 튜브 75ml 기획 (+30ml 추가 증정)     아비브  35,000
# 7         [단독대용량] 라운드랩 자작나무 수분 크림 120ml 기획 (+수분패드 4매)    라운드랩  42,000
# 8              [단독기획] 웰라쥬 리얼 히알루로닉 100 크림 50ml 1+1 기획     웰라쥬  39,000
# 9     [단독기획] 토리든 다이브인 저분자 히알루론산 수딩 크림 100ml 기획(+20ml)     토리든  24,000
# 10  [단독기획] 토리든 다이브인 저분자 히알루론산 크림 80ml 기획(+크림 20ml ...     토리든  21,000
# 11                               낫츠 센텔라스카 연고 일랑일랑 15g      낫츠  20,000
# 12            [광노화케어_신소재적용] 리쥬란 바이옴 힐러 유스 포뮬러 크림 50ml     리쥬란  49,000
# 13     [디렉터파이추천] 이즈앤트리 어니언 뉴페어 겔크림 50ml 기획(+겔크림 20ml)   이즈앤트리  32,000
# 14                    닥터자르트 세라마이딘 울트라 모이스처라이징 크림 50ml   닥터자르트  50,000
# 15           라로슈포제 시카플라스트 크림 B5 100ml 기획 (+시카마스크 25g)   라로슈포제  58,000
# 16            [한정기획] 피지오겔 레드수딩 AI 크림 100ml+30ml 증정 기획    피지오겔  49,900
# 17      [혜림쌤 PICK][단독기획]더하르나이 시카이드 크림 100ml + 30ml 기획   더하르나이  29,000
# 18                         라로슈포제 NEW 시카플라스트 밤B5+ 40ml   라로슈포제  25,000
# 19  [피부특화 DNA성분] 리쥬란 힐러 턴오버 액티브 크림 50ml 기획(+더마힐러 크...     리쥬란  49,000
# 20                       에스트라 아토베리어365 하이드로 수딩크림 60ml    에스트라  33,000
# 21                             샤이샤이샤이 바나나 컨실 아이크림 15g  샤이샤이샤이  26,000
# 22          [백현 PICK] 브링그린 티트리시카수딩크림플러스 100mL더블기획_NEW    브링그린  34,200
# 23  [단독기획] 파티온 노스카나인 트러블 흔적 리페어 크림 50ml 기획(+5ml+흔적...     파티온  35,000
# 24    [판매량 1억개 돌파] AHC 텐 레볼루션 리얼 아이크림 포 페이스 스페셜 퍼밍 세트     AHC  23,000
# 25  아벤느 이드랑스 아쿠아 크림-인-젤 EX 50ml 한정기획 (+이드랑스 에센스인로션...     아벤느  31,000
# 26                                바이오더마 시카비오 포마드 40ml   바이오더마  25,000
# 27              [대용량/단독기획] 리얼베리어 익스트림 크림 70ml+30ml 기획   리얼베리어  38,000
# 28              [NEW] 바이오힐보 판테셀 리페어시카 크림 50mL+50mL 기획   바이오힐보  57,600
# 29  [1월 올영픽] 아비브 콜라겐 아이크림 부활초 튜브 30ml 기획 (+부활초 크림 ...     아비브  26,000
# 30        [단독기획] 닥터지 레드 블레미쉬 클리어 모이스처 크림 70ml+30ml 기획     닥터지  39,000
# 31    라로슈포제 NEW 시카플라스트 밤B5+ 100ml 기획(+시카밤 3ml * 2 증정)   라로슈포제  39,000
# 32                  [단독기획]에뛰드 순정 수분 베리어 크림 75ml 트리오기획     에뛰드  22,000
# 33               비욘드 엔젤아쿠아 수분 진정 크림 150ml 1+1 기획 (비건)     비욘드  25,000
# 34  [1월올영PICK/선착순워터뱅크4종키트] 라네즈 워터뱅크 모이스춰 크림 45ml 배...     라네즈  39,000
# 35       [단독기획] 아이소이 속보습, 100시간 장수진 수분크림 70ml+15ml 기획    아이소이  36,000
# 36                       테라로직 레틴에이 안티 링클 3D 크림 20g+5g    테라로직  48,000
# 37        크리니크 모이스춰 써지 쏙보습크림/리치크림 50ml 기획 (루피 파우치 증정)    크리니크  48,000
# 38          [더블기획] 피지오겔 레드수딩 시카밸런스 크림 50ml+50ml 증정 기획    피지오겔  30,000
# 39      [단독기획]센텔리안24 링클셀 코어 아이크림 25ml (코어 세럼 10ml 증정)  센텔리안24  38,000
# 40                             로우퀘스트 베리어 리커버리 크림 80ml   로우퀘스트  38,000
# 41                     바이오힐보 프로바이오덤 리프팅 크림 50mL 더블 기획   바이오힐보  62,400
# 42               [디렉터파이 PICK] 유세린 하이알루론 3X 나이트크림 50ML     유세린  64,000
# 43                                  [김고은 Pick] 가히 멀티밤      가히  37,800
# 44         [박은빈 PICK] 한율 어린쑥 수분진정크림 55ml+25ml+마스크팩 기획      한율  38,000
# 45       [2세대 천만크림] 레드블레미쉬 클리어 수딩 크림 트리오 세트(50ml 3개입)     닥터지  42,000
# 46  [엔하이픈/성훈Pick] 닥터자르트 시카페어 인텐시브 수딩 리페어 크림 기획(50m...   닥터자르트  50,000
# 47           폴라초이스 클리니컬 0.3% 레티놀 + 2% 바쿠치올 트리트먼트 30ml   폴라초이스  87,000
#
#                                                  상품정보  \
# 0   [내용물의 용량 또는 중량 80ml, 제품 주요 사양 모든 피부용, 사용기한(또는 ...
# 1   [내용물의 용량 또는 중량 200ml + 50ml + 3ml * 2, 제품 주요 사...
# 2   [내용물의 용량 또는 중량 크림 70ml(jar) + 30ml(tube), 제품 주...
# 3   [내용물의 용량 또는 중량 100ml+100ml, 제품 주요 사양 모든피부용, 사용...
# 4   [내용물의 용량 또는 중량 60ml*2개입, 제품 주요 사양 모든 피부 타입, 사용...
# 5   [내용물의 용량 또는 중량 크림 100ml+100ml, 제품 주요 사양 모든 피부용...
# 6   [내용물의 용량 또는 중량 75ml(+30ml 증정), 제품 주요 사양 모든 피부용...
# 7   [내용물의 용량 또는 중량 [본품] 라운드랩 자작나무 수분 크림 120ml [증정품...
# 8   [내용물의 용량 또는 중량 50ml+50ml, 제품 주요 사양 모든피부타입, 사용기...
# 9   [내용물의 용량 또는 중량 [본품] 다이브인 수딩크림 100ml [증정] 다이브인 ...
# 10  [내용물의 용량 또는 중량 본품 80ml + 미니어처 20ml, 제품 주요 사양 모...
# 11  [품명 및 모델명 낫츠 센텔라스카 연고 [일랑일랑] 15g, 인증·허가 의약외품, ...
# 12  [내용물의 용량 또는 중량 50ml, 제품 주요 사양 모든피부용, 사용기한(또는 개...
# 13  [내용물의 용량 또는 중량 [본품]50ml+[증정]20ml, 제품 주요 사양 모든피...
# 14  [내용물의 용량 또는 중량 본품 50ml, 제품 주요 사양 모든피부용도, 사용기한(...
# 15  [내용물의 용량 또는 중량 100ml + 25g, 제품 주요 사양 민감성 및 모든 ...
# 16  [내용물의 용량 또는 중량 100ml+30ml, 제품 주요 사양 모든 피부용., 사...
# 17  [내용물의 용량 또는 중량 100ml+30ml, 제품 주요 사양 모든피부용(페이스용...
# 18  [내용물의 용량 또는 중량 40ml, 제품 주요 사양 민감성 및 모든 피부에 사용 ...
# 19  [내용물의 용량 또는 중량 50ml, 제품 주요 사양 모든피부타입, 사용기한(또는 ...
# 20  [내용물의 용량 또는 중량 60ml, 제품 주요 사양 모든 피부 타입, 사용기한(또...
# 21  [내용물의 용량 또는 중량 15g, 제품 주요 사양 모든 피부용, 사용기한(또는 개...
# 22  [내용물의 용량 또는 중량 ■ 100mLX2EA, 제품 주요 사양 ■ 모든 피부용,...
# 23  [내용물의 용량 또는 중량 흔적 크림 50ml+흔적 크림5ml+흔적앰플 3ml, 제...
# 24  [내용물의 용량 또는 중량 본품: 아이크림 35ml / 증정품: 본품 동일 아이크림...
# 25  [내용물의 용량 또는 중량 아벤느 이드랑스 아쿠아 인 젤 EX 50ml + 아벤느 ...
# 26  [내용물의 용량 또는 중량 40ml, 제품 주요 사양 피부 개선 크림, 사용기한(또...
# 27  [내용물의 용량 또는 중량 70ml(본품)+30ml(증정), 제품 주요 사양 모든 ...
# 28  [내용물의 용량 또는 중량 50mL + 50mL(리필), 제품 주요 사양 모든 피부...
# 29  [내용물의 용량 또는 중량 아이크림 30ml + 크림 30ml, 제품 주요 사양 모...
# 30  [내용물의 용량 또는 중량 70ml+30ml, 제품 주요 사양 모든 피부용, 사용기...
# 31  [내용물의 용량 또는 중량 100ml + 3ml * 2, 제품 주요 사양 민감성 및...
# 32  [내용물의 용량 또는 중량 용량 75ml*3 / 중량 39g, 제품 주요 사양 모든...
# 33  [내용물의 용량 또는 중량 150ml * 2ea, 제품 주요 사양 모든피부용, 사용...
# 34  [내용물의 용량 또는 중량 45ml + 키링 + 모이스춰10ml*2ea, 제품 주요...
# 35  [내용물의 용량 또는 중량 본품 장수진크림: 70ml/ 증정품(동일품목): 15ml...
# 36  [내용물의 용량 또는 중량 20g + 5g, 제품 주요 사양 모든피부타입, 사용기한...
# 37  [내용물의 용량 또는 중량 50ml, 제품 주요 사양 모든 피부 타입, 사용기한(또...
# 38  [내용물의 용량 또는 중량 50ml+50ml, 제품 주요 사양 모든피부용., 사용기...
# 39  [내용물의 용량 또는 중량 아이크림 25ml*1ea, 세럼 10ml*1ea, 제품 ...
# 40  [내용물의 용량 또는 중량 80mL, 제품 주요 사양 모든 피부용, 사용기한(또는 ...
# 41  [내용물의 용량 또는 중량 50mL + 50mL, 제품 주요 사양 모든 피부 타입,...
# 42  [내용물의 용량 또는 중량 50ml, 제품 주요 사양 모든 피부용, 사용기한(또는 ...
# 43  [내용물의 용량 또는 중량 9g, 제품 주요 사양 모든 피부 타입, 사용기한(또는 ...
# 44  [내용물의 용량 또는 중량 55ml+25ml+어린쑥 랩핑마스크 1매, 제품 주요 사...
# 45  [내용물의 용량 또는 중량 크림 tube 50ml + 50ml + 50ml, 제품 ...
# 46  [내용물의 용량 또는 중량 본품 50mL+15mL*2ea, 제품 주요 사양 모든피부...
# 47  [내용물의 용량 또는 중량 30ml, 제품 주요 사양 피부타입: 모든피부, 사용기한...
#
#                                                   썸네일
# 0                 [./prdimgs/page_1_prd_0_thumb1.jpg]
# 1                 [./prdimgs/page_1_prd_1_thumb1.jpg]
# 2   [./prdimgs/page_1_prd_2_thumb1.jpg, ./prdimgs/...
# 3   [./prdimgs/page_1_prd_3_thumb1.jpg, ./prdimgs/...
# 4   [./prdimgs/page_1_prd_4_thumb1.jpg, ./prdimgs/...
# 5   [./prdimgs/page_1_prd_5_thumb1.jpg, ./prdimgs/...
# 6   [./prdimgs/page_1_prd_6_thumb1.jpg, ./prdimgs/...
# 7   [./prdimgs/page_1_prd_7_thumb1.jpg, ./prdimgs/...
# 8   [./prdimgs/page_1_prd_8_thumb1.jpg, ./prdimgs/...
# 9   [./prdimgs/page_1_prd_9_thumb1.jpg, ./prdimgs/...
# 10  [./prdimgs/page_1_prd_10_thumb1.jpg, ./prdimgs...
# 11  [./prdimgs/page_1_prd_11_thumb1.jpg, ./prdimgs...
# 12  [./prdimgs/page_1_prd_12_thumb1.jpg, ./prdimgs...
# 13  [./prdimgs/page_1_prd_13_thumb1.jpg, ./prdimgs...
# 14  [./prdimgs/page_1_prd_14_thumb1.jpg, ./prdimgs...
# 15  [./prdimgs/page_1_prd_15_thumb1.jpg, ./prdimgs...
# 16  [./prdimgs/page_1_prd_16_thumb1.jpg, ./prdimgs...
# 17  [./prdimgs/page_1_prd_17_thumb1.jpg, ./prdimgs...
# 18               [./prdimgs/page_1_prd_18_thumb1.jpg]
# 19  [./prdimgs/page_1_prd_19_thumb1.jpg, ./prdimgs...
# 20               [./prdimgs/page_1_prd_20_thumb1.jpg]
# 21  [./prdimgs/page_1_prd_21_thumb1.jpg, ./prdimgs...
# 22  [./prdimgs/page_1_prd_22_thumb1.jpg, ./prdimgs...
# 23  [./prdimgs/page_1_prd_23_thumb1.jpg, ./prdimgs...
# 24                [./prdimgs/page_2_prd_0_thumb1.jpg]
# 25  [./prdimgs/page_2_prd_1_thumb1.jpg, ./prdimgs/...
# 26  [./prdimgs/page_2_prd_2_thumb1.jpg, ./prdimgs/...
# 27  [./prdimgs/page_2_prd_3_thumb1.jpg, ./prdimgs/...
# 28  [./prdimgs/page_2_prd_4_thumb1.jpg, ./prdimgs/...
# 29  [./prdimgs/page_2_prd_5_thumb1.jpg, ./prdimgs/...
# 30  [./prdimgs/page_2_prd_6_thumb1.jpg, ./prdimgs/...
# 31  [./prdimgs/page_2_prd_7_thumb1.jpg, ./prdimgs/...
# 32                [./prdimgs/page_2_prd_8_thumb1.jpg]
# 33  [./prdimgs/page_2_prd_9_thumb1.jpg, ./prdimgs/...
# 34  [./prdimgs/page_2_prd_10_thumb1.jpg, ./prdimgs...
# 35  [./prdimgs/page_2_prd_11_thumb1.jpg, ./prdimgs...
# 36  [./prdimgs/page_2_prd_12_thumb1.jpg, ./prdimgs...
# 37  [./prdimgs/page_2_prd_13_thumb1.jpg, ./prdimgs...
# 38  [./prdimgs/page_2_prd_14_thumb1.jpg, ./prdimgs...
# 39  [./prdimgs/page_2_prd_15_thumb1.jpg, ./prdimgs...
# 40  [./prdimgs/page_2_prd_16_thumb1.jpg, ./prdimgs...
# 41  [./prdimgs/page_2_prd_17_thumb1.jpg, ./prdimgs...
# 42  [./prdimgs/page_2_prd_18_thumb1.jpg, ./prdimgs...
# 43  [./prdimgs/page_2_prd_19_thumb1.jpg, ./prdimgs...
# 44  [./prdimgs/page_2_prd_20_thumb1.jpg, ./prdimgs...
# 45  [./prdimgs/page_2_prd_21_thumb1.jpg, ./prdimgs...
# 46  [./prdimgs/page_2_prd_22_thumb1.jpg, ./prdimgs...
# 47  [./prdimgs/page_2_prd_23_thumb1.jpg, ./prdimgs...

# %%
category = '크림'
cream.to_csv(f'./data/02.데이터수집_01크롤링_올리브영_제품_{category}.csv', index=False)

# %%
cream.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48 entries, 0 to 47
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   제품명     48 non-null     object
#  1   브랜드     48 non-null     object
#  2   가격      48 non-null     object
#  3   상품정보    48 non-null     object
#  4   썸네일     48 non-null     object
# dtypes: object(5)
# memory usage: 2.0+ KB
