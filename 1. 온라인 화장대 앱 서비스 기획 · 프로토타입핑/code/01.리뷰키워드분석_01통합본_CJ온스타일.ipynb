# %% [markdown]
# # 리뷰 데이터 수집

# %%
# https://play.google.com/store/apps/details?id=com.cjoshppingphone&hl=ko-KR

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("com.cjoshppingphone",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST,
                      count=50000)

# %%
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
import numpy as np
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    df.to_csv(f'./data/01.리뷰키워드분석_01통합본_{name}_리뷰크롤링파일.csv',escapechar=' ', index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'CJ온스타일')

# %%
df.sort_values('at',ascending=False)
# Out:
#                                                  content  score  \
# 7319                               일단 사용 해봐야 실감합니다 최고입니다      5
# 49               구매하시는데 도움이 되도록 사진 여러장 찍었는데 3장밖에 안올라가네요~      5
# 5009                                      넘 예뻐요 기대돼요~~^^      5
# 4453                           위에옷이 제가 찿던 스타일이네요 ~~짱 😀 👍      5
# 3094                                              핏이 이뻐요      5
# ...                                                  ...    ...
# 14637                             전보다예뻐지고 상품을. 찾기도 편해졌네요      5
# 14640                   업뎃하고 더 좋아졌어요♥특히 방송볼수있어서 너무 좋아요ㅎㅎ      5
# 14638                                   이전 앱보다 더 산뜻해졌네요!      4
# 14639  장바구니 오류! 주문삭제도 안되고 선택주문도 안되고.... 일단 장바구니에 담은건 ...      3
# 14641                                        여러가지물건보니좋아요      4
#
#        thumbsUpCount                  at
# 7319               0 2024-02-21 02:08:29
# 49                 0 2024-02-20 22:23:11
# 5009               0 2024-02-20 20:09:49
# 4453               0 2024-02-20 20:00:08
# 3094               0 2024-02-20 19:48:28
# ...              ...                 ...
# 14637              0 2011-04-28 23:55:30
# 14640              0 2011-04-24 04:30:41
# 14638              0 2011-04-23 09:58:07
# 14639              3 2011-03-22 22:07:57
# 14641              0 2011-02-28 19:30:53
#
# [15981 rows x 4 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15981 entries, 0 to 15980
# Data columns (total 4 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        15862 non-null  object
#  1   score          15981 non-null  int64
#  2   thumbsUpCount  15981 non-null  int64
#  3   at             15981 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), int64(2), object(1)
# memory usage: 499.5+ KB

# %%
df['year'] = df['at'].dt.strftime("%Y")
df
# Out:
#                                                  content  score  \
# 0      실용적인 제품이 많이 소개돼서 좋아요~근데 왠지 노출이 많이 되지 못하는 것 같아요...      5
# 1      분명히 앱을 실행한 건데도, 바로가기 적용이 안되어서 혜택 적용(vip즉시할인 등)...      3
# 2      로그인 화면에서 튕기면서 메인페이지로 넘어갑니다. 로그인 자체가 불가능해서 물건 주...      1
# 3      앱에서 상품 볼때 로딩이 너무 느려요. 썸네일 이미지랑 텍스트 로딩이 너무 느리고,...      1
# 4      꽤 상당기간, 언젠가부터 이미지 파일이 깨져서 나오지가 않고 상품 상세 페이지가 보...      1
# ...                                                  ...    ...
# 15976                                             좋은것같아요      5
# 15977                                                 賽海      5
# 15978                                              지하철노선      5
# 15979                                                ...      5
# 15980                                               None      4
#
#        thumbsUpCount                  at  year
# 0                316 2023-10-10 11:23:58  2023
# 1               1576 2018-10-10 22:04:05  2018
# 2                732 2022-07-07 23:40:08  2022
# 3                697 2022-09-07 15:02:18  2022
# 4                453 2021-03-01 09:11:13  2021
# ...              ...                 ...   ...
# 15976              0 2014-11-19 11:31:57  2014
# 15977              0 2022-01-01 08:41:28  2022
# 15978              1 2015-07-06 14:01:04  2015
# 15979              0 2015-08-17 14:11:41  2015
# 15980              0 2014-03-06 13:50:58  2014
#
# [15981 rows x 5 columns]

# %%
df.loc[:][df['year']==2022]
# Out:
# Empty DataFrame
# Columns: [content, score, thumbsUpCount, at, year]
# Index: []

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df['content'].isnull().sum()
# Out:
# 119

# %%
print(df.info())
print()
df.dropna(subset='content',axis=0,inplace=True)
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15981 entries, 0 to 15980
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        15862 non-null  object
#  1   score          15981 non-null  int64
#  2   thumbsUpCount  15981 non-null  int64
#  3   at             15981 non-null  datetime64[ns]
#  4   year           15981 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 624.4+ KB
# None
#
# <class 'pandas.core.frame.DataFrame'>
# Index: 15862 entries, 0 to 15979
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   content        15862 non-null  object
#  1   score          15862 non-null  int64
#  2   thumbsUpCount  15862 non-null  int64
#  3   at             15862 non-null  datetime64[ns]
#  4   year           15862 non-null  object
# dtypes: datetime64[ns](1), int64(2), object(2)
# memory usage: 743.5+ KB
# None

# %%
def tokenize(dataFrame):
    okt = Okt()
    
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    dataframe = tokenize(dataFrame)
    dataframe = remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
tokenized = tokenize(df)

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <15862x5829 sparse matrix of type '<class 'numpy.int64'>'
# 	with 47128 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <15862x5829 sparse matrix of type '<class 'numpy.float64'>'
# 	with 47128 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '실용 제품 소개 노출 채널 느낌 모바일 구매 서비스 제품 제한 별로 혜택,앱 실행 건데 바로가기 적용 혜택 적용 할인 계속 발생 앱 행해 강제 종료 행해 폰 재부팅 마찬가지 앱 자체 삭제 재 설치 해당 오류 사이트 광고 배너 클릭 씨제이 사이트 실행 앱 실행 계속 에러 분명 예전 기기 사용 시 계속 사이트 이용 실수 로라 씨제이 광고 배너 클릭 꼭 오류 발생 걸 확인 앱 재 설치 정말 앱 개발 팀 꼭 검수 수정,로그인 화면 튕기면 메인 페이지 로그인 자체 물건 주문 어플리케이션 버그 발견 폰 앱 강제 종료 재 접속 현상 발생 최근 업데이트 이후 현상 버그 수정,앱 상품 볼때 로딩 썸네일 이미지 텍스트 로딩 한참 이미지 아예 텍스트 스 크롤 첫 번은 듯 리다 홈페이지 접속 상품 개발자 관리자 본인 폰 앱 확인,꽤 상당 기간 이미지 파일 상품 상세 페이지 보이지 공백 방금 앱 업데이트 마찬가지 패션 상품 옷 핏 상세 치수 소재 확인 매우 구매 전환 해당 부분 스크린 캡처 해 사진 첨부 곳 증상 최대한 개선,안드로이드 버전 앱 최신 버전 로그인 캐시 버그 발생 얼럿뜨 삭제 앱 시동 동일 현상 재현 모바일 웹 정상 카카오 톡 알림 톡 통해 앱 동시 앱 종료 앱 시동 재현,그동안 블편함 최근 상품 클릭 상세 화면 내용 빈번 장바구니 넣기 버튼 먹통 앱 진짜 느낌 결제 업데이트 안해 건가 계속 체크 해결,가장 애용 사이 종종 판매 자가 사이트 동시 제품 재고 파악 제대로 주문 결제 연락 품절 몇번 재발 방지 방법 불량 교환 교환 반품 검수 배송 불량 고객 불편 반품 교환 땐 배송 경험 건의 사항,구매 앱 구매 못 앱 통 여러가지 혜택 나이 스마트 폰 기능 사용 전화 구매 혜택 나이 제한 세 은 전화 구매 혜택,원래 편의 성과 혜택 덕분 어플 뉴스 중간 중간 의지 실행 마다 호감 기존 장점 광고 의존 쇼핑몰 본연 역할,이즈 치수 걸 구입 품 넉 넉 화이트 완죤 버핏 부 올여름 재질 품 고민 가격 블랙 블루 블라우스,로그 비번 설정 번은 계속 뭐 가문 제입 설정 비번 설정 현재 비번 몇번 확인 계속 로그 밑 리뷰 오류 수정 짜증 화가 로그인 로그인 비번 무한 반복 겁,페북 뉴스 기사 배 배꼽 기사 보지 광고 크게 무조건 설치 사이트 꼼수 장난 광고 기사 광고 클릭 광고,요즘 웹쇼핑 어플 매우 뒤 앱 튕김 이미지 로딩 검색 똑바로 어플 속도 시스템 대충 꼬박꼬박 배송비 제품 사이트 꼭 쿠폰 적용 포인트 생일 쿠폰 쿠폰 적용 상품 소수 쿠폰 사용 포인트 쿠폰 막 값 사이트 값 품일 필요 뒤,업데이트 업데이트 앱 사용 건 편리 고객 센터 통 반품 물건 이제 상품 평 품절 상품 상품 페이지 방문 할인 앱 점점 가요,맘 바지핏 겉옷 조끼 폼 겉옷 자체 칭구 지인 추천 제품,사용 피부 샷 가격 무제한 맘 일만,마음 앞뒤 시접 부분 겨 수선 원래 모델 사진 품위,홈쇼핑 신발 사이즈 업체 실수 잘못 배송 반품 신청 일주일 물건 달라 확인 전화 이틀 뒤 씨제이 쇼핑 이용,마 데카 크림 악 건성 탈출 아침 저녁 계속 쭉 사용 시즌 최신 쭉 사용 사용 지인 피부 남편 사용 만족 제품 새해 복,설 명절 선물 엄마 선물 려구 시골 도마 드릴 려고 가격,체형 커버 옷 스타일 자주,화면 땐 두께 실제,오쿠 구입 조작 하니 맛 구입,소재 싸이 색상 가방,사이즈 실용,미백 효과 아주 데이 소량 나이트 툼 잠자리 티슈 살짝 터치 취침 잠 백설공주 광채 미부 만족,맘 에드 선물 와이프 칭찬 상품 수고,가격 항상 애용 찹쌀 찰보리 사은 품 주시 배송 포장,관리 피부 사용,택배 적정 시기 색상 맘,뺑뺑 대상 이벤트 관리자 끼리,배송 원래 도착 예정일 상품 역시 늘 이용,가장 눈 띠 목 부분 불량 성의 검사 제대로 물건 성의 매출 신경 홈쇼핑 기분 쇼핑,색감 수납 공간 가방 적극 추천,처음 사용 전체 쫀쫀해 느낌 조작 법도 쭉 사용,부라 착용 감 색상 마음 디자인,화장품 정말 제일 효과 팔자주름 고민 정말,그린 색상 봄 미국여행 계획 기대 보고,목 부분 보리 처리 옷 별로 밑단 캐 주얼 활용 컬러 검정 가죽 쟈켓 색상 도전,가격 설정 금액 세밀 가격 도저히 수가 그냥 직접 입력 는걸 사용자 편의 고려,색상 싸이 요즘 날씨 겨울 무난 주머니 양쪽 지퍼 상품 맘에듭니,홈쇼핑 엣지 상품 상품 절대,배송 상품 아주 맘 상품,옷 맘 꼭 고요 사이즈,구매 해 세안 얼굴 볼 구매,털 블랙 컬러 구매,앞코 사각 발가락 굽이 대체로 신발 쿠션 고급 딸아이 신발,사용 디자인 쓰기,구매 도움 사진 장 장,정말 보정 멋 레이스 부분 여성,효과 동생 와이프 사주,필터 링 좀더 세밀 상품 만족,소개 상세 가격 대비 질도 홈쇼핑 휠씬 믿음 감 패션,항상 스타인 이용 배달 냉 도충,오늘 처음 사용 얼굴 업 산 관리,처음 도착 원단 보고 뭐 패드 왤케 걸 세탁 먼지 안나 진짜 어케 가격 상품 구매 두셋 트 구매 걸,상품 스타일 옷감 질감 대체로 마음,몸 증상 향 솔솔 향수,지문 로그인 예전 등록 상태 최근 로그인 지문 인식 무한 로딩,배송 정품 퀄리티 상품 득템,쿠폰 사용 조건 완화 가입 할인 쿠폰 가입 사용 가능 구매 제품 쿠폰 사용 불가 가입 쿠폰 걸 추가 배 배꼽,간혹 쇼 호스트 과대 액션 상품 곳 사랑 여러가지 통화 기분 곳 칭찬,평소 교환 어깨 부분 허리 밑 교환 사이즈 스판기 교환 옷,디자인 무난,항상 할인 혜택 자동,제품 정보 제공 구입,방송 설선물 구입,가격 배송,디자인 색깔 질감,배송,사고 디자인 바느질,혜택 이면 혜택 배송 배송 상품 거기 즐거움 퍼팩트 홈쇼핑 독보 존재 온스타일,검색 만하 먹통 업뎃해 마찬가지,친구 보고 구매 뎄습,스타일 상품 브랜드 후회,배송 포장,모양 색상 마음,케리 맘 색상 만족,목 어깨,토프 그레이 색상,노후 캐리어 구매 마침 방송 보고 구매 빈티 블루,착용 감 보기 싸구려 느낌 안남 키 신분 치수 크게 이유 기장 살짝 개인 차 후기 한번,아주 마음 구매,온스타일 제품 고급 지고 배송,제품,마음 쏙 상품,사용 쫀쫀하 탄력 로라 화장 기대 광고 피부관리 바,옷 두툼 카라 기모 정사 이즈 배송 겨울 셔츠 최고,언니 동생 조카 상품 보고 선전,배송 제품 사용,모카 베이지색 두루 두루,가격 대비 상품 인정 상품 소개 추천,상품 가격 구매,마음 스타일 옷 친구,상품,배송 물건,쇼핑 아이템 방송 상품 미리 용,매우 사용 효과 아주,디자인 색상 맘,상품 품질 제품,배송 교환 신청 제일 맘 홈 쇼핑,사용 걸 사서 사용 사용 결과,앱 배송 자주 애용,홈쇼핑 쇼핑몰 물건 구매,제품 구입 케 감사,항상 배송 상품,인테리어 효과 제대로,배송 킹왕짱 제품 소개,가을 앱 통해 전기장판 합리 가격 구입 사용,배송 취소 반품 처리 구매,배송 주의 사항 첨부,맘 흰색 만족,배송 빨 상품,이틀 사용 기분 상인,죤상품 배송,최고,항상 상품 자주 애용 읍니,제품,온스 딸 광고 서비스 개선 셈 상세 페이지 입점 제품 다양성 리뷰,엔드 레인 도마 제사 이제야 구매 가격,가끔 마음 설명,개봉 야채 웬 요리사 칼 소리 주방,아주 셋뚜 명절 구입 정말 상품,일부 특 상품 매우 방송 계속,여러 가격 사이즈 주문 취소 꼭 사이즈 마,아주 종류 색상 차이 일색 브랜드 로고 시장 산 느낌,장만 마침 가격 장만 주문 오늘 배송 기분,가격 구입 왼쪽 덧 창의 마무리 못 게 경량 자주 손,핏 맘 베이지 추가 구매,색상 완전 기분 얼굴,향 종류 포장 지인 차 디퓨져 선물 차 냄새 달 강력 추천 방도 향기,제스처 기사 동의 허용 이용 불가 태임 허용 라이브 방송 안내 팝업창 뭡,고급 원단 만족 검정색 주문,배송 무상 반품 주문,제스쳐 기능 허용 안함 핸드폰 사용 안내 팝업,한번 사용 효과 날 세안 피부,품질 서비스 최우수,마침 저가 클랜 고민 마침 홈쇼핑 방송 호감 구매 어제 세수 여태 보지 얼굴 촉감 담,웹쇼핑 앱 설치 링크 클릭 다운 주네 마케팅 수법 완전 사기꾼,배송 색상 마음 신영와코루 편안함 안해 몸,아주 재품 판매 곳 매우,적극 추천 탄력 눈,구성,피부 수분 수량 추석 선물 강,상품 신영와코루 실내 향,상품 자주 자주 구입,요즘 냉감 소재 봄 해,어플 키 처음 화면 계속 그냥 어플 자체 먹통 조치,듀얼 쇼닉 맥시 엄 사용 한지 일주일 탄력 매일 사용,방송 실제,항상 제품 선택 구성,금번 구입 스키 제품 제품 상 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'실용': 23,
#  '제품': 791,
#  '소개': 63,
#  '노출': 7,
#  '채널': 21,
#  '느낌': 122,
#  '모바일': 451,
#  '구매': 1106,
#  '서비스': 82,
#  '제한': 8,
#  '별로': 82,
#  '혜택': 297,
#  '앱': 1561,
#  '실행': 106,
#  '바로가기': 20,
#  '적용': 68,
#  '할인': 374,
#  '계속': 423,
#  '발생': 13,
#  '행해': 2,
#  '강제': 26,
#  '종료': 38,
#  '폰': 105,
#  '재부팅': 5,
#  '마찬가지': 21,
#  '자체': 56,
#  '삭제': 174,
#  '재': 79,
#  '설치': 303,
#  '해당': 17,
#  '오류': 190,
#  '사이트': 92,
#  '광고': 240,
#  '배너': 15,
#  '클릭': 67,
#  '씨제이': 264,
#  '에러': 46,
#  '분명': 15,
#  '예전': 42,
#  '기기': 9,
#  '사용': 893,
#  '시': 119,
#  '이용': 489,
#  '실수': 8,
#  '로라': 2,
#  '꼭': 130,
#  '걸': 63,
#  '확인': 157,
#  '정말': 441,
#  '개발': 10,
#  '팀': 7,
#  '검수': 4,
#  '수정': 69,
#  '로그인': 525,
#  '화면': 251,
#  '튕기': 11,
#  '메인': 24,
#  '페이지': 91,
#  '물건': 330,
#  '주문': 691,
#  '어플리케이션': 5,
#  '버그': 15,
#  '발견': 3,
#  '접속': 132,
#  '현상': 17,
#  '최근': 27,
#  '업데이트': 281,
#  '이후': 37,
#  '상품': 1378,
#  '볼때': 10,
#  '로딩': 78,
#  '썸네일': 2,
#  '이미지': 27,
#  '텍스트': 2,
#  '한참': 14,
#  '아예': 51,
#  '스': 43,
#  '크롤': 17,
#  '첫': 17,
#  '번은': 10,
#  '듯': 95,
#  '리다': 2,
#  '홈페이지': 15,
#  '개발자': 15,
#  '관리자': 12,
#  '본인': 19,
#  '꽤': 13,
#  '상당': 1,
#  '기간': 14,
#  '파일': 3,
#  '상세': 54,
#  '보이지': 9,
#  '공백': 1,
#  '방금': 13,
#  '패션': 16,
#  '옷': 226,
#  '핏': 84,
#  '치수': 14,
#  '소재': 62,
#  '매우': 132,
#  '전환': 10,
#  '부분': 57,
#  '스크린': 3,
#  '캡처': 4,
#  '해': 167,
#  '사진': 48,
#  '첨부': 12,
#  '곳': 110,
#  '증상': 5,
#  '최대한': 2,
#  '개선': 110,
#  '안드로이드': 8,
#  '버전': 33,
#  '최신': 13,
#  '캐시': 14,
#  '얼럿뜨': 1,
#  '시동': 2,
#  '동일': 8,
#  '재현': 2,
#  '웹': 44,
#  '정상': 11,
#  '카카오': 14,
#  '톡': 15,
#  '알림': 124,
#  '통해': 33,
#  '동시': 5,
#  '그동안': 15,
#  '블편함': 1,
#  '내용': 18,
#  '빈번': 3,
#  '장바구니': 42,
#  '넣기': 3,
#  '버튼': 32,
#  '먹통': 22,
#  '진짜': 209,
#  '결제': 220,
#  '안해': 17,
#  '건가': 29,
#  '체크': 29,
#  '해결': 52,
#  '가장': 47,
#  '애용': 143,
#  '사이': 14,
#  '종종': 18,
#  '판매': 76,
#  '자가': 1,
#  '재고': 21,
#  '파악': 5,
#  '제대로': 54,
#  '연락': 26,
#  '품절': 40,
#  '몇번': 78,
#  '재발': 1,
#  '방지': 3,
#  '방법': 31,
#  '불량': 5,
#  '교환': 55,
#  '반품': 92,
#  '배송': 818,
#  '고객': 143,
#  '불편': 35,
#  '땐': 19,
#  '경험': 11,
#  '건의': 4,
#  '사항': 16,
#  '못': 77,
#  '통': 23,
#  '여러가지': 42,
#  '나이': 32,
#  '스마트': 10,
#  '기능': 95,
#  '전화': 50,
#  '세': 7,
#  '은': 41,
#  '원래': 14,
#  '편의': 20,
#  '성과': 10,
#  '덕분': 24,
#  '어플': 399,
#  '뉴스': 6,
#  '중간': 7,
#  '의지': 2,
#  '마다': 8,
#  '호감': 3,
#  '기존': 36,
#  '장점': 19,
#  '의존': 1,
#  '쇼핑몰': 150,
#  '본연': 1,
#  '역할': 1,
#  '이즈': 44,
#  '구입': 415,
#  '품': 41,
#  '넉': 2,
#  '화이트': 7,
#  '완죤': 8,
#  '버핏': 2,
#  '부': 11,
#  '올여름': 14,
#  '재질': 29,
#  '고민': 56,
#  '가격': 496,
#  '블랙': 20,
#  '블루': 12,
#  '블라우스': 7,
#  '로그': 33,
#  '비번': 110,
#  '설정': 68,
#  '뭐': 193,
#  '가문': 2,
#  '제입': 1,
#  '현재': 7,
#  '밑': 13,
#  '리뷰': 82,
#  '짜증': 62,
#  '화가': 7,
#  '무한': 24,
#  '반복': 41,
#  '겁': 20,
#  '페북': 5,
#  '기사': 20,
#  '배': 19,
#  '배꼽': 2,
#  '보지': 11,
#  '크게': 22,
#  '무조건': 20,
#  '꼼수': 1,
#  '장난': 39,
#  '요즘': 110,
#  '웹쇼핑': 2,
#  '뒤': 34,
#  '튕김': 5,
#  '검색': 267,
#  '똑바로': 13,
#  '속도': 62,
#  '시스템': 22,
#  '대충': 2,
#  '꼬박꼬박': 3,
#  '배송비': 22,
#  '쿠폰': 430,
#  '포인트': 172,
#  '생일': 13,
#  '소수': 1,
#  '막': 14,
#  '값': 17,
#  '품일': 1,
#  '필요': 39,
#  '건': 48,
#  '편리': 22,
#  '센터': 41,
#  '이제': 70,
#  '평': 60,
#  '방문': 27,
#  '점점': 18,
#  '가요': 55,
#  '맘': 562,
#  '바지': 45,
#  '겉옷': 3,
#  '조끼': 8,
#  '폼': 3,
#  '칭구': 1,
#  '지인': 44,
#  '추천': 200,
#  '피부': 182,
#  '샷': 3,
#  '무제한': 1,
#  '일만': 1,
#  '마음': 293,
#  '앞뒤': 1,
#  '시접': 1,
#  '겨': 12,
#  '수선': 4,
#  '모델': 7,
#  '품위': 3,
#  '홈쇼핑': 353,
#  '신발': 25,
#  '사이즈': 136,
#  '업체': 13,
#  '잘못': 23,
#  '신청': 46,
#  '일주일': 13,
#  '달라': 17,
#  '이틀': 10,
#  '쇼핑': 932,
#  '마': 62,
#  '데카': 55,
#  '크림': 60,
#  '악': 4,
#  '건성': 10,
#  '탈출': 2,
#  '아침': 38,
#  '저녁': 16,
#  '쭉': 22,
#  '시즌': 6,
#  '남편': 54,
#  '만족': 168,
#  '새해': 10,
#  '복': 10,
#  '설': 6,
#  '명절': 7,
#  '선물': 138,
#  '엄마': 33,
#  '려구': 1,
#  '시골': 2,
#  '도마': 20,
#  '드릴': 3,
#  '려고': 18,
#  '체형': 14,
#  '커버': 22,
#  '스타일': 115,
#  '자주': 411,
#  '두께': 15,
#  '실제': 16,
#  '오쿠': 1,
#  '조작': 7,
#  '하니': 49,
#  '맛': 39,
#  '싸이': 20,
#  '색상': 279,
#  '가방': 28,
#  '미백': 7,
#  '효과': 68,
#  '아주': 351,
#  '데이': 4,
#  '소량': 1,
#  '나이트': 1,
#  '툼': 1,
#  '잠자리': 3,
#  '티슈': 1,
#  '살짝': 15,
#  '터치': 20,
#  '취침': 1,
#  '잠': 4,
#  '백설공주': 1,
#  '광채': 7,
#  '미부': 1,
#  '에드': 35,
#  '와이프': 8,
#  '칭찬': 9,
#  '수고': 25,
#  '항상': 248,
#  '찹쌀': 2,
#  '찰보리': 2,
#  '사은': 23,
#  '주시': 16,
#  '포장': 32,
#  '관리': 80,
#  '택배': 37,
#  '적정': 1,
#  '시기': 8,
#  '뺑뺑': 3,
#  '대상': 2,
#  '이벤트': 262,
#  '끼리': 2,
#  '도착': 30,
#  '예정일': 6,
#  '역시': 84,
#  '늘': 116,
#  '눈': 48,
#  '띠': 2,
#  '목': 22,
#  '성의': 4,
#  '검사': 5,
#  '매출': 1,
#  '신경': 14,
#  '기분': 141,
#  '색감': 24,
#  '수납': 4,
#  '공간': 8,
#  '적극': 27,
#  '처음': 175,
#  '전체': 32,
#  '쫀쫀해': 2,
#  '법도': 2,
#  '부라': 3,
#  '착용': 196,
#  '감': 149,
#  '디자인': 284,
#  '화장품': 29,
#  '제일': 68,
#  '팔자주름': 4,
#  '그린': 9,
#  '봄': 31,
#  '미국여행': 1,
#  '계획': 4,
#  '기대': 118,
#  '보고': 200,
#  '보리': 2,
#  '처리': 68,
#  '밑단': 3,
#  '캐': 6,
#  '주얼': 2,
#  '활용': 36,
#  '컬러': 15,
#  '검정': 6,
#  '가죽': 7,
#  '쟈켓': 5,
#  '도전': 3,
#  '금액': 27,
#  '세밀': 3,
#  '도저히': 8,
#  '수가': 21,
#  '그냥': 102,
#  '직접': 21,
#  '입력': 64,
#  '는걸': 12,
#  '사용자': 29,
#  '고려': 3,
#  '날씨': 24,
#  '겨울': 53,
#  '무난': 9,
#  '주머니': 3,
#  '양쪽': 1,
#  '지퍼': 2,
#  '맘에듭': 17,
#  '엣지': 14,
#  '절대': 20,
#  '고요': 7,
#  '세안': 10,
#  '얼굴': 69,
#  '볼': 48,
#  '털': 5,
#  '앞코': 1,
#  '사각': 3,
#  '발가락': 1,
#  '굽이': 1,
#  '대체로': 11,
#  '쿠션': 6,
#  '고급': 36,
#  '딸아이': 9,
#  '쓰기': 59,
#  '도움': 41,
#  '장': 11,
#  '보정': 12,
#  '멋': 11,
#  '레이스': 18,
#  '여성': 14,
#  '동생': 18,
#  '사주': 2,
#  '필터': 8,
#  '링': 3,
#  '좀더': 35,
#  '대비': 73,
#  '질도': 12,
#  '휠씬': 2,
#  '믿음': 40,
#  '스타인': 1,
#  '배달': 23,
#  '냉': 2,
#  '도충': 1,
#  '오늘': 125,
#  '업': 25,
#  '산': 16,
#  '원단': 39,
#  '패드': 3,
#  '왤케': 3,
#  '세탁': 10,
#  '먼지': 5,
#  '안나': 10,
#  '어케': 6,
#  '두셋': 3,
#  '트': 17,
#  '옷감': 18,
#  '질감': 8,
#  '몸': 35,
#  '향': 52,
#  '솔솔': 2,
#  '향수': 4,
#  '지문': 5,
#  '등록': 40,
#  '상태': 31,
#  '인식': 6,
#  '정품': 4,
#  '퀄리티': 18,
#  '득템': 30,
#  '조건': 15,
#  '완화': 3,
#  '가입': 182,
#  '가능': 13,
#  '불가': 22,
#  '추가': 133,
#  '간혹': 8,
#  '쇼': 28,
#  '호스트': 27,
#  '과대': 3,
#  '액션': 1,
#  '사랑': 46,
#  '통화': 14,
#  '평소': 55,
#  '어깨': 17,
#  '허리': 13,
#  '스판기': 2,
#  '자동': 62,
#  '정보': 137,
#  '제공': 20,
#  '방송': 341,
#  '설선물': 2,
#  '색깔': 31,
#  '사고': 39,
#  '바느질': 7,
#  '이면': 11,
#  '거기': 18,
#  '즐거움': 16,
#  '퍼': 1,
#  '팩트': 8,
#  '독보': 2,
#  '존재': 10,
#  '온스타일': 150,
#  '만하': 19,
#  '업뎃해': 4,
#  '친구': 79,
#  '뎄습': 1,
#  '브랜드': 43,
#  '후회': 36,
#  '모양': 14,
#  '케리': 3,
#  '토프': 1,
#  '그레이': 8,
#  '노후': 1,
#  '캐리어': 6,
#  '마침': 18,
#  '빈티': 1,
#  '보기': 217,
#  '싸구려': 3,
#  '안남': 2,
#  '키': 35,
#  '신분': 10,
#  '이유': 43,
#  '기장': 9,
#  '개인': 13,
#  '차': 15,
#  '후기': 24,
#  '한번': 138,
#  '지고': 10,
#  '쏙': 65,
#  '쫀쫀하': 2,
#  '탄력': 24,
#  '화장': 10,
#  '피부관리': 3,
#  '바': 31,
#  '두툼': 3,
#  '카라': 8,
#  '기모': 2,
#  '정사': 30,
#  '셔츠': 6,
#  '최고': 308,
#  '언니': 20,
#  '조카': 2,
#  '선전': 3,
#  '모카': 1,
#  '베이지색': 1,
#  '두루': 3,
#  '인정': 6,
#  '아이템': 11,
#  '미리': 30,
#  '용': 59,
#  '품질': 105,
#  '홈': 39,
#  '사서': 27,
#  '결과': 11,
#  '케': 2,
#  '감사': 99,
#  '인테리어': 1,
#  '킹왕짱': 2,
#  '가을': 14,
#  '전기장판': 1,
#  '합리': 28,
#  '취소': 68,
#  '주의': 5,
#  '흰색': 4,
#  '빨': 58,
#  '상인': 1,
#  '죤': 2,
#  '읍': 44,
#  '온스': 2,
#  '딸': 82,
#  '셈': 4,
#  '입점': 1,
#  '다양성': 7,
#  '엔드': 1,
#  '레인': 1,
#  '제사': 1,
#  '이제야': 8,
#  '가끔': 66,
#  '설명': 96,
#  '개봉': 2,
#  '야채': 2,
#  '웬': 3,
#  '요리사': 1,
#  '칼': 9,
#  '소리': 17,
#  '주방': 6,
#  '셋뚜': 1,
#  '일부': 6,
#  '특': 42,
#  '여러': 26,
#  '종류': 24,
#  '차이': 7,
#  '일색': 2,
#  '로고': 3,
#  '시장': 3,
#  '장만': 11,
#  '왼쪽': 9,
#  '덧': 4,
#  '창의': 2,
#  '마무리': 4,
#  '게': 46,
#  '경량': 1,
#  '손': 25,
#  '베이지': 8,
#  '완전': 217,
#  '디퓨져': 1,
#  '냄새': 15,
#  '달': 31,
#  '강력': 14,
#  '방도': 2,
#  '향기': 8,
#  '제스처': 1,
#  '동의': 39,
#  '허용': 6,
#  '태임': 1,
#  '라이브': 10,
#  '안내': 34,
#  '팝업창': 6,
#  '뭡': 12,
#  '검정색': 3,
#  '무상': 2,
#  '제스쳐': 2,
#  '안함': 6,
#  '핸드폰': 56,
#  '팝업': 21,
#  '날': 48,
#  '최우수': 1,
#  '저가': 4,
#  '클랜': 1,
#  '어제': 31,
#  '세수': 1,
#  '여태': 5,
#  '촉감': 59,
#  '담': 17,
#  '링크': 18,
#  '다운': 200,
#  '주네': 11,
#  '마케팅': 4,
#  '수법': 1,
#  '사기꾼': 16,
#  '신영와코루': 5,
#  '편안함': 12,
#  '재품': 9,
#  '구성': 112,
#  '수분': 6,
#  '수량': 13,
#  '추석': 6,
#  '강': 72,
#  '실내': 3,
#  '냉감': 1,
#  '조치': 15,
#  '듀얼': 5,
#  '쇼닉': 1,
#  '맥시': 5,
#  '엄': 4,
#  '한지': 13,
#  '매일': 83,
#  '선택': 118,
#  '금번': 1,
#  '스키': 1,
#  '과장': 4,
#  '만족도': 17,
#  '차이나': 1,
#  '참고': 23,
#  '시정': 5,
#  '해주시': 13,
#  '한가지': 12,
#  '손쇱': 1,
#  '계기': 2,
#  '소비자': 51,
#  '욕구': 6,
#  '신뢰': 34,
#  '사업': 5,
#  '콘': 3,
#  '테츠': 2,
#  '수준': 16,
#  '건투': 1,
#  '누룽지': 1,
#  '그릇': 9,
#  '오일': 2,
#  '무늬': 2,
#  '가게': 8,
#  '실패': 20,
#  '속옷': 104,
#  '사면': 14,
#  '진': 12,
#  '부피': 1,
#  '단어': 6,
#  '편성표': 34,
#  '예고': 2,
#  '처럼': 7,
#  '표현': 5,
#  '방식': 10,
#  '뭘': 46,
#  '도통': 2,
#  '시도': 43,
#  '소용': 2,
#  '머릿수': 1,
#  '편': 42,
#  '일반': 10,
#  '콜라겐': 3,
#  '인지': 5,
#  '모발': 4,
#  '스스로': 5,
#  '강추': 82,
#  '킹': 3,
#  '포토': 3,
#  '퀸': 2,
#  '한장': 4,
#  '기횟거': 1,
#  '움': 30,
#  '비교': 48,
#  '딸도': 5,
#  '코디': 5,
#  '함': 103,
#  '폭': 8,
#  '은한': 1,
#  '위생': 3,
#  '베스트': 6,
#  '햇': 73,
#  '마감': 3,
#  '박': 4,
#  '킵킵': 1,
#  '힘안': 1,
#  '청소': 4,
#  '갑자기': 54,
#  '끝': 18,
#  '돋보기': 1,
#  '며칠': 30,
#  '무것': 1,
#  '불가능': 2,
#  '렌': 2,
#  '시아': 1,
#  '로그아웃': 45,
#  '플레이스토어': 8,
#  '제거': 40,
#  '누르기': 3,
#  '자꾸': 199,
#  '눌려': 3,
#  '아차': 1,
#  '순간': 21,
#  '여지': 2,
#  '벌써': 20,
#  '지게': 4,
#  '타이': 4,
#  '트업': 1,
#  '이마': 3,
#  '라인업': 1,
#  '대체': 19,
#  '분위기': 3,
#  '음식': 5,
#  '듭': 94,
#  '학원': 1,
#  '동기': 1,
#  '간식': 5,
#  '반응': 11,
#  '소매': 2,
#  '길': 7,
#  '최상': 7,
#  '시일': 4,
#  '세트': 44,
#  '여행': 24,
#  '간지': 1,
#  '짱짱': 34,
#  '스튜디오': 2,
#  '아들': 42,
#  '발사이즈': 1,
#  '워낙': 9,
#  '부탁': 32,
#  '전반': 6,
#  '한국': 3,
#  '달리': 10,
#  '나나': 1,
#  '난': 19,
#  '누': 7,
#  '컬리': 5,
#  '티': 26,
#  '마켓': 7,
#  '더비': 1,
#  '미니': 2,
#  '서랍': 1,
#  '바보': 5,
#  '미끼': 3,
#  '결재': 35,
#  '직원': 17,
#  '무료': 25,
#  '포함': 11,
#  '줄알': 1,
#  '더니': 18,
#  '반나절': 3,
#  '지방': 1,
#  '완료': 37,
#  '가구': 6,
#  '짱': 126,
#  '새치기': 1,
#  '밀렷겟군': 1,
#  '식': 22,
#  '대기업': 22,
#  '짓': 10,
#  '오만원': 1,
#  '떼': 21,
#  '코': 8,
#  '거래': 8,
#  '동서': 1,
#  '클리': 1,
#  '사랍': 1,
#  '뱃살': 8,
#  '청바지': 7,
#  '자동실행': 8,
#  '위해': 26,
#  '벌': 14,
#  '바람': 8,
#  '정장': 3,
#  '팔꿈치': 1,
#  '길이': 29,
#  '무릎': 2,
#  '딮': 1,
#  '장딴지': 1,
#  '단도': 1,
#  '태도': 4,
#  '곤색': 1,
#  '자주색': 1,
#  '원피스': 15,
#  '하나로': 9,
#  '외출': 23,
#  '준비': 21,
#  '한해': 5,
#  '에어': 4,
#  '프라이어': 2,
#  '땀': 13,
#  '보푸라기': 1,
#  '특성': 4,
#  '모드': 3,
#  '안바': 1,
#  '하라': 82,
#  '콜센터': 4,
#  '상의': 6,
#  '적립금': 165,
#  '소진': 1,
#  '타': 43,
#  '프로그램': 14,
#  '작성': 25,
#  '이전': 19,
#  '글': 40,
#  '저장': 9,
#  '장의': 1,
#  '리기': 2,
#  '상픔': 2,
#  '태반': 1,
#  '상담': 71,
#  '살때': 9,
#  '청': 5,
#  '번창': 33,
#  '소망': 1,
#  '셀렙숍': 1,
#  '홧': 2,
#  '팅': 10,
#  '후반': 7,
#  '입지': 2,
#  '니트': 25,
#  '종': 28,
#  '벌이': 3,
#  '각기': 1,
#  '드': 58,
#  '중이': 9,
#  '찜': 6,
#  '그게': 10,
#  '위': 36,
#  '디테': 8,
#  '운동': 21,
#  '배경': 2,
#  '모습': 19,
#  '패치': 7,
#  '걱정': 49,
#  '주말': 7,
#  '운딩': 2,
#  '우후': 1,
#  '신건': 1,
#  '등급': 24,
#  '매진': 22,
#  '인기': 9,
#  '옵션': 12,
#  '보시': 9,
#  '살수': 64,
#  '티몬': 5,
#  '쿠팡': 18,
#  '실망': 36,
#  '권리': 2,
#  '푸시': 14,
#  '차단': 18,
#  '업뎃': 53,
#  '강요': 3,
#  '짓거리': 1,
#  '최악': 96,
#  '일방': 1,
#  '덕': 7,
#  '실시간': 18,
#  '메이져': 1,
#  '임': 77,
#  '배송지': 14,
#  '기본': 27,
#  '지지': 3,
#  '돈좀': 2,
#  '영진': 1,
#  '수신': 3,
#  '메시지': 5,
#  '쉬': 21,
#  '과도': 3,
#  '가까이': 4,
#  '최소': 1,
#  '하루': 84,
#  '종일': 29,
#  '테러': 1,
#  '능': 2,
#  '가슴': 25,
#  '선도': 3,
#  '와이어': 6,
#  '브라': 49,
#  '얘': 4,
#  '팬티': 63,
#  '사각팬티': 9,
#  '욤': 13,
#  '카톡': 12,
#  '문자': 52,
#  '온': 21,
#  '풀': 9,
#  '폴더': 1,
#  '유지': 10,
#  '최하': 1,
#  '직관': 10,
#  '번가': 6,
#  '세분': 2,
#  '제작': 2,
#  '거나': 12,
#  '머리': 58,
#  '회원': 159,
#  '얘기': 10,
#  '감수': 1,
#  '목도': 1,
#  '목티': 1,
#  '프라': 2,
#  '기': 38,
#  '생기': 10,
#  '지난번': 8,
#  '기억': 4,
#  '배경화면': 1,
#  '중도': 1,
#  '창': 68,
#  '색': 29,
#  '굿': 432,
#  '서치': 2,
#  '와우': 13,
#  '민트': 1,
#  '케이스': 4,
#  '캘빈': 1,
#  '주변': 12,
#  '홍보': 18,
#  '입': 44,
#  '퇴근': 3,
#  '레이': 3,
#  '마냥': 4,
#  '고함': 9,
#  '나중': 5,
#  '진행': 21,
#  '구함': 1,
#  '소정': 1,
#  '쓰레기': 62,
#  '높은펀': 1,
#  '환불': 23,
#  '초': 5,
#  '스피드': 2,
#  '절차': 14,
#  '확': 16,
#  '젔습': 1,
#  '가족': 22,
#  '욥': 4,
#  '휴대폰': 33,
#  '제멋대로': 3,
#  '먼저': 21,
#  '의도': 2,
#  '물': 10,
#  '흡수': 13,
#  '만날': 4,
#  '친척': 1,
#  '선별': 2,
#  '되엇어': 1,
#  '유': 9,
#  '분기': 2,
#  '기미': 30,
#  '별': 57,
#  '권유': 6,
#  '센텰': 1,
#  '리안': 2,
#  '앰플': 15,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
