# %% [markdown]
# # 리뷰 데이터 수집

# %%
# https://play.google.com/store/apps/details?id=kr.co.ssg&hl=ko-KR

# %%
import pandas as pd
from google_play_scraper import app
from google_play_scraper import Sort,reviews_all
reviews = reviews_all("kr.co.ssg",
                      sleep_milliseconds=0,
                      lang = "ko",
                      country = "KR",
                      sort = Sort.NEWEST)

# %%
import numpy as np
# raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
# raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
# df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
# df.head()
# raw_df.to_csv('./data/oliveyoung_raw.csv',index=False)
# df.to_csv('./data/oliveyoung_df.csv',index=False)

# %%
def reviews_df(reviews,name):
    raw_df = pd.DataFrame(np.array(reviews),columns=["review"])
    raw_df =raw_df.join(pd.DataFrame(raw_df.pop("review").to_list()))
    df = raw_df.drop(['reviewId','userName','userImage','replyContent','repliedAt','reviewCreatedVersion','appVersion'],axis=1,inplace=False)
    df.head()
    df.to_csv(f'./data/01.리뷰키워드분석_01통합본_{name}_리뷰크롤링파일.csv',index=False)
    return raw_df, df

# %%
raw,df = reviews_df(reviews,'SSG')

# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df.dropna(subset="content",axis=0,inplace=True)

# %%
def tokenize(dataFrame):
    okt = Okt()
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    tokenize(dataFrame)
    remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <2629x2590 sparse matrix of type '<class 'numpy.int64'>'
# 	with 10377 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <2629x2590 sparse matrix of type '<class 'numpy.float64'>'
# 	with 10377 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '열 어플 쿠폰 뭐 적용 적용 주문 어플 삭제 마이 페이지 자사 구독 상품 광고 별로 물건 팔고 어플 광고 어플,정말 쓱 주문 정말 마음 앱 현장 정성 서비스 비 정말 형편 툭하면 앱 리뷰 작성 멋데 화면 리셋 윈도우 미러링 블루투스 키 보드 마우스 사용 기기 지원 기기 지원 작성 튕기 수정 개선 전혀 관련 수정 예정 끝 앱 개발 외주 차체팀 개발 여러 쇼핑몰 앱 이용 카테고리 수정 이용자 편의 앱 요즘 찾기 리뷰 작성 이용자 손가락 관절염 음성 입력 주문 상황 가야 개선 겁,이후 접속 버퍼링 계속 아예 화면 로딩 계속 사진 아예 와이파이 모드 데이터 모드 로딩 갑자기 개선 밤 쇼핑 수가,와이파이 환경 접속 데이터 실행 업데이트 마찬가지 상품 상세 보기 마찬가지 와이파이 환경 페이지 표시 화면 데이터 제품 상세 페이지 볼 와이파이 환경 실행 예전 글,가격 동네 마트 간혹 품절 사용 환경 부적절 실시간 정보 업데이트 오류 발생 처음 현관 비밀번호 보이스피싱 결제 수단 복잡 쓱카 카드 자꾸 자동 체크 간편 결제 신용 결제 앱 몇개 인터페이스 복잡 화면 글 외 이유 사이트 이벤트 한번 삭제,개선 이마트 트 레이더스 새벽 배송 앱 통화 부분 고객 만족도 추가 건의 사항 베스트 랭킹 진짜 베스트 의문 리스트 던데 확인 메커니즘 동작 대부분 쇼핑몰 앱 추가 혜택 앱 설치 강제 뽐뿌 핫딜 통해 주로 사용 쇼핑몰 신선 배송 경쟁력 일반 쇼핑몰 경쟁력 핫딜 제품 뽐뿌 통해 앱 설치 유인 신선 배송 쇼핑몰 양쪽 윈윈 개발자 주주 사용자 로서 건의 앱 기능 기능 단점 사용자 이마트 트 레이더스 크게 물건 구입 관심 관계 통합 기능 통합,여러 모로 취급 상품 퀄리
기 설정 검색 자동 필터 사이즈 보기 클릭 쿠팡 이기 쿠팡 어플 차이 검색 관련 항목 상위 신발 사이즈 필터 링 자동 고생,신세계 백화점 쇼핑 쇼핑몰 이마트 제외 대부분 주문 품절 주문 취소 문자 옴 백화점 전화 재고 제품 온라인쇼핑 문의 재고 주문 움 생기 신세계 쇼핑 픽업,선 별 이건정 최악 신세계 상품권 스 려고 배송 주소 뭐 검색 클릭 확인 드 래그 밑 에버튼 반의 반 빼꼼 드래그 윈도 공인 인증서 세대 앱 결제 주문 어플 처음 봄,업뎃 전이 업뎃 쓱 배송 계속 화면 필터 화면 이미지 속도 업데이트,리뷰 사진 장만 선택 장 사진 업로드 시 한장 등록 시스템 한번 장 등록,단계 앱 사용성 고객 센터 식품 반품 관련 접근성 문의 버튼 하단 찾기 고객 센터 톡 기능 권한 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'열': 16,
#  '어플': 129,
#  '쿠폰': 100,
#  '뭐': 81,
#  '적용': 27,
#  '주문': 126,
#  '삭제': 71,
#  '마이': 4,
#  '페이지': 37,
#  '자사': 2,
#  '구독': 1,
#  '상품': 164,
#  '광고': 133,
#  '별로': 31,
#  '물건': 81,
#  '팔고': 1,
#  '정말': 59,
#  '쓱': 118,
#  '마음': 9,
#  '앱': 448,
#  '현장': 3,
#  '정성': 1,
#  '서비스': 30,
#  '비': 12,
#  '형편': 3,
#  '툭하면': 3,
#  '리뷰': 49,
#  '작성': 8,
#  '멋데': 1,
#  '화면': 52,
#  '리셋': 3,
#  '윈도우': 1,
#  '미러링': 1,
#  '블루투스': 2,
#  '키': 14,
#  '보드': 8,
#  '마우스': 1,
#  '사용': 159,
#  '기기': 4,
#  '지원': 5,
#  '튕기': 8,
#  '수정': 24,
#  '개선': 47,
#  '전혀': 12,
#  '관련': 11,
#  '예정': 10,
#  '끝': 8,
#  '개발': 8,
#  '외주': 1,
#  '차체팀': 1,
#  '여러': 5,
#  '쇼핑몰': 45,
#  '이용': 65,
#  '카테고리': 16,
#  '이용자': 5,
#  '편의': 11,
#  '요즘': 17,
#  '찾기': 21,
#  '손가락': 2,
#  '관절염': 1,
#  '음성': 1,
#  '입력': 28,
#  '상황': 7,
#  '가야': 4,
#  '겁': 10,
#  '이후': 9,
#  '접속': 18,
#  '버퍼링': 2,
#  '계속': 99,
#  '아예': 13,
#  '로딩': 22,
#  '사진': 17,
#  '와이파이': 8,
#  '모드': 2,
#  '데이터': 6,
#  '갑자기': 32,
#  '밤': 3,
#  '쇼핑': 88,
#  '수가': 15,
#  '환경': 7,
#  '실행': 49,
#  '업데이트': 94,
#  '마찬가지': 7,
#  '상세': 11,
#  '보기': 25,
#  '표시': 12,
#  '제품': 66,
#  '볼': 9,
#  '예전': 11,
#  '글': 16,
#  '가격': 55,
#  '동네': 1,
#  '마트': 23,
#  '간혹': 1,
#  '품절': 76,
#  '부적절': 1,
#  '실시간': 6,
#  '정보': 29,
#  '오류': 89,
#  '발생': 15,
#  '처음': 43,
#  '현관': 1,
#  '비밀번호': 25,
#  '보이스피싱': 1,
#  '결제': 167,
#  '수단': 6,
#  '복잡': 3,
#  '쓱카': 1,
#  '카드': 50,
#  '자꾸': 59,
#  '자동': 30,
#  '체크': 14,
#  '간편': 15,
#  '신용': 1,
#  '몇개': 6,
#  '인터페이스': 6,
#  '외': 4,
#  '이유': 17,
#  '사이트': 24,
#  '이벤트': 35,
#  '한번': 36,
#  '이마트': 114,
#  '트': 14,
#  '레이더스': 11,
#  '새벽': 25,
#  '배송': 252,
#  '통화': 5,
#  '부분': 15,
#  '고객': 76,
#  '만족도': 2,
#  '추가': 15,
#  '건의': 4,
#  '사항': 5,
#  '베스트': 2,
#  '랭킹': 1,
#  '진짜': 92,
#  '의문': 3,
#  '리스트': 3,
#  '던데': 2,
#  '확인': 56,
#  '메커니즘': 1,
#  '동작': 1,
#  '대부분': 5,
#  '혜택': 20,
#  '설치': 103,
#  '강제': 18,
#  '뽐뿌': 2,
#  '핫딜': 2,
#  '통해': 8,
#  '주로': 2,
#  '신선': 8,
#  '경쟁력': 4,
#  '일반': 4,
#  '유인': 1,
#  '양쪽': 1,
#  '윈윈': 1,
#  '개발자': 12,
#  '주주': 2,
#  '사용자': 17,
#  '로서': 1,
#  '기능': 29,
#  '단점': 2,
#  '크게': 2,
#  '구입': 18,
#  '관심': 4,
#  '관계': 2,
#  '통합': 21,
#  '모로': 3,
#  '취급': 1,
#  '퀄리티': 3,
#  '최고': 47,
#  '쓰기': 12,
#  '등록': 27,
#  '글자': 2,
#  '띄어쓰기': 1,
#  '연속': 3,
#  '해당': 2,
#  '시도': 15,
#  '팝업': 11,
#  '메시지': 2,
#  '내용': 10,
#  '후기': 2,
#  '단말기': 1,
#  '갤럭시': 6,
#  '장바구니': 52,
#  '순서': 4,
#  '최신': 4,
#  '순이': 1,
#  '기준': 5,
#  '정렬': 9,
#  '규칙': 1,
#  '일시': 3,
#  '순': 9,
#  '배송지': 17,
#  '별': 24,
#  '판매': 26,
#  '전화': 21,
#  '연락': 21,
#  '연락처': 2,
#  '센터': 41,
#  '접근': 3,
#  '반품': 21,
#  '교환': 7,
#  '프로세스': 4,
#  '지마켓': 4,
#  '듯': 19,
#  '수고': 4,
#  '공통': 1,
#  '영역': 1,
#  '빈': 2,
#  '페이': 36,
#  '평소': 5,
#  '신용카드': 3,
#  '도저히': 1,
#  '선택': 32,
#  '어차피': 2,
#  '거': 80,
#  '어쨌든': 1,
#  '코로나': 6,
#  '장': 8,
#  '장보기': 11,
#  '디폴트': 1,
#  '설정': 29,
#  '조절': 1,
#  '면': 1,
#  '검토': 1,
#  '직관': 7,
#  '버벅거': 1,
#  '린다': 2,
#  '사양': 2,
#  '폰': 31,
#  '의심': 2,
#  '브랜드': 11,
#  '건': 18,
#  '클릭': 17,
#  '찜': 1,
#  '버튼': 25,
#  '제일': 7,
#  '위': 8,
#  '과유': 1,
#  '불급': 1,
#  '짜증': 12,
#  '빼': 1,
#  '모든': 11,
#  '저절로': 2,
#  '로그아웃': 7,
#  '비번': 37,
#  '포인트': 29,
#  '소멸': 1,
#  '대서': 2,
#  '의도': 3,
#  '매우': 20,
#  '실망': 12,
#  '옴': 11,
#  '쓷': 1,
#  '갈수록': 3,
#  '이상은': 3,
#  '불가': 4,
#  '던지기': 1,
#  '기본': 11,
#  '묶음': 4,
#  '라벨': 1,
#  '락스': 3,
#  '몸': 4,
#  '젠': 3,
#  '그냥': 56,
#  '맘': 14,
#  '쪽': 4,
#  '택배': 16,
#  '기사': 13,
#  '심': 1,
#  '주시': 3,
#  '감': 2,
#  '민폐': 1,
#  '직구': 3,
#  '보름': 4,
#  '조회': 10,
#  '가입': 81,
#  '하라': 20,
#  '신세계': 78,
#  '상품권': 28,
#  '생기': 2,
#  '라지': 1,
#  '세상': 5,
#  '장보고': 3,
#  '시작': 11,
#  '답변': 12,
#  '쪼끔': 1,
#  '감명': 1,
#  '영상': 3,
#  '열정': 1,
#  '일전': 2,
#  '시스템': 24,
#  '계': 5,
#  '터치': 6,
#  '재': 16,
#  '로그인': 96,
#  '화': 2,
#  '이쯤': 2,
#  '호구': 3,
#  '임': 38,
#  '수준': 7,
#  '우리나라': 2,
#  '가장': 9,
#  '뭐함': 1,
#  '보유': 1,
#  '기업': 5,
#  '점점': 7,
#  '하나로': 7,
#  '백화점': 24,
#  '매장': 9,
#  '검색': 72,
#  '오픈마켓': 5,
#  '느낌': 14,
#  '유니버스': 4,
#  '클럽': 5,
#  '그닥': 1,
#  '각성': 1,
#  '대기업': 23,
#  '기존': 5,
#  '시': 36,
#  '상단': 5,
#  '꼭': 10,
#  '스': 14,
#  '크롤': 7,
#  '만듬': 3,
#  '바닥': 1,
#  '침': 2,
#  '방식': 5,
#  '어둠': 2,
#  '목록': 13,
#  '아주': 35,
#  '퓸절': 1,
#  '환불': 49,
#  '짓': 8,
#  '몇번': 20,
#  '반복': 8,
#  '후회': 3,
#  '온라인': 13,
#  '구매': 72,
#  '적극': 1,
#  '조치': 4,
#  '일방': 7,
#  '응답': 3,
#  '손절': 2,
#  '쿠팡': 49,
#  '회사': 25,
#  '윤리': 1,
#  '만원': 5,
#  '할인': 59,
#  '컷': 1,
#  '행태': 1,
#  '어제': 7,
#  '오늘': 34,
#  '대기': 7,
#  '상태': 6,
#  '보임': 2,
#  '신청': 7,
#  '자가': 3,
#  '취소': 50,
#  '아치': 5,
#  '역대': 5,
#  '최악': 52,
#  '용감': 1,
#  '선물': 12,
#  '주소': 12,
#  '뒤': 14,
#  '맥락': 1,
#  '수만': 1,
#  '지속': 4,
#  '하자': 3,
#  '로그': 7,
#  '아웃': 1,
#  '변경': 19,
#  '원클릭': 1,
#  '진행': 14,
#  '라운드': 6,
#  '박스': 1,
#  '봉투': 1,
#  '품질': 9,
#  '중간': 3,
#  '아이디어': 3,
#  '덕분': 4,
#  '판매량': 1,
#  '의미': 1,
#  '혼란': 1,
#  '라이브': 6,
#  '고정': 2,
#  '온통': 1,
#  '배너': 6,
#  '천지': 2,
#  '제대로': 28,
#  '성향': 1,
#  '기록': 3,
#  '맞춤': 2,
#  '품목': 12,
#  '제안': 1,
#  '비교': 13,
#  '엉터리': 1,
#  '네이버': 20,
#  '닌텐도': 1,
#  '스위치': 1,
#  '게임': 13,
#  '제노': 1,
#  '블레이드': 1,
#  '특': 6,
#  '문자': 14,
#  '송장': 2,
#  '번호': 14,
#  '허위': 6,
#  '방법': 19,
#  '소보원': 2,
#  '요청': 7,
#  '건가': 21,
#  '홈플러스': 4,
#  '매출': 6,
#  '하락': 1,
#  '인지': 1,
#  '재고': 34,
#  '관리': 34,
#  '구해': 1,
#  '네트워크': 26,
#  '불안': 2,
#  '정이': 2,
#  '원래': 5,
#  '불': 6,
#  '안정': 6,
#  '알람': 5,
#  '금방': 3,
#  '못': 21,
#  '고치': 3,
#  '단골': 1,
#  '보고': 24,
#  '핸드폰': 9,
#  '연결': 26,
#  '해제': 2,
#  '항상': 22,
#  '전달': 2,
#  '웹뷰': 7,
#  '자주': 37,
#  '파일': 2,
#  '십년': 1,
#  '쯤': 2,
#  '인터넷': 20,
#  '개불': 3,
#  '굳이': 4,
#  '스트레스': 10,
#  '필요': 9,
#  '개구': 1,
#  '린': 1,
#  '돈': 26,
#  '지연': 5,
#  '부가': 1,
#  '입장': 4,
#  '기분': 12,
#  '뜸': 11,
#  '물품': 19,
#  '먼저': 6,
#  '봄': 4,
#  '탄소': 1,
#  '어쩌': 9,
#  '니': 15,
#  '이득': 2,
#  '소비자': 21,
#  '걱정': 3,
#  '뿐': 8,
#  '옵션': 4,
#  '차별': 3,
#  '지정': 1,
#  '여러가지': 3,
#  '창': 37,
#  '번거러워': 1,
#  '오류로': 2,
#  '결재': 29,
#  '제휴': 3,
#  '충전': 5,
#  '떼': 2,
#  '에전': 1,
#  '애': 2,
#  '마다': 2,
#  '전환': 15,
#  '가요': 20,
#  '컴터': 2,
#  '홈': 5,
#  '욕': 9,
#  '글케': 2,
#  '일부': 10,
#  '미적': 2,
#  '용이': 1,
#  '제외': 5,
#  '가능': 6,
#  '계산': 4,
#  '금액': 11,
#  '점도': 2,
#  '움': 7,
#  '상담사': 15,
#  '거짓말': 4,
#  '준비': 13,
#  '문의': 34,
#  '발송': 5,
#  '장난': 14,
#  '첨부': 3,
#  '터': 2,
#  '식': 10,
#  '곳': 28,
#  '안해': 4,
#  '직전': 2,
#  '임의': 2,
#  '완료': 20,
#  '처리': 27,
#  '현황': 2,
#  '고지': 2,
#  '직접': 13,
#  '특정': 2,
#  '배': 7,
#  '라식': 1,
#  '톡': 13,
#  '전체': 3,
#  '씈': 2,
#  '자체': 9,
#  '확인가능': 1,
#  '여기저기': 4,
#  '일일이': 3,
#  '꽤': 2,
#  '이제': 24,
#  '곤': 1,
#  '자제': 1,
#  '엉망': 14,
#  '논': 2,
#  '항목': 3,
#  '반영': 5,
#  '가기': 4,
#  '위치': 3,
#  '어보': 1,
#  '업뎃': 13,
#  '동일': 3,
#  '증상': 3,
#  '제발': 20,
#  '편법': 1,
#  '메인': 2,
#  '퍼포먼스': 2,
#  '기네': 1,
#  '칸': 3,
#  '애니메이션': 1,
#  '듬': 2,
#  '조잡': 1,
#  '권한': 9,
#  '허용': 4,
#  '휴대폰': 13,
#  '와중': 2,
#  '화통': 1,
#  '누락': 2,
#  '채': 1,
#  '통보': 8,
#  '답': 11,
#  '이전': 4,
#  '음식물': 1,
#  '상': 4,
#  '연달': 1,
#  '신발': 6,
#  '사이즈': 9,
#  '아디다스': 1,
#  '콜드': 1,
#  '레디': 1,
#  '란': 4,
#  '필터': 4,
#  '이기': 2,
#  '차이': 1,
#  '상위': 1,
#  '링': 1,
#  '고생': 3,
#  '온라인쇼핑': 1,
#  '픽업': 3,
#  '선': 1,
#  '이건정': 1,
#  '려고': 5,
#  '드': 19,
#  '래그': 3,
#  '밑': 6,
#  '에버튼': 1,
#  '반의': 1,
#  '반': 8,
#  '빼꼼': 1,
#  '윈도': 1,
#  '공인': 1,
#  '인증서': 8,
#  '세대': 1,
#  '전이': 2,
#  '이미지': 11,
#  '속도': 11,
#  '장만': 1,
#  '업로드': 1,
#  '한장': 2,
#  '단계': 3,
#  '사용성': 4,
#  '식품': 9,
#  '접근성': 3,
#  '하단': 4,
#  '주지': 2,
#  '설계': 2,
#  '경험': 7,
#  '가공품': 2,
#  '노': 5,
#  '알임': 1,
#  '해': 23,
#  '주가': 2,
#  '인': 1,
#  '스턴': 1,
#  '달': 18,
#  '가까이': 3,
#  '습솬적': 1,
#  '워낙': 1,
#  '함': 45,
#  '물검': 1,
#  '반나절': 1,
#  '일쑤': 1,
#  '가끔': 14,
#  '그동안': 6,
#  '스토어': 4,
#  '일도': 3,
#  '뭡': 4,
#  '상담': 22,
#  '도대체': 13,
#  '일부러': 4,
#  '이건': 14,
#  '확보': 12,
#  '고요': 2,
#  '입': 4,
#  '장보': 10,
#  '가도': 2,
#  '옷': 6,
#  '귀걸이': 1,
#  '딜': 4,
#  '추세': 2,
#  '역행': 1,
#  '최근': 9,
#  '어플리케이션': 1,
#  '왼쪽': 2,
#  '무단': 1,
#  '현상': 4,
#  '하니': 12,
#  '히루빨리': 1,
#  '챠': 1,
#  '두시': 1,
#  '탈퇴': 13,
#  '정책': 2,
#  '최대': 4,
#  '기간': 3,
#  '경과': 1,
#  '회원': 55,
#  '점검': 6,
#  '참고': 7,
#  '콜센터': 2,
#  '부서': 3,
#  '늘': 5,
#  '자원': 1,
#  '배터리': 1,
#  '쭉쭉': 1,
#  '분': 13,
#  '정신': 8,
#  '날': 16,
#  '사고': 5,
#  '운전': 2,
#  '활짝': 1,
#  '여름': 1,
#  '완전': 17,
#  '주위': 2,
#  '친구': 2,
#  '추천': 12,
#  '강추': 2,
#  '세션': 6,
#  '만료': 5,
#  '문구': 5,
#  '쇼필': 1,
#  '운영': 8,
#  '뭘': 13,
#  '사라': 4,
#  '오지': 14,
#  '중이': 5,
#  '네크워트': 1,
#  '잘만': 4,
#  '절대': 9,
#  '아침': 8,
#  '태블릿': 1,
#  '검색어': 8,
#  '오전': 8,
#  '노트북': 3,
#  '유튭': 1,
#  '음악': 3,
#  '아무': 5,
#  '지장': 2,
#  '장본': 2,
#  '뭔가': 13,
#  '수십': 2,
#  '대입': 1,
#  '프로필': 1,
#  '회원정보': 2,
#  '연배': 1,
#  '가치': 3,
#  '아이디': 17,
#  '계정': 10,
#  '연동': 12,
#  '검수': 1,
#  '고차원': 1,
#  '넷마블': 1,
#  '화창': 1,
#  '타': 15,
#  '종료': 20,
#  '어무': 1,
#  '이동': 7,
#  '좀더': 5,
#  '수영선': 1,
#  '양복': 1,
#  '풀': 2,
#  '간': 4,
#  '둘러보기': 1,
#  '다운': 34,
#  '웹앱': 1,
#  '통한': 1,
#  '면서': 3,
#  '아트': 3,
#  '쓹': 2,
#  '적립': 6,
#  '근래': 1,
#  '하급': 1,
#  '폴더': 1,
#  '밖': 3,
#  '편리': 7,
#  '성도': 5,
#  '제거': 7,
#  '홈쇼핑': 2,
#  '코너': 2,
#  '겸용': 1,
#  '휴면': 5,
#  '껏': 3,
#  '다가': 4,
#  '켯는데': 1,
#  '바꿧던': 1,
#  '설명': 11,
#  '답글': 3,
#  '공백': 1,
#  '니요': 1,
#  '대소문자': 1,
#  '뇨': 2,
#  '인증': 33,
#  '걸': 26,
#  '탓': 2,
#  '다해': 2,
#  '초기': 2,
#  '릴': 1,
#  '트럭': 3,
#  '뜰': 1,
#  '에러': 9,
#  '공지': 3,
#  '시대': 3,
#  '프로그램': 5,
#  '임원진': 1,
#  '추측': 1,
#  '애꿎': 1,
#  '말단': 1,
#  '사원': 2,
#  '확장': 2,
#  '퀼트': 1,
#  '쿠': 4,
#  '포맷': 1,
#  '컴': 8,
#  '실속': 2,
#  '손': 6,
#  '취지': 1,
#  '요새': 1,
#  '구성': 5,
#  '가시': 1,
#  '안드': 3,
#  '랜딩': 1,
#  '썩': 2,
#  '눈': 3,
#  '잡지': 1,
#  '체감': 2,
#  '금융': 1,
#  '강요': 2,
#  '욕구': 1,
#  '자취': 2,
#  '혁명': 1,
#  '정': 7,
#  '외출': 1,
#  '생': 1,
#  '마켓': 6,
#  '옥션': 3,
#  '말로': 3,
#  '무료': 8,
#  '연장': 2,
#  '냎': 1,
#  '줄알': 2,
#  '게시판': 1,
#  '스마일': 4,
#  '요구사항': 1,
#  '제기': 1,
#  '배송비': 13,
#  '수동': 1,
#  '반성': 1,
#  '주심': 2,
#  '신하': 1,
#  '프로': 9,
#  '사도': 1,
#  '치': 5,
#  '오프라인': 6,
#  '남자': 1,
#  '직원': 16,
#  '상술': 2,
#  '멤버십': 1,
#  '한적': 4,
#  '자고': 2,
#  '핸펀': 3,
#  '재부팅': 1,
#  '대제': 1,
#  '일주일': 13,
#  '대체': 9,
#  '팝업창': 1,
#  '아래': 7,
#  '막': 1,
#  '적도': 3,
#  '종류': 6,
#  '가성': 5,
#  '웹': 13,
#  '음': 7,
#  '타이밍': 2,
#  '소요': 1,
#  '순간': 2,
#  '그게': 2,
#  '평점': 7,
#  '해결': 19,
#  '아보': 1,
#  '최소한': 4,
#  '도도': 1,
#  '커서': 1,
#  '통틀어': 1,
#  '대한': 5,
#  '오픈': 3,
#  '공유': 9,
#  '토요일': 1,
#  '월요일': 4,
#  '예약': 9,
#  '제온': 1,
#  '일정': 2,
#  '하루': 10,
#  '종일': 2,
#  '그림': 2,
#  '듯함': 1,
#  '일해': 1,
#  '알림': 28,
#  '쉬': 8,
#  '계열': 6,
#  '스플래쉬': 1,
#  '과도': 1,
#  '기도': 2,
#  '노티': 2,
#  '구려': 3,
#  '른': 2,
#  '횟수': 1,
#  '평이': 1,
#  '인정': 2,
#  '신경안': 1,
#  '한다해': 1,
#  '공효진': 3,
#  '죄임': 1,
#  '별롭': 1,
#  '모자라': 2,
#  '롯데': 10,
#  '평': 4,
#  '불량': 4,
#  '회수': 3,
#  '입금': 17,
#  '온건': 1,
#  '땜': 18,
#  '화남': 1,
#  '저번': 5,
#  '머리': 2,
#  '장점': 1,
#  '미만': 1,
#  '포기': 6,
#  '도움': 7,
#  '공산품': 2,
#  '차감': 4,
#  '해주시': 2,
#  '나머지': 1,
#  '대금': 1,
#  '귀책사유': 1,
#  '영수증': 3,
#  '역': 2,
#  '자동실행': 2,
#  '방안': 2,
#  '카메라': 2,
#  '마이크': 3,
#  '무조건': 6,
#  '허가': 5,
#  '납득': 1,
#  '뿐더러': 1,
#  '어쨌거': 1,
#  '법': 4,
#  '오후': 4,
#  '온': 3,
#  '유료': 1,
#  '멤버': 5,
#  '도입': 1,
#  '문턱': 1,
#  '해외': 1,
#  '바지': 1,
#  '다인': 1,
#  '주말': 6,
#  '배달': 24,
#  '이안': 3,
#  '왓': 3,
#  '나가야': 3,
#  '내일': 4,
#  '케어': 2,
#  '이해해': 1,
#  '줌': 4,
#  '제공': 5,
#  '소비': 2,
#  '정작': 3,
#  '우리카드': 1,
#  '기술': 2,
#  '손해': 1,
#  '마늘': 1,
#  '미끼상품': 4,
#  '저녁': 3,
#  '식빵': 1,
#  '유독': 1,
#  '바게트': 1,
#  '컷팅': 1,
#  '절': 2,
#  '왕': 6,
#  '대우': 2,
#  '예의': 1,
#  '대답': 3,
#  '마감': 2,
#  '개판': 4,
#  '사별': 1,
#  '유도': 7,
#  '땐': 4,
#  '분리': 2,
#  '고려': 3,
#  '서도': 3,
#  '달이': 3,
#  '거기': 3,
#  '사랑': 3,
#  '리부팅': 1,
#  '성장': 1,
#  '그룹': 2,
#  '애정': 2,
#  '투자': 1,
#  '판단': 1,
#  '버벅': 3,
#  '거리': 4,
#  '경쟁': 11,
#  '유통업체': 1,
#  '수도': 1,
#  '제한': 3,
#  '로켓': 4,
#  '버벅거림': 1,
#  '한도': 1,
#  '조정': 2,
#  '확대': 2,
#  '한국': 6,
#  '더욱': 4,
#  '매력': 1,
#  '이글': 2,
#  '담당자': 1,
#  '응원': 2,
#  '우롱': 5,
#  '청구': 5,
#  '최저': 5,
#  '캡쳐': 4,
#  '승인': 6,
#  '달라': 5,
#  '고함': 4,
#  '경고': 1,
#  '메세지': 5,
#  '본적': 1,
#  '합산': 1,
#  '방금': 4,
#  '게': 13,
#  '통': 4,
#  '사보': 1,
#  '사문': 1,
#  '현대인': 1,
#  '거저': 1,
#  '한정': 3,
#  '벌써': 4,
#  '나라': 4,
#  '애용': 5,
#  '가로': 2,
#  '탭': 3,
#  '세로': 1,
#  '졸라': 4,
#  '신한카드': 2,
#  '튕깁': 1,
#  '몰이': 5,
#  '열사': 5,
#  '분류': 2,
#  ...}

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
