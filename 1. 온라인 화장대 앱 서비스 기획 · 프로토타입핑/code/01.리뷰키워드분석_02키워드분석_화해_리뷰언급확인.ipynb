# %% [markdown]
# # 토큰화

# %%
import pandas as pd
from konlpy.tag import Okt
from sklearn.feature_extraction.text import CountVectorizer, TfidfTransformer

# %%
df = pd.read_csv('./data/01.리뷰키워드분석_01통합본_화해_리뷰크롤링파일.csv')
df = df.fillna('-')
df = df[df['content'].str.contains('리뷰')]

# %%
df['content'].isnull().sum()
df
# Out:
#                                                 content  score  thumbsUpCount  \
# 3     총평 - 사용자 수가 많은게 장점이고 그외에는 다 단점임 이용자 수만 많으면 옆동네...      3             54
# 6     이벤트 구란줄알고 반신반의로 신청했었는데 두번이나 걸려서 진짜 신기하고 감사했던 기...      5              0
# 9     잘 쓰고 있는데 두 가지 기능이 추가되면 좋겠습니다. 1. 유저차단 기능이 있었으면...      4            186
# 16    화장품 살 일 있을 때마다 정말 유용하게 잘쓰고있어요! 리뷰 작성해주시는 분들도 꼼...      3             42
# 22    화해를 통해서 많은 리뷰도 보고 정말 제게 맞는 유용하고 좋은 제품들을 많이 만날 ...      4              3
# ...                                                 ...    ...            ...
# 8120  성분명을 알기도 하고 그 성분이 피부 타입별로 어떤지 기능은 무엇인지 참고하는데 도...      5              0
# 8124  전성분을 봐도 이름이 어려워 한눈에 알아보기 힘들었는데 유해성분이나 피부 타입에 따...      5              0
# 8129  그동안 화장품에대해 무지했던 저를 팁들과 리뷰덕분에 많은 유익한 정보들을 보면서 화...      5              0
# 8138  피부가 민감해서 화장품 선택이 어려운데 성분 확인 및 다양한 사람들의 리뷰가 있어서...      5              0
# 8144  일단 사실 화장품에 대해 잘 아는 편이 아닌데 들어가면 성분.가격.순위도 뜨고 많은...      5              0
#
#                        at
# 3     2023-10-12 13:54:15
# 6     2024-02-18 16:00:11
# 9     2020-07-20 11:13:11
# 16    2020-03-13 01:12:53
# 22    2020-09-19 00:17:16
# ...                   ...
# 8120  2016-12-19 19:56:46
# 8124  2016-12-19 20:40:24
# 8129  2016-12-16 21:28:11
# 8138  2016-12-17 15:58:33
# 8144  2016-12-17 21:01:29
#
# [1193 rows x 4 columns]

# %%
def tokenize(dataFrame):
    okt = Okt()
    
    dataFrame['morphs'] = [okt.nouns(content) for content in dataFrame['content']]
    return dataFrame

def remove_stop_words(dataFrame):
    text = '~ ~~ ~~~ ~~~~ ~~~~~ ^ ^^ ! !! ㅜㅜ . .. , ,, 가 도 고 이고 이나 요 아 휴 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼 어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다 하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영 이 있 하 것 들 그 되 수 이 보 않 없 나 사람 주 아니 등 같 우리 때 년 가 한 지 대하 오 말 일 그렇 위하 때문 그것 두 말하 알 그러나 받 못하 일 그런 또 문제 더 사회 많 그리고 좋 크 따르 중 나오 가지 씨 시키 만들 지금 생각하 그러 속 하나 집 살 모르 적 월 데 자신 안 어떤 내 내 경우 명 생각 시간 그녀 다시 이런 앞 보이 번 나 다른 어떻 여자 개 전 들 사실 이렇 점 싶 말 정도 좀 원 잘 통하 놓 입니다' 
    stop_words = text.split(" ")
    stop_words_set = set(stop_words)
    dataFrame['morphs'] = [[word for word in morphs if word not in stop_words_set] for morphs in dataFrame['morphs']]
    return dataFrame

def dtm_maker(dataFrame):
    cv = CountVectorizer()
    dataFrame['morphs'] = dataFrame['morphs'].apply(lambda x: ' '.join(x) if isinstance(x, list) else x)
    dtm = cv.fit_transform(dataFrame['morphs'])
    return dtm

def tf_idf_maker(dtm):
    trans = TfidfTransformer()
    tf_idf = trans.fit_transform(dtm)
    return tf_idf

def data_preprocessing(dataFrame):
    dataframe = tokenize(dataFrame)
    dataframe = remove_stop_words(dataFrame)
    dtm = dtm_maker(dataFrame)
    
    return dataFrame,dtm

# %%
tokenized = tokenize(df)

# %%
dataframe, dtm = data_preprocessing(df)

# %%
dtm
# Out:
# <1193x2296 sparse matrix of type '<class 'numpy.int64'>'
# 	with 15606 stored elements in Compressed Sparse Row format>

# %%
tf_idf = tf_idf_maker(dtm)
tf_idf
# Out:
# <1193x2296 sparse matrix of type '<class 'numpy.float64'>'
# 	with 15606 stored elements in Compressed Sparse Row format>

# %% [markdown]
# # 단어구름

# %%
def col_to_doc(col):
    combined_list = col.tolist()
    combined_string = col.str.cat(sep=',')

    return combined_string

# %%
doc = col_to_doc(df['morphs'])
doc
# Out:
# '평 사용자 수가 장점 외 단점 임 이용자 수만 옆 동네 글로우픽 장점 이벤트 샘플 줌 제품 체험 가능 단점 보임 옥색 인테리어 느낌 정리 느낌 주의 성분 거 대체 한국 유사과학 잡채 랭킹 시스템 랭킹 샘플 단기간 리뷰 키 워드 선택 글로우픽 리뷰 키 워드 검색 자꾸 비교,이벤트 란줄알 반신반의 신청 진짜 기억 성분 배합 목적 포인트 리뷰 상품 구매 피부 키 워드 리뷰 정말 효과 키 워드 선택 효과 보기 장점 단점 정말,기능 추가 유저 차단 기능 해당 유저 차단 리뷰 댓글 일절 블라인드 처리 기능 프로필 상 웜톤 쿨톤 톤 설정 기능 톤 설정 색조 메이크업 제품 톤 매우 걸 수가 어플 사용,화장품 정말 리뷰 작성 분 작성 앱 업데이트 가요 업데이트 이벤트 참여 려고 몇개 상품 선택 개정 상품 선택 빈칸 폰 폰 폰 개선,화해 통해 리뷰 보고 정말 제품 만날 정말 앱 성분 피부 타입 별 랭킹 여러 리뷰 눈 볼 최애 앱 유튜브 통해 추천 제품 접 화해 앱 통해 기준 제품 과정 신세계 한가지 치명 화해 앱 결제 게 정말 분 결제 기억 실시간 계좌 이체 카드 결제 휴대폰결제 카드 결제 계좌 이체 연결 앱 오류 정보 학생 체크 카드 카드 보안 번호 결제 못 쇼핑몰 화해 단독 상품 사고 결제 못,화장품 관련 리뷰 상품 결제 기존 곳 온라인 결제 시 토스 무 통장 입금 결제 화해 온라인 결제 시스템 세라 휴대폰결제 카드 결제 계좌 이체 관련 앱 꽤 절차 최근 결제 처음 개선 더욱,화장품 성분 사용자 후기 볼 이용 리뷰 포인트 할인 제도 정말 결제 방식 제발 무 통장 입금 기능 화장품 어플 사용 실제 구매 어플 사용 못 해결 어플,리뷰 기간 포인트 혜자 움 업데이트 제때 화해 쇼핑 가격 보기 뷰티 온 메뉴 내용 캐릭터 표현 모습 실생활 유행 거리,성분 피부 리뷰 볼 랭킹 볼 제품 참고 화장품 구매 실패 확률 한가지 부탁 도구 랭킹 도구 사용 화해 도구 장단점 볼 파운데이션 브러쉬 아이섀도우 브러쉬 타입 분류 브러쉬 랭킹,화해 정말 애용 인기 제품 등록 이해 효과 제품 종종 기간 제품 등록 신청 데이터 수신 네트워크 확인 와이파이 빵빵 앱 계속 포기 브랜드 제품 사진 표기 뭡 화해 앱 버그 해결 등록 성분 검색 가격 표시 위 앱 명성 바 문의 해결 임시 저장 리뷰 제품 등록 요청 로드 기간 뒷북,광고 리뷰 광고 실사 용인 성분 집착 화장품 구매 독 방부 처리 피부 뭐 신뢰 사용 면,리뷰 볼때 피부 맞춤 기능 정말 카테고리 별로 분류 피부 타입 별로 분류 피부 타입 별로 선택 검색 기능 매우,화장품 성분 도움 의성 알러지 성분 표기 정말 평소 화장품 몇몇 의성 함유 보고 매우 앱 주의 성분 확인 구매 피부 트러블 앱 쇼핑 이벤트 리뷰 포인트 개념 마음 앱 엄마 앱,화해 온 유저 앱 반복 화장품 살때 앱 스킨 케어 제품 성분 앱 성분 꼭 확인 리뷰 볼 정말 카테고리 랭킹 정말 글쿠 제품 할인 정말 진짜 앱 단종 제품 제품 단종 가격 수정,화해 앱 사용 유저 평소 화장품 살때 성분 관심 편 어플 상품 가격 최근 애용 어플 결제 수단 어려움 결제 앱 추가 설치 중간 결제 포기 상황 발생 리뷰 분 어려움 꼭 담당 부서 내용 전달 무 통장 입금 결제 수단 마련,화장품 골 이제 화장 시작 테 제품 제품 성분 리뷰 이건 성분 거 성분 거 성분 가격 거 앱 가장 별 습,화해 앱 사용 피부 눈치 발생 간식 일절 먹기 초콜렛 커피 사랑 발생 스트레스 이유 피부 그냥 얘기 처방 그게 다임 화해 앱 시작 피부 타입 모든 기초 사용 중단 드 매일 막 트러블 어쩌다가 생리 주기 거나 하루 이틀 아주 중단 단 피부 화해 성분 조회 피부 타입 별 사용 가능 사용자 리뷰 덕이 몇개 중단 화장품 사기 용도 상품 검색 상품 비교 판매 처 가격 비교 이벤트 몇개 구매 설 도착,화해 이벤트 신청 시 개인정보 전화번호 유출 의심 화장품 성분 리뷰 확인 곳 이벤트 신청 화해 꼼평단 신청 계속 스팸 보이스피싱 전화 쇄도 어플 거르 불구 최근 국제 전화 스팸 보이스피싱,모든 화장품 성분 리뷰 가득 차서 화장품 선별 사용 제품 리뷰 작성 도움 포인트 화장품 브랜드 카테고리 별로 정리 순위도 화장품 구입 도움 앱 이벤트 나름,점점 업데이트 앱 관리 제대로 로딩 화장품 리뷰 볼때 사진 로딩 예전 대폭 졋 점점 앱,사용 화장품 리뷰 포인트 출석 체크 매일 쿠폰 사용 화장품 할인 구매 재미 갑자기 포인트 쿠폰 중복 적용 그냥 쿠팡 화장품 정책 굳이 리뷰 포인드 출석 체크 필요성 요즘 네이버 화장품 성분 혜택 화장품 애플리캐이션 굳이 화해 계속 사용 필요성,세 세 이용 가능 폰 혼란 사용 점도 리뷰,포인트 리뷰 출첵 포인트 재미 소용 그냥 네이버 최저 가로,성분 확인 리뷰 화장품 사기 자주 확인 앱 관리 제품 리뷰 화해 리뷰 포인트 적립 화해 쇼핑 이용 이제 포인트 주지 굳이 화해 쇼핑 이용 필요 듭니 가장 메리트,파우더 룸 앱 역시 선택 이유 이벤트 랜덤 당첨 파우더 룸 활동 응모 레벨 런가 리기 드릅 리뷰 화해 소통 파우더 룸 화해 추천,화해 앱 기초 제품 클렌징 선 케어 색조 화장품 제품 리뷰 백 성분 표시 비교 사기 인기 제품 제품 골 이벤트 랭킹 화플 건성 지성 중성 복합 게 화 테 진짜 도움 화해 제품 사고 사용 리뷰 포인트 적립 포인트 화장품 꼭꼭 사용,화해 정말 유저 화해 상품 예전 성분 가격 유명 브랜드 렉템 신생 브랜드 품질 화장품 구별 메이크업 꿀팁 유저 광고 후기 꼼 평단 회화 설 무료 화장품 보고 리뷰 기회 한번 너므 습 화해 결제 방법 앱 카드 설치 학생 연령 층 화해 포인트 특 화해 구매 학생 앱 카드 부모님 결재 편의점 결제 무 통장 입금 연령 연령 결 제법,먼저 화해 거 진짜 화장품 인기 피부 타입 성별 트러블 아기 임산부 한눈 랭킹 화해 이용자 리뷰 덕분 제품 소비 더욱 도움 이벤트 제품 의성 알레르기 의성 거 다운 후회,화해 리뷰 앱 소개 장점 모든 화장품 성분 성분 뿐 화장품 성분 피부 타입 도움 기능 성분 장점 랭킹 화해 피플 분 직접 보고 정말 객관 조언 리뷰 랭킹 신뢰 화 블로그 형식 화장품 이외 꿀팁 브러쉬 세척 법 용법 네일아트 다이어트 색 조합 퍼스 널 컬러 정말 꿀팁 이벤트 공짜 화장품 리뷰 정말 템 경쟁률 당첨 은근 성분 화장품 리뷰 기회 단점 단점 화해 사랑,점점 기능 정말 앱 하나로 성분 보고 리뷰 보고 구매 화장품 쇼핑 확 드 평가 단 신청 제품 무료 볼 기회 후기 칸 건 필수 어플 정말,진짜 앱 제품 리뷰 볼 게 제일 한가지 추가 부분 렌즈 렌즈 화장 부분 부분 꼭 요새 렌즈 정보 찾기 화해 싹 렌즈 리뷰 제품 확인,리뷰 정말 사용자 직접 리뷰 작성 이벤트 진행 건 정말 태그 별로 꿀팁 페이지 참고 유해 성분 그냥,이제 화해 화장품 성분 가격 특징 리뷰 화해 한눈 확인 유튜브 블로그 홍보 보고 이제 걱정 이벤트 신청 껜 당첨 화해 분 그냥 확률 왜냐면 포기 계속 도전 쇼,화장품 대한 리뷰 가격 정보 상세 보기 계속 앱 즐겨찾기 상품 순서 기능 순,제품 햐 여러 의견 곳 가장 곳 화해 진짜 화해 덕분 피부 화장품 돈 일도 사용 화장품 어플 화해 이벤트 통해 시험 단 추첨 솔직 리뷰 당첨 노력 당첨 화해 랭킹 통해 화장품 브랜드 별 순위 피부 별 순위 연령 대별 순위 방면 순위 볼 걱정,어플 오류 자주 데이터 수신 튕기거 리뷰 아예 안보 제발,화장품 리뷰 볼 추천 앱 한가지 추가 필터 기능 피부 퍼스 널 컬러 추가 뭐 겨울 딥 쿨 라이트 봄웜 여름 쿨 가을 웜 겨울 쿨,피부 화장품 항상 고민 리뷰 화장품 스킨 로션 바디 로션 피부 추천 상품 피부 화장품 찾기 화장품 리뷰 피부 화장품,앱 피부 기초 제품 욤 외 리뷰 적립금 이벵 추천 팁 정보 공유 리뷰 필러 기능 장점 단점 볼 리뷰 분 임티 이용 보기 설명 정말 앱 가끔 화장품 구입 쉐딩 득탬했음,원래 성분 관심 그냥 거 화해 화장품 기준 뒤 가끔 브랜드 거 대부분 제품 일도 첫 리뷰 두번째 리뷰 하나요 외국 제품 화해 구매 못 장가 화해 배송 두번째 리뷰 못 관계자 보시 답변,피부 화해 앱 요즘 성분 검색 계속 검색 데이터 수신 네트워크 확인 와이파이 곳 리뷰 화해 앱 점검 복구,화장품 특 기간 구매 게 제일 맘 포인트 적용 결제 수단 선택 부분 네이버 페이 카카오 페이 무 통장 입금 추가 바람 ...

# %%
def build_wto_bow_cws(document):
    okt = Okt()
    document = document.replace('.','')                
    tokenized_document = okt.nouns(document)      
    
    # BoW와 단어집합 만들기 - 객체 선언
    bow = []                                          
    word_to_index = {}                                  
    word_counts = {}
    # Bow와 단어집합 만들기
    for word in tokenized_document:
        if word not in word_to_index.keys():
            word_to_index[word] = len(word_to_index)
            bow.insert(len(word_to_index) - 1, 1)
        else:                                           
            index = word_to_index.get(word)
            bow[index] += 1
    word_counts = {key:bow[idx] for idx,key in enumerate(word_to_index)}
    
    return word_to_index, bow, word_counts

# %%
word_to_index, bow, word_counts = build_wto_bow_cws(doc)

# %%
# word_counts={key:bow[idx] for idx,key in enumerate(word_to_index)}
word_counts
# Out:
# {'평': 9,
#  '사용자': 74,
#  '수가': 26,
#  '장점': 32,
#  '외': 11,
#  '단점': 45,
#  '임': 17,
#  '이용자': 16,
#  '수만': 1,
#  '옆': 1,
#  '동네': 1,
#  '글': 46,
#  '로우': 10,
#  '픽': 6,
#  '이벤트': 216,
#  '샘플': 8,
#  '줌': 4,
#  '제품': 482,
#  '체험': 19,
#  '가능': 13,
#  '보임': 2,
#  '옥색': 1,
#  '인테리어': 1,
#  '느낌': 18,
#  '정리': 14,
#  '주의': 23,
#  '성분': 811,
#  '거': 147,
#  '대체': 5,
#  '한국': 5,
#  '유사과학': 1,
#  '잡채': 1,
#  '랭킹': 95,
#  '시스템': 8,
#  '단기간': 1,
#  '리뷰': 1770,
#  '키': 18,
#  '워드': 13,
#  '선택': 61,
#  '검색': 165,
#  '자꾸': 19,
#  '비교': 43,
#  '란줄알': 1,
#  '반신반의': 2,
#  '신청': 28,
#  '진짜': 266,
#  '기억': 9,
#  '배합': 1,
#  '목적': 9,
#  '포인트': 73,
#  '상품': 56,
#  '구매': 186,
#  '피부': 559,
#  '정말': 344,
#  '효과': 9,
#  '보기': 50,
#  '기능': 83,
#  '추가': 46,
#  '유저': 29,
#  '차단': 13,
#  '해당': 8,
#  '댓글': 14,
#  '일절': 2,
#  '블라인드': 14,
#  '처리': 18,
#  '프로필': 5,
#  '상': 4,
#  '웜톤': 4,
#  '쿨톤': 5,
#  '톤': 7,
#  '설정': 9,
#  '색조': 12,
#  '메이크업': 14,
#  '매우': 16,
#  '걸': 53,
#  '어플': 373,
#  '사용': 237,
#  '화장품': 1075,
#  '작성': 54,
#  '분': 123,
#  '앱': 606,
#  '업데이트': 32,
#  '가요': 23,
#  '참여': 15,
#  '려고': 3,
#  '몇개': 17,
#  '개정': 2,
#  '빈칸': 1,
#  '폰': 21,
#  '개선': 27,
#  '화해': 833,
#  '통해': 78,
#  '보고': 248,
#  '만날': 2,
#  '타입': 158,
#  '별': 68,
#  '여러': 41,
#  '눈': 19,
#  '볼': 197,
#  '최애': 4,
#  '유튜브': 12,
#  '추천': 147,
#  '접': 13,
#  '기준': 21,
#  '과정': 4,
#  '신세계': 2,
#  '한가지': 16,
#  '치명': 2,
#  '결제': 86,
#  '게': 52,
#  '실시간': 5,
#  '계좌': 15,
#  '이체': 13,
#  '카드': 11,
#  '휴대폰결제': 3,
#  '연결': 4,
#  '오류': 14,
#  '정보': 199,
#  '학생': 17,
#  '체크': 16,
#  '보안': 3,
#  '번호': 1,
#  '못': 34,
#  '쇼핑몰': 3,
#  '단독': 1,
#  '사고': 34,
#  '관련': 28,
#  '기존': 8,
#  '곳': 24,
#  '온라인': 6,
#  '시': 10,
#  '토스': 5,
#  '무': 24,
#  '통장': 22,
#  '입금': 28,
#  '세라': 1,
#  '꽤': 17,
#  '절차': 1,
#  '최근': 14,
#  '처음': 73,
#  '더욱': 11,
#  '후기': 67,
#  '이용': 57,
#  '할인': 19,
#  '제도': 1,
#  '방식': 8,
#  '제발': 30,
#  '실제': 23,
#  '해결': 8,
#  '기간': 19,
#  '혜자': 3,
#  '움': 7,
#  '제때': 1,
#  '쇼핑': 46,
#  '가격': 65,
#  '뷰티': 31,
#  '온': 4,
#  '메뉴': 2,
#  '내용': 16,
#  '캐릭터': 1,
#  '표현': 1,
#  '모습': 3,
#  '실생활': 1,
#  '유행': 4,
#  '거리': 1,
#  '참고': 41,
#  '실패': 17,
#  '확률': 17,
#  '부탁': 5,
#  '도구': 8,
#  '장단점': 14,
#  '파운데이션': 5,
#  '브러쉬': 15,
#  '아이섀도우': 1,
#  '분류': 11,
#  '애용': 33,
#  '인기': 14,
#  '등록': 42,
#  '이해': 9,
#  '종종': 5,
#  '데이터': 8,
#  '수신': 6,
#  '네트워크': 5,
#  '확인': 155,
#  '와이파이': 10,
#  '빵빵': 5,
#  '계속': 59,
#  '포기': 8,
#  '브랜드': 43,
#  '사진': 41,
#  '표기': 10,
#  '뭡': 1,
#  '버그': 1,
#  '표시': 43,
#  '위': 19,
#  '명성': 1,
#  '바': 4,
#  '문의': 7,
#  '임시': 3,
#  '저장': 7,
#  '요청': 8,
#  '로드': 19,
#  '뒷북': 1,
#  '광고': 113,
#  '실사': 1,
#  '용인': 1,
#  '집착': 1,
#  '독': 2,
#  '방부': 1,
#  '뭐': 59,
#  '신뢰': 35,
#  '면': 6,
#  '볼때': 9,
#  '맞춤': 10,
#  '카테고리': 28,
#  '별로': 80,
#  '도움': 175,
#  '의성': 19,
#  '알러지': 3,
#  '평소': 22,
#  '몇몇': 3,
#  '함유': 1,
#  '트러블': 48,
#  '개념': 1,
#  '마음': 23,
#  '엄마': 8,
#  '반복': 4,
#  '살때': 80,
#  '스킨': 19,
#  '케어': 14,
#  '꼭': 102,
#  '글쿠': 1,
#  '단종': 3,
#  '수정': 24,
#  '관심': 33,
#  '편': 16,
#  '수단': 17,
#  '어려움': 9,
#  '설치': 26,
#  '중간': 3,
#  '상황': 4,
#  '발생': 3,
#  '담당': 1,
#  '부서': 2,
#  '전달': 3,
#  '마련': 1,
#  '골': 11,
#  '이제': 60,
#  '화장': 46,
#  '시작': 24,
#  '테': 4,
#  '이건': 15,
#  '가장': 35,
#  '습': 16,
#  '눈치': 2,
#  '간식': 1,
#  '먹기': 1,
#  '초콜렛': 1,
#  '커피': 1,
#  '사랑': 21,
#  '스트레스': 4,
#  '이유': 16,
#  '그냥': 82,
#  '얘기': 5,
#  '처방': 1,
#  '그게': 9,
#  '다임': 1,
#  '모든': 30,
#  '기초': 26,
#  '중단': 4,
#  '드': 5,
#  '매일': 12,
#  '막': 27,
#  '어쩌다가': 1,
#  '생리': 1,
#  '주기': 2,
#  '거나': 33,
#  '하루': 6,
#  '이틀': 2,
#  '아주': 35,
#  '단': 20,
#  '조회': 3,
#  '덕이': 1,
#  '사기': 31,
#  '용도': 8,
#  '판매': 8,
#  '처': 4,
#  '설': 2,
#  '도착': 2,
#  '개인정보': 2,
#  '전화번호': 1,
#  '유출': 1,
#  '의심': 5,
#  '꼼': 62,
#  '평단': 61,
#  '스팸': 2,
#  '보이스피싱': 2,
#  '전화': 2,
#  '쇄도': 1,
#  '거르': 7,
#  '불구': 2,
#  '국제': 1,
#  '가득': 2,
#  '차서': 1,
#  '선별': 1,
#  '순위도': 8,
#  '구입': 30,
#  '나름': 9,
#  '점점': 18,
#  '관리': 14,
#  '제대로': 6,
#  '로딩': 14,
#  '예전': 35,
#  '대폭': 1,
#  '졋': 2,
#  '출석': 3,
#  '쿠폰': 8,
#  '재미': 17,
#  '갑자기': 21,
#  '중복': 3,
#  '적용': 3,
#  '쿠팡': 1,
#  '정책': 1,
#  '굳이': 14,
#  '포인드': 1,
#  '필요성': 2,
#  '요즘': 45,
#  '네이버': 28,
#  '혜택': 3,
#  '애플리캐이션': 1,
#  '세': 5,
#  '혼란': 1,
#  '점도': 8,
#  '출첵': 1,
#  '소용': 3,
#  '최저': 2,
#  '가로': 1,
#  '자주': 41,
#  '적립': 6,
#  '주지': 3,
#  '필요': 7,
#  '듭': 6,
#  '메리트': 2,
#  '파우더': 3,
#  '룸': 3,
#  '역시': 4,
#  '랜덤': 2,
#  '당첨': 108,
#  '활동': 1,
#  '응모': 6,
#  '레벨': 2,
#  '런가': 2,
#  '리기': 2,
#  '드릅': 1,
#  '소통': 10,
#  '클렌징': 6,
#  '선': 5,
#  '백': 2,
#  '화': 38,
#  '건성': 31,
#  '지성': 22,
#  '중성': 3,
#  '복합': 12,
#  '꼭꼭': 6,
#  '유명': 5,
#  '렉템': 1,
#  '신생': 1,
#  '품질': 2,
#  '구별': 5,
#  '꿀팁': 53,
#  '회화': 1,
#  '무료': 25,
#  '기회': 13,
#  '한번': 74,
#  '너므': 1,
#  '방법': 28,
#  '연령': 18,
#  '층': 1,
#  '특': 5,
#  '부모님': 3,
#  '결재': 6,
#  '편의점': 1,
#  '결': 2,
#  '제법': 1,
#  '먼저': 20,
#  '성별': 5,
#  '아기': 8,
#  '임산부': 1,
#  '한눈': 39,
#  '덕분': 77,
#  '소비': 5,
#  '알레르기': 26,
#  '다운': 17,
#  '후회': 18,
#  '소개': 8,
#  '뿐': 30,
#  '피플': 1,
#  '직접': 39,
#  '객관': 14,
#  '조언': 2,
#  '블로그': 29,
#  '형식': 1,
#  '이외': 4,
#  '세척': 2,
#  '법': 10,
#  '용법': 2,
#  '네일아트': 1,
#  '다이어트': 3,
#  '색': 8,
#  '조합': 1,
#  '퍼스': 4,
#  '널': 4,
#  '컬러': 4,
#  '공짜': 5,
#  '템': 22,
#  '경쟁률': 1,
#  '은근': 2,
#  '하나로': 5,
#  '확': 9,
#  '평가': 21,
#  '칸': 10,
#  '건': 31,
#  '필수': 36,
#  '제일': 32,
#  '부분': 34,
#  '렌즈': 13,
#  '요새': 9,
#  '찾기': 25,
#  '싹': 4,
#  '진행': 6,
#  '태그': 1,
#  '페이지': 5,
#  '유해': 59,
#  '특징': 3,
#  '홍보': 13,
#  '걱정': 21,
#  '껜': 1,
#  '왜냐면': 1,
#  '도전': 3,
#  '쇼': 1,
#  '대한': 36,
#  '상세': 14,
#  '즐겨찾기': 11,
#  '순서': 6,
#  '순': 19,
#  '햐': 1,
#  '의견': 13,
#  '돈': 29,
#  '일도': 17,
#  '시험': 2,
#  '추첨': 1,
#  '솔직': 8,
#  '노력': 5,
#  '순위': 33,
#  '대별': 6,
#  '방면': 1,
#  '튕기거': 1,
#  '아예': 16,
#  '안보': 20,
#  '필터': 17,
#  '겨울': 6,
#  '딥': 2,
#  '쿨': 4,
#  '라이트': 2,
#  '봄웜': 3,
#  '여름': 3,
#  '가을': 1,
#  '웜': 1,
#  '항상': 63,
#  '고민': 66,
#  '로션': 13,
#  '바디': 4,
#  '욤': 2,
#  '적립금': 7,
#  '이벵': 2,
#  '팁': 21,
#  '공유': 18,
#  '필러': 1,
#  '임티': 1,
#  '설명': 20,
#  '가끔': 16,
#  '쉐딩': 2,
#  '득탬했음': 1,
#  '원래': 29,
#  '뒤': 10,
#  '대부분': 11,
#  '첫': 7,
#  '두번째': 3,
#  '하나요': 10,
#  '외국': 1,
#  '장가': 3,
#  '배송': 10,
#  '관계자': 1,
#  '보시': 7,
#  '답변': 14,
#  '점검': 4,
#  '복구': 3,
#  '맘': 13,
#  '페이': 13,
#  '카카오': 12,
#  '바람': 3,
#  '화설': 1,
#  '여러가지': 19,
#  '프리': 1,
#  '브러시': 1,
#  '주시': 9,
#  '렉': 18,
#  '폼': 3,
#  '친구': 58,
#  '건의': 4,
#  '사항': 3,
#  '동물실험': 1,
#  '동물': 1,
#  '실험': 1,
#  '해': 47,
#  '시대': 2,
#  '신용카드': 7,
#  '북': 2,
#  '피드백': 3,
#  '위험': 10,
#  '달라': 8,
#  '위해': 21,
#  '처럼': 2,
#  '민감': 53,
#  '홍조': 5,
#  '디테일': 1,
#  '쏠쏠': 2,
#  '브랜드관': 1,
#  '무리': 1,
#  '직관': 2,
#  '단어': 4,
#  '포함': 8,
#  '번창': 3,
#  '고난': 2,
#  '이후': 17,
#  '공률': 1,
#  '정가': 2,
#  '정품': 2,
#  '등급': 9,
#  '실용': 5,
#  '매력': 2,
#  '휴대폰': 5,
#  '대애': 1,
#  '버튼': 14,
#  '건가': 15,
#  '중이': 5,
#  '어워즈': 1,
#  '선정': 3,
#  '가입': 30,
#  '나이': 30,
#  '남성': 2,
#  '공부': 12,
#  '화이팅': 8,
#  '모낭': 2,
#  '염': 2,
#  '지루': 4,
#  '피부염': 6,
#  '고생': 6,
#  '뭔가': 12,
#  '대박': 7,
#  '살짝': 4,
#  '분석': 39,
#  '살수': 22,
#  '좀더': 9,
#  '해주시': 11,
#  '저가': 2,
#  '고가': 1,
#  '안심': 16,
#  '첨부': 6,
#  '끝': 6,
#  '다해': 6,
#  '밥': 1,
#  '재': 6,
#  '분과': 10,
#  '착착': 1,
#  '심심': 1,
#  '풀이': 1,
#  '개이득': 2,
#  '남': 9,
#  '구분': 12,
#  '이름': 18,
#  '함': 24,
#  '결정': 23,
#  '쩌보': 1,
#  '신상': 4,
#  '닪는거': 1,
#  '용량': 10,
#  '장': 3,
#  '로그인': 23,
#  '조작': 1,
#  '이전': 10,
#  '폴더': 4,
#  '찜': 3,
#  '며칠': 6,
#  '글자': 3,
#  '여요': 5,
#  '설문': 3,
#  '횟수': 3,
#  '성부': 1,
#  '폭발': 2,
#  '만원': 1,
#  '가기': 4,
#  '창': 15,
#  '밑': 10,
#  '클렌져': 1,
#  '용품': 3,
#  '표': 11,
#  '사서': 17,
#  '막상': 6,
#  '별하나': 2,
#  '어쨋': 3,
#  '가루': 1,
#  '날림': 1,
#  '숨기': 1,
#  '기분': 15,
#  '고등학교': 2,
#  '군인': 1,
#  '아무': 13,
#  '군대': 1,
#  '장교': 1,
#  '태': 2,
#  '사려': 16,
#  '기': 12,
#  '달': 12,
#  '의미': 5,
#  '토너': 7,
#  '수분크림': 5,
#  '재생': 1,
#  '크림': 9,
#  '사이': 2,
#  '남자': 5,
#  '때매': 1,
#  '버': 2,
#  '문의사항': 2,
#  '뿐더러': 1,
#  '거기': 15,
#  '다가': 6,
#  '유발': 6,
#  '반값': 1,
#  '오늘': 11,
#  '가가': 2,
#  '헤어': 3,
#  '향수': 2,
#  '급': 2,
#  '존댓말': 1,
#  '여태': 4,
#  '조건': 5,
#  '거짓말': 6,
#  '박사': 2,
#  '우리엄마': 1,
#  '허락': 4,
#  '은': 6,
#  '초보': 6,
#  '하든': 1,
#  '은행': 2,
#  '입력': 1,
#  '나사': 1,
#  '꼴': 3,
#  '배송비': 3,
#  '딜': 3,
#  '초특': 1,
#  '이하': 3,
#  '젹': 1,
#  '사이트': 7,
#  '그동안': 13,
#  '본격': 1,
#  '쓰기': 16,
#  '운영': 10,
#  '폭도': 2,
#  '커서': 3,
#  '올리브영': 3,
#  '즈음': 1,
#  '주문': 14,
#  '업뎃되': 1,
#  '꾸욱': 1,
#  '수도': 22,
#  '실행': 3,
#  '일주일': 3,
#  '하늘': 1,
#  '은진': 1,
#  '확율': 1,
#  '말씀': 4,
#  '신규': 3,
#  '가입자': 1,
#  '기제': 1,
#  '최악': 3,
#  '만족도': 4,
#  '적기': 1,
#  '지도': 8,
#  '겹': 3,
#  '최대': 3,
#  '안주': 1,
#  '지급': 3,
#  '정성': 9,
#  '재고': 2,
#  '안정': 3,
#  '장바구니': 4,
#  '목록': 5,
#  '화면': 11,
#  '빈번': 1,
#  '서두': 1,
#  '이점': 3,
#  '빡센데': 1,
#  '소멸': 1,
#  '빨': 6,
#  '싢어짐': 1,
#  '매체': 2,
#  '아이디': 12,
#  '핸드폰': 6,
#  '패드': 1,
#  '세컨폰': 1,
#  '하라': 9,
#  '열': 7,
#  '하트': 4,
#  '색상': 4,
#  '케': 2,
#  '점순': 1,
#  '인생': 40,
#  '완전': 47,
#  '순이': 2,
#  '발견': 6,
#  '여드름': 29,
#  '자체': 15,
#  '통한': 2,
#  '뱅크': 3,
#  '신한은행': 1,
#  '우체국': 1,
#  '송금': 2,
#  '제한': 3,
#  '미자': 1,
#  '적극성': 1,
#  '성실': 1,
#  '보이지': 3,
#  '달리': 5,
#  '용감': 7,
#  '그대로': 8,
#  '뷰': 5,
#  '지우': 2,
#  '몸': 3,
#  '강': 9,
#  '추강': 3,
#  '추': 4,
#  '옛날': 16,
#  '얼굴': 24,
#  '욥': 6,
#  '덕': 14,
#  '마스크': 8,
#  '팩': 10,
#  '크기': 4,
#  '크게': 4,
#  '무조건': 31,
#  '평점': 17,
#  '의구': 1,
#  '라며': 2,
#  '기록': 4,
#  '한지': 8,
#  '뭘': 14,
#  '건젔': 1,
#  '마다': 4,
#  '애': 6,
#  '뭐썻어': 1,
#  '지유': 1,
#  '증말': 2,
#  '당청': 1,
#  '택배': 6,
#  '난후': 2,
#  '담청': 1,
#  '문자': 4,
#  '카톡': 4,
#  '떳는데': 1,
#  '용': 12,
#  '저번': 5,
#  '관리자': 6,
#  '구글': 3,
#  '치면': 4,
#  '이모': 1,
#  '예정': 3,
#  '강추': 16,
#  '손해': 1,
#  '전보': 3,
#  '파격': 2,
#  '초창': 3,
#  '쭉': 15,
#  '중인': 3,
#  '유지': 3,
#  '발전': 11,
#  '개발': 7,
#  '지인': 9,
#  '진성': 1,
#  '여태껏': 1,
#  '트럴블': 1,
#  '과대': 2,
#  '무었': 1,
#  '절말': 1,
#  '높이': 1,
#  '이벤': 2,
#  '개도': 6,
#  '실만': 1,
#  '타박': 1,
#  '란': 5,
#  '요하': 1,
#  '늘': 19,
#  '확정': 1,
#  '응원': 6,
#  '발색': 4,
#  '형': 2,
#  '애긔': 1,
#  '오른쪽': 2,
#  '왼쪽': 2,
#  '수집': 1,
#  '몰입': 1,
#  '품': 5,
#  '증정': 2,
#  '소리': 5,
#  '최소': 3,
#  '공통점': 1,
#  '공': 3,
#  '효율': 5,
#  '성도': 4,
#  '갑': 3,
#  '악용': 4,
#  '일반': 4,
#  '피해': 9,
#  '뇨': 2,
#  '쾌감': 2,
#  '프로': 3,
#  '소비자': 9,
#  '사춘기': 2,
#  '생기': 11,
#  '컨텐츠': 5,
#  '지식': 10,
#  '신제품': 11,
#  '다섯손가락': 1,
#  '더더': 6,
#  '쏙쏙': 4,
#  '연관': 2,
#  '짱': 15,
#  '알림': 5,
#  '삭제': 18,
#  '진동': 1,
#  '울리몀': 1,
#  '답글': 3,
#  '메일': 1,
#  '플레이스토어': 1,
#  '능력': 1,
#  '스': 5,
#  '크롤': 5,
#  '우측': 3,
#  '하단': 3,
#  '위로': 8,
#  '눌려': 1,
#  '화가': 3,
#  '겨': 1,
#  '지고': 3,
#  '제주도': 1,
#  '거주': 1,
#  '비용': 2,
#  '조': 1,
#  '권': 1,
#  '머': 4,
#  '아보': 2,
#  '랄': 2,
#  '잼': 2,
#  '분구': 1,
#  '선크림': 7,
#  '제작자': 4,
#  '부디': 1,
#  '번만': 3,
#  '유': 2,
#  '천자': 1,
#  '생활': 6,
#  '론': 2,
#  '최적화': 1,
#  '자극': 3,
#  '계정': 19,
#  '현': 1,
#  '일과': 1,
#  '기적': 3,
#  '꿀앱': 2,
#  '최고': 46,
#  '쩐다': 1,
#  '만하': 6,
#  '센스': 1,
#  '만점': 3,
#  '석': 2,
#  '애정': 4,
#  '보더': 1,
#  '취지': 4,
#  '활용': 7,
#  '성은': 1,
#  '촬영': 1,
#  '거치': 2,
#  '데이터베이스': 1,
#  '데모': 1,
#  '해시태그': 1,
#  '유독': 1,
#  '곰': 1,
#  '모양': 4,
#  '부담': 4,
#  '기전': 50,
#  '세안': 1,
#  '제나': 1,
#  '햇': 6,
#  '전혀': 4,
#  '디자인': 4,
#  '주로': 3,
#  '장문': 1,
#  '장려': 1,
#  '댓': 2,
#  '절절': 3,
#  '요구': 3,
#  '정작': 4,
#  '핵심': 2,
#  '그거': 10,
#  '타': 2,
#  '전체': 12,
#  '최신': 3,
#  '버전': 3,
#  '서버': 4,
#  '메인': 2,
#  '벌써': 6,
#  '미리': 14,
#  '맨': 4,
#  '만해': 4,
#  '함량': 2,
#  '토대': 1,
#  '믿음': 22,
#  '신경': 10,
#  '체적': 1,
#  '상한': 1,
#  '위험성': 7,
#  '미백': 5,
#  '지속': 4,
#  '성격': 3,
#  '투자': 3,
#  '비': 4,
#  '요정': 1,
#  '팩트': 2,
#  '오시': 1,
#  '아시': 2,
#  '정리정돈': 1,
#  '용어': 1,
#  '노출': 6,
#  '부언': 1,
#  '분위기': 3,
#  '결론': 5,
#  '똥망': 1,
#  '치기': 1,
#  '프라푸치노': 1,
#  '엽떡': 1,
#  '치맥': 1,
#  '아웃': 1,
#  '문화': 1,
#  '선도': 1,
#  '금방': 2,
#  '관': 4,
#  '유효': 1,
#  '어쩜': 1,
#  '년새': 1,
#  '거인': 1,
#  '안성맞춤': 1,
#  '장공': 1,
#  '진심': 9,
#  '물통': 1,
#  '이야기': 5,
#  '다한': 1,
#  '방출': 1,
#  '오프라인': 5,
#  '마장': 1,
#  '물품': 3,
#  '준비': 3,
#  '뷰러': 6,
#  '어퓨': 1,
#  '칭찬': 19,
#  '뎁': 1,
#  '소모품': 1,
#  '롱런': 1,
#  '법좀': 1,
#  '사지': 9,
#  '젤로': 1,
#  '개인': 14,
#  '판단': 10,
#  '거르길': 1,
#  '로서': 3,
#  '만족': 5,
#  '특별': 1,
#  '종류': 23,
#  '한참': 5,
#  '요즈음': 1,
#  '지점': 1,
#  '질감': 1,
#  '시기': 3,
#  '특성': 4,
#  '성심': 1,
#  '성의껏': 1,
#  '각질': 2,
#  '블랙': 1,
#  '헤드': 1,
#  '낫': 1,
#  '셧으': 1,
#  ...}

# %%
df = pd.DataFrame({'키워드': list(word_counts.keys()), '빈도':list(word_counts.values())})
df = df.sort_values('빈도',ascending=False)
df.head(20)
# Out:
#      키워드    빈도
# 35    리뷰  1770
# 77   화장품  1075
# 90    화해   833
# 26    성분   811
# 80     앱   606
# 52    피부   559
# 17    제품   482
# 75    어플   373
# 53    정말   344
# 45    진짜   266
# 92    보고   248
# 76    사용   237
# 14   이벤트   216
# 117   정보   199
# 98     볼   197
# 51    구매   186
# 216   도움   175
# 39    검색   165
# 94    타입   158
# 183   확인   155

# %% [markdown]
# ## 이미지화

# %%
from wordcloud import WordCloud

wc = WordCloud(font_path='./data/malgun.ttf',background_color='white', max_words=100, width=400, height=300,colormap='PuBu')
cloud = wc.fit_words(word_counts)
cloud.to_image()
# Out:
# <PIL.Image.Image image mode=RGB size=400x300>
